# %% [markdown]
# # Compute metrics for different window lengths
#
# **See file [visual_win_lens.ipynb](visual_win_lens.ipynb) for interactive plots.**

# %%
from pathlib import Path

CUR_ABS_DIR = Path.cwd().resolve()
PROJ_DIR = (CUR_ABS_DIR / '../../../').resolve()
OUTPUT_DIR = (PROJ_DIR / 'swissrivernetwork/benchmark/outputs/ray_results/').resolve()
DUMP_DIR = (CUR_ABS_DIR / 'outputs/').resolve()

LOAD_LATEST_RESULTS = True

# ISSUE_TAG = "\033[91m[issue]\033[0m "  # Red
# INFO_TAG = "[info] "  # Blue
# SUCCESS_TAG = "\033[92m[success]\033[0m "  # Green
#
# from rich.console import Console as rConsole
# from rich.text import Text as rText
#
# console = rConsole()
#
#
# def rprint(text=None):
#     if text is None:
#         console.print()
#         return
#     text = str(text)
#     if text.startswith(ISSUE_TAG):
#         t1, t2 = rText("[issue]", style="red bold"), text[len(ISSUE_TAG):]
#     elif text.startswith(INFO_TAG):
#         t1, t2 = rText("[info]", style="blue bold"), rText(text[len(INFO_TAG):], style="none")
#     elif text.startswith(SUCCESS_TAG):
#         t1, t2 = rText("[success]", style="green bold"), rText(text[len(SUCCESS_TAG):], style="none")
#     else:
#         t1, t2 = rText("", style="none"), rText(text, style="none")
#     console.print(t1, t2, end='')
#
#
# rprint(f'{INFO_TAG} Project directory: {PROJ_DIR}')
# rprint(f'{INFO_TAG} Output directory: {OUTPUT_DIR}')
# rprint(f'{INFO_TAG} Current directory: {CUR_ABS_DIR}')

ISSUE_TAG = '<span style="color:red;">[issue]</span> '
INFO_TAG = '<span style="color:blue;">[info]</span> '
SUCCESS_TAG = '<span style="color:green;">[success]</span> '


def print(text=None):
    from IPython.display import display, HTML
    if text is None:
        display(HTML("<br>"))
        return
    text = str(text)
    display(HTML(text))


print(f'{INFO_TAG} Project directory: {PROJ_DIR}')
print(f'{INFO_TAG} Current directory: {CUR_ABS_DIR}')
print(f'{INFO_TAG} Output directory: {OUTPUT_DIR}')
print(f'{INFO_TAG} Dump directory: {DUMP_DIR}')
# Out:
# <span style="color:blue;">[info]</span>  Project directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark
# <span style="color:blue;">[info]</span>  Current directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/visualize_results
# <span style="color:blue;">[info]</span>  Output directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/outputs/ray_results
# <span style="color:blue;">[info]</span>  Dump directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/visualize_results/outputs

# %%
import numpy as np


def curate_window_lens(window_lens: np.array, data_name: str, mode: str = 'subsequences', max_days: int = np.inf) -> list:
    """
    Curate window lengths based on dataset characteristics.

    Args:
        window_lens (list of int): List of window lengths to curate.
        data_name (str): Name of the dataset ('swiss-1990', 'swiss-2010', 'zurich').
        mode (str): Mode of operation. "full" for full dataset,
    """
    if data_name == 'swiss-1990':
        if mode == 'full':
            max_days = min(2188, max_days)
        elif mode == 'subsequences':
            max_days = min(853, max_days)
    elif data_name == 'swiss-2010':
        if mode == 'full' or mode == 'subsequences':
            max_days = min(1096, max_days)
    elif data_name == 'zurich':
        if mode == 'full' or mode == 'subsequences':
            max_days = min(1035, max_days)
    else:
        raise ValueError(f'Unknown data name: {data_name}')
    window_lens = window_lens[window_lens < max_days]
    window_lens = np.unique(np.concatenate((window_lens, [max_days])))
    window_lens = np.sort(window_lens)
    return window_lens

# %%
import pandas as pd
import os


def read_results_from_csv(output_dir: Path, graph_name: str, method: str):
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_window_lens_results.csv')
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        # print(f"{SUCCESS_TAG} Loaded results from {file_path}.")
        return df
    else:
        # print(f"{INFO_TAG} No results found at {file_path}.")
        return pd.DataFrame()


def save_results_to_csv(df: pd.DataFrame, output_dir: Path, graph_name: str, method: str):
    output_dir.mkdir(parents=True, exist_ok=True)
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_window_lens_results.csv')
    df.to_csv(file_path, index=False)
    # print(f"{SUCCESS_TAG} Saved results to {file_path}.")
    return file_path

# %%
WINDOW_LENS = np.concatenate(
    ([1, 3, 5, 7, 15], 30 * np.arange(1, 13), [365], 30 * np.arange(13, 25), 365 * np.arange(2, 11))
)

GRAPH_NAMES = ['swiss-1990', 'swiss-2010', 'zurich']
METHODS = ['lstm_embedding', 'transformer_embedding', 'lstm', 'graphlet', 'stgnn']

# %%
from swissrivernetwork.benchmark.ray_evaluation import process_method

def run_for_graph(graph_name: str):

    for m in METHODS[0:2]:  # test [2:3]
        print()
        print(f'{INFO_TAG} #### Starting processing for method="{m}" on graph="{graph_name}"...')

        max_days = 500 if m == 'transformer_embedding' else np.inf
        window_lens = curate_window_lens(WINDOW_LENS, graph_name, mode='subsequences', max_days=max_days)
        print(f'{INFO_TAG} Curated window lengths for graph="{graph_name}", method="{m}": {window_lens}')

        df_res = read_results_from_csv(DUMP_DIR, graph_name, m)

        for i_len, window_len in enumerate(window_lens):
            print(f"{INFO_TAG} ==== Processing window_len={window_len} [{i_len + 1}/{len(window_lens)}] ====")

            if not df_res.empty and window_len in df_res['window_len'].values:
                print(f"{SUCCESS_TAG} Results for window_len={window_len} already exist. Skipping...")
                continue

            df_data = process_method(
                graph_name, m, output_dir=OUTPUT_DIR, settings={'window_len': window_len, 'verbose': 1, 'env': 'notebook'}
            )
            new_row = {'window_len': window_len}
            for metric in ['RMSE', 'MAE', 'NSE']:
                for stat_measure in ['Mean', 'Std', 'Median', 'Min', 'Max']:
                    col_name = f'{metric}_{stat_measure}'
                    if metric in df_data.columns:
                        value = df_data[df_data['Station'] == stat_measure][metric]
                        if not value.empty:
                            new_row[col_name] = value.values[0]
                        else:
                            new_row[col_name] = np.nan
                    else:
                        new_row[col_name] = np.nan
            df_res = pd.concat([df_res, pd.DataFrame([new_row])], ignore_index=True)

            file_path = save_results_to_csv(df_res, DUMP_DIR, graph_name, m)

            print(f'{SUCCESS_TAG} Completed processing for window_len={window_len}. Results saved to {file_path}.')

        print(f'{SUCCESS_TAG} #### Finished processing for method="{m}" on graph="{graph_name}"!')

# %%
# Compute results and save to CSV:
for graph_name in GRAPH_NAMES[0:]:
    print(f'{INFO_TAG} ================= Starting processing for graph="{graph_name}" =================')
    run_for_graph(graph_name)
# Out:
# <span style="color:blue;">[info]</span>  ================= Starting processing for graph="swiss-1990" =================
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="lstm_embedding" on graph="swiss-1990"...
# <span style="color:blue;">[info]</span>  Curated window lengths for graph="swiss-1990", method="lstm_embedding": [  1   3   5   7  15  30  60  90 120 150 180 210 240 270 300 330 360 365
#  390 420 450 480 510 540 570 600 630 660 690 720 730 853]
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1 [1/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=1 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=3 [2/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=3 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=5 [3/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=5 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=7 [4/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=7 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=15 [5/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=15 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=30 [6/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=30 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=60 [7/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=60 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=90 [8/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=120 [9/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=120 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=150 [10/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=150 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=180 [11/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=180 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=210 [12/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=210 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=240 [13/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=240 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=270 [14/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=270 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=300 [15/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=300 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=330 [16/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=330 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=360 [17/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=360 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=365 [18/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=365 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=390 [19/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=390 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=420 [20/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=420 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=450 [21/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=450 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=480 [22/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=480 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=510 [23/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=510 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=540 [24/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=540 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=570 [25/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=570 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=600 [26/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=600 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=630 [27/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=630 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=660 [28/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=660 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=690 [29/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=690 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=720 [30/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=720 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=730 [31/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=730 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=853 [32/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=853 already exist. Skipping...
# <span style="color:green;">[success]</span>  #### Finished processing for method="lstm_embedding" on graph="swiss-1990"!
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer_embedding" on graph="swiss-1990"...
# <span style="color:blue;">[info]</span>  Curated window lengths for graph="swiss-1990", method="transformer_embedding": [  1   3   5   7  15  30  60  90 120 150 180 210 240 270 300 330 360 365
#  390 420 450 480 500]
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1 [1/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=1 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=3 [2/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=3 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=5 [3/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=5 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=7 [4/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=7 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=15 [5/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=15 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=30 [6/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=30 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=60 [7/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=60 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=90 [8/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=120 [9/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=120 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=150 [10/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=150 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=180 [11/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=180 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=210 [12/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=210 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=240 [13/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=240 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=270 [14/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=270 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=300 [15/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=300 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=330 [16/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=330 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=360 [17/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=360 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=365 [18/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=365 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=390 [19/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=390 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=420 [20/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=420 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=450 [21/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=450 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=480 [22/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=480 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=500 [23/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=500 already exist. Skipping...
# <span style="color:green;">[success]</span>  #### Finished processing for method="transformer_embedding" on graph="swiss-1990"!
# <span style="color:blue;">[info]</span>  ================= Starting processing for graph="swiss-2010" =================
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="lstm_embedding" on graph="swiss-2010"...
# <span style="color:blue;">[info]</span>  Curated window lengths for graph="swiss-2010", method="lstm_embedding": [   1    3    5    7   15   30   60   90  120  150  180  210  240  270
#   300  330  360  365  390  420  450  480  510  540  570  600  630  660
#   690  720  730 1095 1096]
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1 [1/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=1 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=3 [2/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=3 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=5 [3/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=5 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=7 [4/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=7 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=15 [5/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=15 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=30 [6/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=30 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=60 [7/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=60 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=90 [8/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=120 [9/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=120 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=150 [10/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=150 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=180 [11/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=180 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=210 [12/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=210 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=240 [13/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=240 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=270 [14/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=270 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=300 [15/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=300 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=330 [16/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=330 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=360 [17/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=360 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=365 [18/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=365 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=390 [19/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=390 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=420 [20/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=420 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=450 [21/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=450 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=480 [22/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=480 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=510 [23/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=510 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=540 [24/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=540 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=570 [25/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=570 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=600 [26/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=600 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=630 [27/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=630 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=660 [28/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=660 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=690 [29/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=690 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=720 [30/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=720 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=730 [31/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=730 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1095 [32/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=1095 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1096 [33/33] ====
# <span style="color:green;">[success]</span>  Results for window_len=1096 already exist. Skipping...
# <span style="color:green;">[success]</span>  #### Finished processing for method="lstm_embedding" on graph="swiss-2010"!
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer_embedding" on graph="swiss-2010"...
# <span style="color:blue;">[info]</span>  Curated window lengths for graph="swiss-2010", method="transformer_embedding": [  1   3   5   7  15  30  60  90 120 150 180 210 240 270 300 330 360 365
#  390 420 450 480 500]
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1 [1/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=1 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=3 [2/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=3 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=5 [3/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=5 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=7 [4/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=7 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=15 [5/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=15 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=30 [6/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=30 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=60 [7/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=60 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=90 [8/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=120 [9/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=120 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=150 [10/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=150 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=180 [11/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=180 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=210 [12/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=210 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=240 [13/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=240 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=270 [14/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=270 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=300 [15/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=300 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=330 [16/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=330 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=360 [17/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=360 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=365 [18/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=365 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=390 [19/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=390 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=420 [20/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=420 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=450 [21/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=450 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=480 [22/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=480 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=500 [23/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=500 already exist. Skipping...
# <span style="color:green;">[success]</span>  #### Finished processing for method="transformer_embedding" on graph="swiss-2010"!
# <span style="color:blue;">[info]</span>  ================= Starting processing for graph="zurich" =================
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="lstm_embedding" on graph="zurich"...
# <span style="color:blue;">[info]</span>  Curated window lengths for graph="zurich", method="lstm_embedding": [   1    3    5    7   15   30   60   90  120  150  180  210  240  270
#   300  330  360  365  390  420  450  480  510  540  570  600  630  660
#   690  720  730 1035]
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1 [1/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=1 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=3 [2/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=3 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=5 [3/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=5 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=7 [4/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=7 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=15 [5/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=15 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=30 [6/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=30 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=60 [7/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=60 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=90 [8/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=120 [9/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=120 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=150 [10/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=150 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=180 [11/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=180 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=210 [12/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=210 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=240 [13/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=240 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=270 [14/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=270 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=300 [15/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=300 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=330 [16/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=330 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=360 [17/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=360 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=365 [18/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=365 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=390 [19/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=390 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=420 [20/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=420 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=450 [21/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=450 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=480 [22/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=480 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=510 [23/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=510 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=540 [24/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=540 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=570 [25/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=570 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=600 [26/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=600 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=630 [27/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=630 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=660 [28/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=660 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=690 [29/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=690 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=720 [30/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=720 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=730 [31/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=730 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1035 [32/32] ====
# <span style="color:green;">[success]</span>  Results for window_len=1035 already exist. Skipping...
# <span style="color:green;">[success]</span>  #### Finished processing for method="lstm_embedding" on graph="zurich"!
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer_embedding" on graph="zurich"...
# <span style="color:blue;">[info]</span>  Curated window lengths for graph="zurich", method="transformer_embedding": [  1   3   5   7  15  30  60  90 120 150 180 210 240 270 300 330 360 365
#  390 420 450 480 500]
# <span style="color:blue;">[info]</span>  ==== Processing window_len=1 [1/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=1 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=3 [2/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=3 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=5 [3/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=5 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=7 [4/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=7 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=15 [5/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=15 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=30 [6/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=30 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=60 [7/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=60 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=90 [8/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=120 [9/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=120 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=150 [10/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=150 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=180 [11/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=180 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=210 [12/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=210 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=240 [13/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=240 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=270 [14/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=270 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=300 [15/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=300 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=330 [16/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=330 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=360 [17/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=360 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=365 [18/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=365 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=390 [19/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=390 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=420 [20/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=420 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=450 [21/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=450 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=480 [22/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=480 already exist. Skipping...
# <span style="color:blue;">[info]</span>  ==== Processing window_len=500 [23/23] ====
# <span style="color:green;">[success]</span>  Results for window_len=500 already exist. Skipping...
# <span style="color:green;">[success]</span>  #### Finished processing for method="transformer_embedding" on graph="zurich"!
