# %% [markdown]
# # Process data

# %% [markdown]
# ## Process error-based metrics (MAE, RMSE, NSE) with window lengths 90
# (together with model size and runtime)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

CUR_ABS_DIR = Path.cwd().resolve()
PROJ_DIR = (CUR_ABS_DIR / '../../../').resolve()
OUTPUT_DIR = (PROJ_DIR / 'swissrivernetwork/benchmark/outputs/ray_results/').resolve()
DUMP_DIR = (CUR_ABS_DIR / 'outputs/radar/').resolve()
STATIONS_DUMP_DIR = (CUR_ABS_DIR / 'outputs/stations/').resolve()

LOAD_LATEST_RESULTS = True

ISSUE_TAG = '<span style="color:red;">[issue]</span> '
INFO_TAG = '<span style="color:blue;">[info]</span> '
SUCCESS_TAG = '<span style="color:green;">[success]</span> '


def print(text=None):
    from IPython.display import display, HTML
    if text is None:
        display(HTML("<br>"))
        return
    text = str(text)
    display(HTML(text))


print(f'{INFO_TAG} Project directory: {PROJ_DIR}')
print(f'{INFO_TAG} Current directory: {CUR_ABS_DIR}')
print(f'{INFO_TAG} Output directory: {OUTPUT_DIR}')
print(f'{INFO_TAG} Dump directory: {DUMP_DIR}')
# Out:
# <span style="color:blue;">[info]</span>  Project directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark
# <span style="color:blue;">[info]</span>  Current directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/visualize_results
# <span style="color:blue;">[info]</span>  Output directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/outputs/ray_results
# <span style="color:blue;">[info]</span>  Dump directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/visualize_results/outputs/radar

# %%
METRICS_LIST = ['RMSE', 'MAE', 'NSE']
STATS_LIST = ['Mean', 'Std', 'Median', 'Min', 'Max', 'CI95']

# %%
# Get Err 90 data, Model Size data, Runtime data

import pandas as pd
import os
import json


def read_results_from_csv(
        output_dir: Path, graph_name: str, method: str, filename_key: str = 'results', verbose: bool = False
) -> pd.DataFrame:
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_{filename_key}.csv')
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        if verbose:
            print(f"{SUCCESS_TAG} Loaded results from {file_path}.")
        return df
    else:
        if verbose:
            print(f"{INFO_TAG} No results found at {file_path}.")
        return pd.DataFrame()


def save_results_to_csv(
        df: pd.DataFrame, output_dir: Path, graph_name: str, method: str, filename_key: str = 'results',
        verbose: bool = True
) -> str:
    output_dir.mkdir(parents=True, exist_ok=True)
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_{filename_key}.csv')
    df.to_csv(file_path, index=False)
    if verbose:
        print(f"{SUCCESS_TAG} Saved results to {file_path}.")
    return file_path


def read_results_from_json(
        output_dir: Path, graph_name: str, method: str, filename_key: str = 'results', verbose: bool = False
) -> dict:
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_{filename_key}.json')
    if os.path.exists(file_path):
        with open(file_path, 'r') as f:
            data = json.load(f)
        if verbose:
            print(f"{SUCCESS_TAG} Loaded extra results from {file_path}.")
        return data
    else:
        if verbose:
            print(f"{INFO_TAG} No extra results found at {file_path}.")
        return {}


def save_results_to_json(
        data: dict, output_dir: Path, graph_name: str, method: str, filename_key: str = 'results',
        verbose: bool = True
) -> str:
    output_dir.mkdir(parents=True, exist_ok=True)
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_{filename_key}.json')
    with open(file_path, 'w') as f:
        json.dump(data, f, indent=4)
    if verbose:
        print(f"{SUCCESS_TAG} Saved results to {file_path}.")
    return file_path


def dump_station_results(
        df_data: pd.DataFrame, output_dir: Path, graph_name: str, method: str,
        filename_key: str = 'station_resu', verbose: bool = False
) -> str:
    # Keep only rows that are stations (not in STATS_LIST) and columns that are in METRICS_LIST:
    df_data = df_data[~df_data['Station'].isin(STATS_LIST)]
    df_data = df_data[['Station'] + METRICS_LIST]
    return save_results_to_csv(df_data, output_dir, graph_name, method, filename_key=filename_key, verbose=verbose)

# %%
from swissrivernetwork.benchmark.ray_evaluation import process_method
from swissrivernetwork.benchmark.util import get_run_extra_key, is_transformer_model
from typing import Union


def infer_single_run(
        graph_name: str, method: str, df_res: pd.DataFrame, settings: dict
) -> (pd.DataFrame, pd.DataFrame, dict):
    import numpy as np

    max_days = 500 if method == 'transformer_embedding' else np.inf
    # window_len = 90  # curate_window_lens(WINDOW_LENS, graph_name, mode='subsequences', max_days=max_days)
    # print(f'{INFO_TAG} Curated window lengths for graph="{graph_name}", method="{m}": {window_lens}')

    settings['path_extra_keys'] = get_run_extra_key(settings)

    df_data, extra_resu = process_method(
        graph_name, method, output_dir=OUTPUT_DIR, settings=settings, return_extra=True
    )
    new_row = {'window_len': settings['window_len']}
    for metric in METRICS_LIST:
        for stat_measure in STATS_LIST:
            col_name = f'{metric}_{stat_measure}'
            if metric in df_data.columns:
                value = df_data[df_data['Station'] == stat_measure][metric]
                if not value.empty:
                    new_row[col_name] = value.values[0]
                else:
                    new_row[col_name] = np.nan
            else:
                new_row[col_name] = np.nan
    # Add extra results:
    extra_resu_keys = [k for k in df_data.keys().to_list() if k.startswith('extra__')]
    for extra_key in extra_resu_keys:
        new_row[f'{extra_key}_Mean'] = df_data[df_data['Station'] == 'Mean'][extra_key].values[0]
    for key in extra_resu.keys():
        if f'extra__{key}' not in new_row:
            new_row[f'extra__{key}'] = extra_resu[key]

    df_res = pd.concat([df_res, pd.DataFrame([new_row])], ignore_index=True)
    return df_res, df_data, extra_resu


def infer_lstm(
        graph_name: str, method: str, df_res: pd.DataFrame, settings: dict
) -> Union[pd.DataFrame, str] | None:
    window_len = settings['window_len']
    if not df_res.empty and window_len in df_res['window_len'].values:
        print(f"{SUCCESS_TAG} Results for window_len={window_len} already exist. Skipping...")
        return None, None

    settings.update(
        {
            'positional_encoding': 'none',
        }
    )

    df_res, df_data, extra_resu = infer_single_run(graph_name, method, df_res, settings)
    file_path = save_results_to_csv(df_res, DUMP_DIR, graph_name, method, filename_key='err_90', verbose=True)
    # file_path_extra = save_results_to_json(
    #     extra_resu, DUMP_DIR, graph_name, method, filename_key='extra_resu', verbose=True
    # )
    dump_station_results(df_data, STATIONS_DUMP_DIR, graph_name, method, filename_key='station_resu', verbose=False)
    return df_res, file_path


def infer_transformer(
        graph_name: str, method: str, df_res: pd.DataFrame, settings: dict
) -> Union[pd.DataFrame, str] | None:
    window_len = settings['window_len']
    position_encodings = ['learnable', 'sinusoidal', 'rope']  # [None, 'learnable', 'sinusoidal', 'rope']
    updated = False
    for pe in position_encodings:
        print(f'{INFO_TAG} --- Processing positional_encoding={pe} ---')
        if not df_res.empty and window_len in df_res['window_len'].values and pe in df_res[
            'positional_encoding'].values:
            print(
                f'{SUCCESS_TAG} Results for window_len={window_len}, positional_encoding={pe} already exist. Skipping...'
            )
            continue

        settings.update(
            {
                'max_len': 500,
                'positional_encoding': pe,  # 'learnable' or 'sinusoidal' or 'rope' or None
            }
        )

        df_res, df_data, extra_resu = infer_single_run(graph_name, method, df_res, settings)  # Already concatenated
        if 'positional_encoding' in df_res.columns:
            df_res.loc[df_res.index[-1], 'positional_encoding'] = pe
        else:
            df_res.insert(loc=1, column='positional_encoding', value=pe)

        file_path = save_results_to_csv(df_res, DUMP_DIR, graph_name, method, filename_key='err_90', verbose=True)
        dump_station_results(
            df_data, STATIONS_DUMP_DIR, graph_name, method, filename_key=f'{pe}_station_resu',
            verbose=False
        )

        updated = True

    if not updated:
        return None, None

    return df_res, file_path


def infer_graph(graph_name: str, methods: list[str], window_len: int = 90):
    for m in methods:
        print()
        print(f'{INFO_TAG} #### Starting processing for method="{m}" on graph="{graph_name}"...')

        df_res = read_results_from_csv(DUMP_DIR, graph_name, m, filename_key='err_90')
        # extra_resu = read_results_from_json(DUMP_DIR, graph_name, m, filename_key='extra_resu')
        # print(f"{INFO_TAG} ==== Processing window_len={window_len} [{i_len + 1}/{len(window_lens)}] ====")

        settings = {
            'missing_value_method': None,  # 'mask_embedding' or 'interpolation' or 'zero' or None
            'use_current_x': True,
            'window_len': 90,
            'verbose': 1,
            'env': 'notebook',
        }

        if is_transformer_model(m):
            df_res, file_path = infer_transformer(graph_name, m, df_res, settings)
        else:
            df_res, file_path = infer_lstm(graph_name, m, df_res, settings)
        if df_res is None:
            continue

        print(f'{SUCCESS_TAG} Completed processing for window_len={window_len}. Results saved to {file_path}. ')

        print(f'{SUCCESS_TAG} #### Finished processing for method="{m}" on graph="{graph_name}"!')

# %%
GRAPH_NAMES = ['swiss-1990', 'swiss-2010', 'zurich']
METHODS = ['lstm', 'transformer', 'graphlet', 'transformer_graphlet', 'lstm_embedding', 'transformer_embedding',
           'stgnn', 'transformer_stgnn']

# %%
# Compute results and save to CSV:
for graph_name in GRAPH_NAMES[0:0]:
    print(f'{INFO_TAG} ================= Starting processing for graph="{graph_name}" =================')
    infer_graph(graph_name, METHODS[0:], window_len=90)  # test [2:3]

# %% [markdown]
# # Plot radar charts

# %% [markdown]
# ## Gather data

# %% [markdown]
# ### Gather Err 90 data, Model Size data, Runtime data

# %%
GRAPH_NAMES = ['swiss-1990', 'swiss-2010', 'zurich']
METHODS = ['lstm', 'transformer', 'graphlet', 'transformer_graphlet', 'lstm_embedding', 'transformer_embedding',
           'stgnn', 'transformer_stgnn']

# %%
import pandas as pd


def get_err_from_df_lstm(df_res: pd.DataFrame, metric: str, window_len: int = 90) -> float | None:
    # Filter rows with window_len=window_len
    df_filtered = df_res[df_res['window_len'] == window_len]
    if df_filtered.empty:
        print(f'{ISSUE_TAG} No data found for window_len={window_len}.')
        return None
    if len(df_filtered) > 1:
        raise ValueError(f'{ISSUE_TAG} Multiple rows found for window_len={window_len}. Expected only one.')
    return float(df_filtered.iloc[0][metric])


def get_err_from_df_transformer(df_res: pd.DataFrame, metric: str, window_len: int = 90) -> (float | None, str | None):
    # Filter rows with window_len=window_len
    df_filtered = df_res[df_res['window_len'] == window_len]
    if df_filtered.empty:
        print(f'{ISSUE_TAG} No data found for window_len={window_len}.')
        return None, None
    # Get the row with the best metric (lowest for RMSE and MAE, highest for NSE):
    if metric.startswith('RMSE') or metric.startswith('MAE'):
        best_row = df_filtered.loc[df_filtered[metric].idxmin()]
    elif metric.startswith('NSE'):
        best_row = df_filtered.loc[df_filtered[metric].idxmax()]
    elif any([k in metric for k in ['model_size', 'train_time', 'infer_time']]):
        best_row = df_filtered.loc[df_filtered['RMSE_Mean'].idxmin()]  # Choose the one with min RMSE Mean
    else:
        print(f'{ISSUE_TAG} Unknown metric "{metric}".')
        return None, None
    return float(best_row[metric]), best_row['positional_encoding']


def gather_err_data(
        graph_names: list[str], methods: list[str], metric: str = 'RMSE_Mean', window_len: int = 90
) -> dict:
    data, best_pes = {}, {}
    for graph_name in graph_names:
        data[graph_name] = {}
        best_pes[graph_name] = {}
        for method in methods:
            df_res = read_results_from_csv(DUMP_DIR, graph_name, method, filename_key='err_90')
            if df_res.empty:
                print(f"{ISSUE_TAG} No data found for graph='{graph_name}', method='{method}'. Skipping...")
                continue
            if is_transformer_model(method):
                result, best_pe = get_err_from_df_transformer(df_res, metric, window_len=window_len)
                best_pes[graph_name][method] = best_pe
            else:
                result = get_err_from_df_lstm(df_res, metric, window_len=window_len)
            print(f'{SUCCESS_TAG} Gathered {metric}={result} for graph="{graph_name}", method="{method}".')

            data[graph_name][method] = result

    return data, best_pes


def normalize_err_data(
        err_data: dict, min_is_better: bool = True, global_min: float | None = None, global_max: float | None = None,
) -> dict:
    """
    Normalize error data to [0, 1] range across all graphs and methods. Higher values are better.
    """
    # Find global min and max
    return err_data
    all_values = []
    for graph_name in err_data:
        for method in err_data[graph_name]:
            value = err_data[graph_name][method]
            if value is not None:
                all_values.append(value)
    global_min = min(all_values) if global_min is None else global_min
    global_max = max(all_values) if global_max is None else global_max

    # Normalize data
    normalized_data = {}
    for graph_name in err_data:
        normalized_data[graph_name] = {}
        for method in err_data[graph_name]:
            value = err_data[graph_name][method]
            if value is None:
                normalized_value = None
            else:
                if min_is_better:
                    normalized_value = (global_max - value) / (global_max - global_min)  # Higher is better
                else:
                    normalized_value = (value - global_min) / (global_max - global_min)  # Higher is better
            normalized_data[graph_name][method] = normalized_value

    return normalized_data

# %%
metric = 'RMSE_Mean'
err_90_data, rmse_best_pes = gather_err_data(GRAPH_NAMES, METHODS, metric, window_len=90)
normalized_err_90_data = normalize_err_data(err_90_data, min_is_better=(not metric.startswith('NSE')))
print(normalized_err_90_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7815847992897034 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7530428171157837 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.76872318983078 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7456002831459045 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.8022345304489136 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7756783366203308 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.9422136545181274 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.9413735270500184 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.788673996925354 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.772978663444519 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7454374432563782 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7245303392410278 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7891973257064819 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.779171884059906 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.8992083072662354 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.8961308002471924 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7480738162994385 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7221101522445679 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7110646963119507 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7197110652923584 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7983226180076599 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.6995705366134644 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.9243724942207336 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.9030463099479676 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.7815847992897034, 'transformer': 0.7530428171157837, 'graphlet': 0.76872318983078, 'transformer_graphlet': 0.7456002831459045, 'lstm_embedding': 0.8022345304489136, 'transformer_embedding': 0.7756783366203308, 'stgnn': 0.9422136545181274, 'transformer_stgnn': 0.9413735270500184}, 'swiss-2010': {'lstm': 0.788673996925354, 'transformer': 0.772978663444519, 'graphlet': 0.7454374432563782, 'transformer_graphlet': 0.7245303392410278, 'lstm_embedding': 0.7891973257064819, 'transformer_embedding': 0.779171884059906, 'stgnn': 0.8992083072662354, 'transformer_stgnn': 0.8961308002471924}, 'zurich': {'lstm': 0.7480738162994385, 'transformer': 0.7221101522445679, 'graphlet': 0.7110646963119507, 'transformer_graphlet': 0.7197110652923584, 'lstm_embedding': 0.7983226180076599, 'transformer_embedding': 0.6995705366134644, 'stgnn': 0.9243724942207336, 'transformer_stgnn': 0.9030463099479676}}

# %%
metric = 'MAE_Mean'
mae_data, mae_best_pes = gather_err_data(GRAPH_NAMES, METHODS, metric, window_len=90)
normalized_mae_data = normalize_err_data(mae_data, min_is_better=True)
print(normalized_mae_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5982856154441833 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5725784301757812 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5905265212059021 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5636321902275085 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6194817423820496 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5890956521034241 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.720732569694519 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.716244637966156 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6094375252723694 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5978536605834961 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5732033252716064 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5589770674705505 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6100487112998962 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6037866473197937 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6839091777801514 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6842291951179504 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5858083367347717 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.564784824848175 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5594092011451721 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5611136555671692 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6033580303192139 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5487588047981262 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6844618320465088 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6691928505897522 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.5982856154441833, 'transformer': 0.5725784301757812, 'graphlet': 0.5905265212059021, 'transformer_graphlet': 0.5636321902275085, 'lstm_embedding': 0.6194817423820496, 'transformer_embedding': 0.5890956521034241, 'stgnn': 0.720732569694519, 'transformer_stgnn': 0.716244637966156}, 'swiss-2010': {'lstm': 0.6094375252723694, 'transformer': 0.5978536605834961, 'graphlet': 0.5732033252716064, 'transformer_graphlet': 0.5589770674705505, 'lstm_embedding': 0.6100487112998962, 'transformer_embedding': 0.6037866473197937, 'stgnn': 0.6839091777801514, 'transformer_stgnn': 0.6842291951179504}, 'zurich': {'lstm': 0.5858083367347717, 'transformer': 0.564784824848175, 'graphlet': 0.5594092011451721, 'transformer_graphlet': 0.5611136555671692, 'lstm_embedding': 0.6033580303192139, 'transformer_embedding': 0.5487588047981262, 'stgnn': 0.6844618320465088, 'transformer_stgnn': 0.6691928505897522}}

# %%
metric = 'NSE_Mean'
nse_data, nse_best_pes = gather_err_data(GRAPH_NAMES, METHODS, metric, window_len=90)
normalized_nse_data = nse_data  # normalize_err_data(nse_data, min_is_better=False, global_min=0.0, global_max=1.0)
print(normalized_nse_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9544531106948853 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.958686888217926 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9563571214675904 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9599848985671996 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9520756006240844 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9546304941177368 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9366945028305054 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9361128807067872 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9604772329330444 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.962583601474762 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9650015234947203 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9673346877098083 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9609785079956056 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.962767779827118 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9504563212394714 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9508898854255676 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9786393046379088 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.979767918586731 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9805818200111388 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9798020124435424 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9765729904174804 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9806655645370485 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9699851870536804 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.971068799495697 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.9544531106948853, 'transformer': 0.958686888217926, 'graphlet': 0.9563571214675904, 'transformer_graphlet': 0.9599848985671996, 'lstm_embedding': 0.9520756006240844, 'transformer_embedding': 0.9546304941177368, 'stgnn': 0.9366945028305054, 'transformer_stgnn': 0.9361128807067872}, 'swiss-2010': {'lstm': 0.9604772329330444, 'transformer': 0.962583601474762, 'graphlet': 0.9650015234947203, 'transformer_graphlet': 0.9673346877098083, 'lstm_embedding': 0.9609785079956056, 'transformer_embedding': 0.962767779827118, 'stgnn': 0.9504563212394714, 'transformer_stgnn': 0.9508898854255676}, 'zurich': {'lstm': 0.9786393046379088, 'transformer': 0.979767918586731, 'graphlet': 0.9805818200111388, 'transformer_graphlet': 0.9798020124435424, 'lstm_embedding': 0.9765729904174804, 'transformer_embedding': 0.9806655645370485, 'stgnn': 0.9699851870536804, 'transformer_stgnn': 0.971068799495697}}

# %% [markdown]
# ### Gather forecasting results (RMSE, MAE, NSE), window length results, and noise robustness results:
# **Forecasting results are loaded from files saved by running `future_steps_resu.ipynb` in the same directory.**
#
# **Window length results are loaded from files saved by running `window_length_resu.ipynb` in the same directory.**
#
# **Noise robustness results are loaded from files saved by running `noise_robustness_resu.ipynb` in the same directory.**

# %%
from typing import Any


def aggregate_fs_metric(values: dict[Any, float]) -> float:
    values = list(values.values())
    return sum(values) / len(values)


def aggregate_win_len_metric(values: dict[Any, float]) -> float:
    """
    $\text{WT-Score}=\frac{\sum_{i} w(c_i) M(c_i)}{\sum_{i} w(c_i)}$,
    where $w(l)=2^{-l/h_{1/2}}$.
    """
    keys = list(values.keys())
    max_len = max(keys)
    h_half = max_len // 2
    weighted_sum = 0.0
    weight_total = 0.0
    for l in keys:
        w_l = 2 ** (-l / h_half)
        weighted_sum += w_l * values[l]
        weight_total += w_l
    return weighted_sum / weight_total


def aggregate_noise_metric(values: dict[Any, float]) -> float:
    """
    $\text{WT-Score}=\frac{\sum_{i} w(c_i) M(c_i)}{\sum_{i} w(c_i)}$,
    where $w(\sigma)=\sigma^\gamma$, and $\sigma$ is the noise level related to the standard deviation of the baseline, and $\gamma=2$.
    """
    keys = list(values.keys())
    gamma = 2.0
    weighted_sum = 0.0
    weight_total = 0.0
    for sigma in keys:
        w_sigma = sigma ** gamma
        weighted_sum += w_sigma * values[sigma]
        weight_total += w_sigma
    return weighted_sum / weight_total
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_194575/641893525.py:10: SyntaxWarning: invalid escape sequence '\s'
#   """
# /tmp/ipykernel_194575/641893525.py:27: SyntaxWarning: invalid escape sequence '\s'
#   """

# %%
from typing import Callable
import pandas as pd


def get_metric_along_variable(
        df_res: pd.DataFrame, metric: str, variable_key: str, variable_list: list,
):
    results = {}
    for var_val in variable_list:
        # Filter rows with variable_key=var_val:
        df_filtered = df_res[df_res[variable_key] == var_val]
        if df_filtered.empty:
            print(f'{ISSUE_TAG} No data found for {variable_key}={var_val}.')
            return None
        if len(df_filtered) > 1:
            raise ValueError(f'{ISSUE_TAG} Multiple rows found for {variable_key}={var_val}. Expected only one.')
        results[var_val] = float(df_filtered.iloc[0][metric])
    return results


def get_variable_data_from_df_lstm(
        df_res: pd.DataFrame, metric: str, variable_key: str, variable_list: list, aggregate_fun: Callable
) -> float | None:
    results = get_metric_along_variable(df_res, metric, variable_key=variable_key, variable_list=variable_list)
    if results is None:
        return None
    return aggregate_fun(results)


def get_variable_data_from_df_transformer(
        df_res: pd.DataFrame, metric: str, variable_key: str, variable_list: list, aggregate_fun: Callable
) -> float | None:
    import numpy as np

    positional_encodings = ['learnable', 'sinusoidal', 'rope']
    results = []
    for pe in positional_encodings:
        # Filter rows with positional_encoding=pe:
        df_pe = df_res[df_res['positional_encoding'] == pe]
        if df_pe.empty:
            print(f'{ISSUE_TAG} No data found for positional_encoding={pe}.')
            return None
        pe_results = get_metric_along_variable(df_pe, metric, variable_key=variable_key, variable_list=variable_list)
        if pe_results is None:
            return None
        pe_results = aggregate_fun(pe_results)
        results.append(pe_results)

    # Get the results with the best metric (lowest for RMSE and MAE, highest for NSE):
    if metric.startswith('RMSE') or metric.startswith('MAE'):
        best_idx = np.argmin(results)
        best_result = results[best_idx]
        best_pe = positional_encodings[best_idx]
    elif metric.startswith('NSE'):
        best_idx = np.argmax(results)
        best_result = results[best_idx]
        best_pe = positional_encodings[best_idx]
    # elif any([k in metric for k in ['model_size', 'train_time', 'infer_time']]):
    #     best_row = df_filtered.loc[df_filtered['RMSE_Mean'].idxmin()]  # Choose the one with min RMSE Mean
    else:
        print(f'{ISSUE_TAG} Unknown metric "{metric}".')
        return None, None
    return best_result, best_pe


def gather_variable_data(
        graph_names: list[str], methods: list[str], metric: str, variable_key: str, variable_list: list,
        aggregate_fun: Callable, filename_key: str, dump_dir: Path = DUMP_DIR
) -> (dict, dict):
    data, best_pes = {}, {}
    for graph_name in graph_names:
        data[graph_name] = {}
        best_pes[graph_name] = {}
        for method in methods:
            df_res = read_results_from_csv(dump_dir, graph_name, method, filename_key=filename_key)
            if df_res.empty:
                print(f"{ISSUE_TAG} No data found for graph='{graph_name}', method='{method}'. Skipping...")
                continue
            if is_transformer_model(method):
                result, best_pe = get_variable_data_from_df_transformer(
                    df_res, metric, variable_key, variable_list, aggregate_fun
                )
                best_pes[graph_name][method] = best_pe
            else:
                result = get_variable_data_from_df_lstm(df_res, metric, variable_key, variable_list, aggregate_fun)
            print(f'{SUCCESS_TAG} Gathered {metric}={result} for graph="{graph_name}", method="{method}".')

            data[graph_name][method] = result

    return data, best_pes

# %% [markdown]
# #### Forecasting results:

# %%
FS_DUMP_DIR = (CUR_ABS_DIR / 'outputs/future_steps/').resolve()
filename_key = 'fs_resu'
MAX_HORIZON = 7
variable_key = 'future_step'
variable_list = list(range(1, MAX_HORIZON + 1))
aggregate_fun = aggregate_fs_metric

# %%
metric = 'RMSE_Mean'
rmse_f_data, rmse_f_best_pes = gather_variable_data(
    GRAPH_NAMES, METHODS, metric, variable_key, variable_list, aggregate_fun, filename_key, FS_DUMP_DIR
)
normalized_rmse_f_data = normalize_err_data(rmse_f_data, min_is_better=(not metric.startswith('NSE')))
print(normalized_rmse_f_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1672031122202777 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1651347808691919 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1602396034464544 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.147493220105463 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1654804537490924 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1536262071862513 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1751828227116137 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1847209103253422 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2253516467114964 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2129289567335395 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2112898355573753 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1806695136894174 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2476980506427704 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2165864628999412 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2123327375539577 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2174434457100978 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.291853440375555 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2714703696114675 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2922117290042696 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2430914958318073 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2842401816731408 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2752472270102726 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2653612931569416 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.281765081768944 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 1.1672031122202777, 'transformer': 1.1651347808691919, 'graphlet': 1.1602396034464544, 'transformer_graphlet': 1.147493220105463, 'lstm_embedding': 1.1654804537490924, 'transformer_embedding': 1.1536262071862513, 'stgnn': 1.1751828227116137, 'transformer_stgnn': 1.1847209103253422}, 'swiss-2010': {'lstm': 1.2253516467114964, 'transformer': 1.2129289567335395, 'graphlet': 1.2112898355573753, 'transformer_graphlet': 1.1806695136894174, 'lstm_embedding': 1.2476980506427704, 'transformer_embedding': 1.2165864628999412, 'stgnn': 1.2123327375539577, 'transformer_stgnn': 1.2174434457100978}, 'zurich': {'lstm': 1.291853440375555, 'transformer': 1.2714703696114675, 'graphlet': 1.2922117290042696, 'transformer_graphlet': 1.2430914958318073, 'lstm_embedding': 1.2842401816731408, 'transformer_embedding': 1.2752472270102726, 'stgnn': 1.2653612931569416, 'transformer_stgnn': 1.281765081768944}}

# %%
metric = 'MAE_Mean'
mae_f_data, mae_f_best_pes = gather_variable_data(
    GRAPH_NAMES, METHODS, metric, variable_key, variable_list, aggregate_fun, filename_key, FS_DUMP_DIR
)
normalized_mae_f_data = normalize_err_data(mae_f_data, min_is_better=(not metric.startswith('NSE')))
print(normalized_mae_f_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9086901434526151 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9083182043871101 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9053230124468705 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.8939223394406086 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9115053023002585 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9033050445877776 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9170412322392268 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9201605707711104 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.957074083506115 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9458141980392861 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9466547544986482 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9218408901945533 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9735727538597557 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9523607563404809 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9433832102351719 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9532790362429457 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=1.0106268445650737 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9972451618739537 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=1.0185169764927455 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9746692475818453 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9924479683240256 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9955468949817475 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9836263202485585 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=1.0015729631696428 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.9086901434526151, 'transformer': 0.9083182043871101, 'graphlet': 0.9053230124468705, 'transformer_graphlet': 0.8939223394406086, 'lstm_embedding': 0.9115053023002585, 'transformer_embedding': 0.9033050445877776, 'stgnn': 0.9170412322392268, 'transformer_stgnn': 0.9201605707711104}, 'swiss-2010': {'lstm': 0.957074083506115, 'transformer': 0.9458141980392861, 'graphlet': 0.9466547544986482, 'transformer_graphlet': 0.9218408901945533, 'lstm_embedding': 0.9735727538597557, 'transformer_embedding': 0.9523607563404809, 'stgnn': 0.9433832102351719, 'transformer_stgnn': 0.9532790362429457}, 'zurich': {'lstm': 1.0106268445650737, 'transformer': 0.9972451618739537, 'graphlet': 1.0185169764927455, 'transformer_graphlet': 0.9746692475818453, 'lstm_embedding': 0.9924479683240256, 'transformer_embedding': 0.9955468949817475, 'stgnn': 0.9836263202485585, 'transformer_stgnn': 1.0015729631696428}}

# %%
metric = 'NSE_Mean'
nse_f_data, nse_f_best_pes = gather_variable_data(
    GRAPH_NAMES, METHODS, metric, variable_key, variable_list, aggregate_fun, filename_key, FS_DUMP_DIR
)
normalized_nse_f_data = normalize_err_data(nse_f_data, min_is_better=(not metric.startswith('NSE')))
print(normalized_nse_f_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8927386646368066 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8957724738485959 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8958927569340686 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.898820412098145 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8934925192472887 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8960655255585301 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8911263982252198 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8923833227279234 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9071943800465591 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9095128493514462 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9102792074891175 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9143202567046461 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9048581728859553 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.909097121010562 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9086661472612497 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9094011691692464 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.934041482493991 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9361471681367783 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.933744071778797 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9390051291102456 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9355324149131775 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9361243060656956 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9362872498376029 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9353055562291827 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.8927386646368066, 'transformer': 0.8957724738485959, 'graphlet': 0.8958927569340686, 'transformer_graphlet': 0.898820412098145, 'lstm_embedding': 0.8934925192472887, 'transformer_embedding': 0.8960655255585301, 'stgnn': 0.8911263982252198, 'transformer_stgnn': 0.8923833227279234}, 'swiss-2010': {'lstm': 0.9071943800465591, 'transformer': 0.9095128493514462, 'graphlet': 0.9102792074891175, 'transformer_graphlet': 0.9143202567046461, 'lstm_embedding': 0.9048581728859553, 'transformer_embedding': 0.909097121010562, 'stgnn': 0.9086661472612497, 'transformer_stgnn': 0.9094011691692464}, 'zurich': {'lstm': 0.934041482493991, 'transformer': 0.9361471681367783, 'graphlet': 0.933744071778797, 'transformer_graphlet': 0.9390051291102456, 'lstm_embedding': 0.9355324149131775, 'transformer_embedding': 0.9361243060656956, 'stgnn': 0.9362872498376029, 'transformer_stgnn': 0.9353055562291827}}

# %% [markdown]
# ### Combine all data into a single structure to construct latex table:

# %%
data = [[]]
for graph_name in GRAPH_NAMES:
    data += [
        (f'{graph_name}, Isolated', [
            [],
            [],
        ]),
        (f'{graph_name}, Graphlet', [
            [],
            [],
        ]),
        (f'{graph_name}, Embedded', [
            [],
            [],
        ]),
        (f'{graph_name}, ST-GNN', [
            [],
            [],
        ]),
    ]


def append_data_to_visual(data: list, data_to_add: dict, varlabel_to_add: str) -> list:
    data[0].append(varlabel_to_add)
    n_models = 4
    for idx_g, graph_name in enumerate(GRAPH_NAMES):
        data[1 + n_models * idx_g][1][0].append(data_to_add[graph_name].get('lstm'))
        data[1 + n_models * idx_g][1][1].append(data_to_add[graph_name].get('transformer'))
        data[2 + n_models * idx_g][1][0].append(data_to_add[graph_name].get('graphlet'))
        data[2 + n_models * idx_g][1][1].append(data_to_add[graph_name].get('transformer_graphlet'))
        data[3 + n_models * idx_g][1][0].append(data_to_add[graph_name].get('lstm_embedding'))
        data[3 + n_models * idx_g][1][1].append(data_to_add[graph_name].get('transformer_embedding'))
        data[4 + n_models * idx_g][1][0].append(data_to_add[graph_name].get('stgnn'))
        data[4 + n_models * idx_g][1][1].append(data_to_add[graph_name].get('transformer_stgnn'))
    return data

# %%
# Metrics for nowcasting:
data = append_data_to_visual(data, normalized_err_90_data, 'RMSE/N')
data = append_data_to_visual(data, normalized_mae_data, 'MAE/N')
data = append_data_to_visual(data, normalized_nse_data, 'NSE/N')
# Metrics for forecasting:
data = append_data_to_visual(data, normalized_rmse_f_data, 'RMSE/F')
data = append_data_to_visual(data, normalized_mae_f_data, 'MAE/F')
data = append_data_to_visual(data, normalized_nse_f_data, 'NSE/F')
print(len(data))
print(data)
# Out:
# 13
# [['RMSE/N', 'MAE/N', 'NSE/N', 'RMSE/F', 'MAE/F', 'NSE/F'], ('swiss-1990, Isolated', [[0.7815847992897034, 0.5982856154441833, 0.9544531106948853, 1.1672031122202777, 0.9086901434526151, 0.8927386646368066], [0.7530428171157837, 0.5725784301757812, 0.958686888217926, 1.1651347808691919, 0.9083182043871101, 0.8957724738485959]]), ('swiss-1990, Graphlet', [[0.76872318983078, 0.5905265212059021, 0.9563571214675904, 1.1602396034464544, 0.9053230124468705, 0.8958927569340686], [0.7456002831459045, 0.5636321902275085, 0.9599848985671996, 1.147493220105463, 0.8939223394406086, 0.898820412098145]]), ('swiss-1990, Embedded', [[0.8022345304489136, 0.6194817423820496, 0.9520756006240844, 1.1654804537490924, 0.9115053023002585, 0.8934925192472887], [0.7756783366203308, 0.5890956521034241, 0.9546304941177368, 1.1536262071862513, 0.9033050445877776, 0.8960655255585301]]), ('swiss-1990, ST-GNN', [[0.9422136545181274, 0.720732569694519, 0.9366945028305054, 1.1751828227116137, 0.9170412322392268, 0.8911263982252198], [0.9413735270500184, 0.716244637966156, 0.9361128807067872, 1.1847209103253422, 0.9201605707711104, 0.8923833227279234]]), ('swiss-2010, Isolated', [[0.788673996925354, 0.6094375252723694, 0.9604772329330444, 1.2253516467114964, 0.957074083506115, 0.9071943800465591], [0.772978663444519, 0.5978536605834961, 0.962583601474762, 1.2129289567335395, 0.9458141980392861, 0.9095128493514462]]), ('swiss-2010, Graphlet', [[0.7454374432563782, 0.5732033252716064, 0.9650015234947203, 1.2112898355573753, 0.9466547544986482, 0.9102792074891175], [0.7245303392410278, 0.5589770674705505, 0.9673346877098083, 1.1806695136894174, 0.9218408901945533, 0.9143202567046461]]), ('swiss-2010, Embedded', [[0.7891973257064819, 0.6100487112998962, 0.9609785079956056, 1.2476980506427704, 0.9735727538597557, 0.9048581728859553], [0.779171884059906, 0.6037866473197937, 0.962767779827118, 1.2165864628999412, 0.9523607563404809, 0.909097121010562]]), ('swiss-2010, ST-GNN', [[0.8992083072662354, 0.6839091777801514, 0.9504563212394714, 1.2123327375539577, 0.9433832102351719, 0.9086661472612497], [0.8961308002471924, 0.6842291951179504, 0.9508898854255676, 1.2174434457100978, 0.9532790362429457, 0.9094011691692464]]), ('zurich, Isolated', [[0.7480738162994385, 0.5858083367347717, 0.9786393046379088, 1.291853440375555, 1.0106268445650737, 0.934041482493991], [0.7221101522445679, 0.564784824848175, 0.979767918586731, 1.2714703696114675, 0.9972451618739537, 0.9361471681367783]]), ('zurich, Graphlet', [[0.7110646963119507, 0.5594092011451721, 0.9805818200111388, 1.2922117290042696, 1.0185169764927455, 0.933744071778797], [0.7197110652923584, 0.5611136555671692, 0.9798020124435424, 1.2430914958318073, 0.9746692475818453, 0.9390051291102456]]), ('zurich, Embedded', [[0.7983226180076599, 0.6033580303192139, 0.9765729904174804, 1.2842401816731408, 0.9924479683240256, 0.9355324149131775], [0.6995705366134644, 0.5487588047981262, 0.9806655645370485, 1.2752472270102726, 0.9955468949817475, 0.9361243060656956]]), ('zurich, ST-GNN', [[0.9243724942207336, 0.6844618320465088, 0.9699851870536804, 1.2653612931569416, 0.9836263202485585, 0.9362872498376029], [0.9030463099479676, 0.6691928505897522, 0.971068799495697, 1.281765081768944, 1.0015729631696428, 0.9353055562291827]])]

# %% [markdown]
# ### Compute significant difference using Wilcoxon signed-rank test:

# %%
from scipy.stats import wilcoxon

ARCHITECTURES = ['Isolated', 'Graphlet', 'Embedded', 'ST-GNN']
archs_to_methods_dict = {
    'Isolated': ['lstm', 'transformer'],
    'Graphlet': ['graphlet', 'transformer_graphlet'],
    'Embedded': ['lstm_embedding', 'transformer_embedding'],
    'ST-GNN': ['stgnn', 'transformer_stgnn'],
}
metric_to_best_pe_dict = {
    'nowcasting': {
        'RMSE': rmse_best_pes,
        'MAE': mae_best_pes,
        'NSE': nse_best_pes,
    },
    'forecasting': {
        'RMSE': rmse_f_best_pes,
        'MAE': mae_f_best_pes,
        'NSE': nse_f_best_pes,
    }
}

significant_diff = {'nowcasting': {}, 'forecasting': {}}
for i_graph, graph_name in enumerate(GRAPH_NAMES):
    for casting in ['nowcasting', 'forecasting']:
        significant_diff[casting][graph_name] = {}
        for i_arch, arch in enumerate(ARCHITECTURES):
            significant_diff[casting][graph_name][arch] = {}
            lstm_method = archs_to_methods_dict[arch][0]
            transformer_method = archs_to_methods_dict[arch][1]
            for metric in ['RMSE', 'MAE', 'NSE']:
                # Get LSTM reference station results:
                cur_df_ref = read_results_from_csv(
                    STATIONS_DUMP_DIR, graph_name, lstm_method,
                    filename_key='station_resu_f' if casting == 'forecasting' else 'station_resu'
                )
                cur_ref = cur_df_ref[['Station', metric]]
                cur_best_pe = metric_to_best_pe_dict[casting][metric][graph_name][transformer_method]
                cur_df = read_results_from_csv(
                    STATIONS_DUMP_DIR, graph_name, transformer_method,
                    filename_key=f'{cur_best_pe}_station_resu_f' if casting == 'forecasting' else f'{cur_best_pe}_station_resu'
                )
                # Get columns "Station" and metric:
                cur_evals = cur_df[['Station', metric]]
                # Merge on "Station":
                merged_df = pd.merge(cur_ref, cur_evals, on='Station', suffixes=('_lstm', '_transformer'))
                # Prepare data for Wilcoxon test:
                lstm_values = merged_df[f'{metric}_lstm'].tolist()
                transformer_values = merged_df[f'{metric}_transformer'].tolist()

                if len(lstm_values) < 2:
                    print(
                        f'{ISSUE_TAG} Not enough data to perform Wilcoxon test for graph="{graph_name}", arch="{arch}", '
                        f'metric="{metric}" (nowcasting).'
                    )
                    significant_diff[casting][graph_name][arch][metric] = False
                    continue

                stat, p_value = wilcoxon(lstm_values, transformer_values)
                alpha = 0.05
                is_significant = p_value < alpha
                significant_diff[casting][graph_name][arch][metric] = is_significant
                print(
                    f'{INFO_TAG} Wilcoxon test for graph="{graph_name}", arch="{arch}", metric="{metric}" ({casting}): '
                    f'stat={stat}, p-value={p_value}, significant={is_significant}'
                )
# Out:
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Isolated", metric="RMSE" (nowcasting): stat=51.0, p-value=0.000244140625, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Isolated", metric="MAE" (nowcasting): stat=57.0, p-value=0.0004729032516479492, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Isolated", metric="NSE" (nowcasting): stat=47.0, p-value=0.00015273690223693848, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Graphlet", metric="RMSE" (nowcasting): stat=71.0, p-value=0.0018673688173294067, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Graphlet", metric="MAE" (nowcasting): stat=76.0, p-value=0.002901986241340637, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Graphlet", metric="NSE" (nowcasting): stat=130.0, p-value=0.0992795079946518, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Embedded", metric="RMSE" (nowcasting): stat=130.0, p-value=0.0992795079946518, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Embedded", metric="MAE" (nowcasting): stat=116.0, p-value=0.04774715006351471, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Embedded", metric="NSE" (nowcasting): stat=131.0, p-value=0.10417398810386658, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="ST-GNN", metric="RMSE" (nowcasting): stat=201.0, p-value=0.973184622824192, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="ST-GNN", metric="MAE" (nowcasting): stat=190.0, p-value=0.7792982533574104, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="ST-GNN", metric="NSE" (nowcasting): stat=147.0, p-value=0.20980393886566162, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Isolated", metric="RMSE" (forecasting): stat=202.0, p-value=0.9910601079463959, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Isolated", metric="MAE" (forecasting): stat=196.0, p-value=0.8841757625341415, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Isolated", metric="NSE" (forecasting): stat=198.0, p-value=0.9196710959076881, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Graphlet", metric="RMSE" (forecasting): stat=150.0, p-value=0.23591722548007965, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Graphlet", metric="MAE" (forecasting): stat=168.0, p-value=0.43800119310617447, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Graphlet", metric="NSE" (forecasting): stat=152.0, p-value=0.25451332330703735, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Embedded", metric="RMSE" (forecasting): stat=132.0, p-value=0.10925160348415375, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Embedded", metric="MAE" (forecasting): stat=139.0, p-value=0.15023531019687653, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="Embedded", metric="NSE" (forecasting): stat=131.0, p-value=0.10417398810386658, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="ST-GNN", metric="RMSE" (forecasting): stat=168.0, p-value=0.43800119310617447, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="ST-GNN", metric="MAE" (forecasting): stat=190.0, p-value=0.7792982533574104, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-1990", arch="ST-GNN", metric="NSE" (forecasting): stat=188.0, p-value=0.7450922578573227, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Isolated", metric="RMSE" (nowcasting): stat=675.0, p-value=0.022622361816169386, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Isolated", metric="MAE" (nowcasting): stat=694.0, p-value=0.031580797709022605, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Isolated", metric="NSE" (nowcasting): stat=678.0, p-value=0.023870054421138223, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Graphlet", metric="RMSE" (nowcasting): stat=469.0, p-value=0.00022420988189636372, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Graphlet", metric="MAE" (nowcasting): stat=523.0, p-value=0.0008990127965259485, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Graphlet", metric="NSE" (nowcasting): stat=560.0, p-value=0.0021617933889260276, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Embedded", metric="RMSE" (nowcasting): stat=788.0, p-value=0.1320304932451523, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Embedded", metric="MAE" (nowcasting): stat=867.0, p-value=0.3343942322149971, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Embedded", metric="NSE" (nowcasting): stat=751.0, p-value=0.07850131720600455, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="ST-GNN", metric="RMSE" (nowcasting): stat=931.0, p-value=0.5980894163154888, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="ST-GNN", metric="MAE" (nowcasting): stat=926.0, p-value=0.5745381497469051, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="ST-GNN", metric="NSE" (nowcasting): stat=910.0, p-value=0.5022726402111019, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Isolated", metric="RMSE" (forecasting): stat=692.0, p-value=0.030512817921750843, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Isolated", metric="MAE" (forecasting): stat=686.0, p-value=0.0274930273471684, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Isolated", metric="NSE" (forecasting): stat=675.0, p-value=0.022622361816169386, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Graphlet", metric="RMSE" (forecasting): stat=337.0, p-value=4.353804313833923e-06, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Graphlet", metric="MAE" (forecasting): stat=346.0, p-value=5.83944067488039e-06, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Graphlet", metric="NSE" (forecasting): stat=350.0, p-value=6.645535116039013e-06, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Embedded", metric="RMSE" (forecasting): stat=404.0, p-value=3.5488218788784354e-05, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Embedded", metric="MAE" (forecasting): stat=545.0, p-value=0.0015257214179358188, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="Embedded", metric="NSE" (forecasting): stat=450.0, p-value=0.000133383469964959, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="ST-GNN", metric="RMSE" (forecasting): stat=968.0, p-value=0.7842043824062324, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="ST-GNN", metric="MAE" (forecasting): stat=709.0, p-value=0.0406595449672822, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="swiss-2010", arch="ST-GNN", metric="NSE" (forecasting): stat=913.0, p-value=0.5154468642535983, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Isolated", metric="RMSE" (nowcasting): stat=28.0, p-value=0.072998046875, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Isolated", metric="MAE" (nowcasting): stat=28.0, p-value=0.072998046875, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Isolated", metric="NSE" (nowcasting): stat=34.0, p-value=0.15142822265625, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Graphlet", metric="RMSE" (nowcasting): stat=35.0, p-value=0.1688232421875, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Graphlet", metric="MAE" (nowcasting): stat=48.0, p-value=0.52447509765625, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Graphlet", metric="NSE" (nowcasting): stat=33.0, p-value=0.1353759765625, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Embedded", metric="RMSE" (nowcasting): stat=3.0, p-value=0.00030517578125, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Embedded", metric="MAE" (nowcasting): stat=3.0, p-value=0.00030517578125, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Embedded", metric="NSE" (nowcasting): stat=3.0, p-value=0.00030517578125, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="ST-GNN", metric="RMSE" (nowcasting): stat=19.0, p-value=0.01806640625, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="ST-GNN", metric="MAE" (nowcasting): stat=28.0, p-value=0.072998046875, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="ST-GNN", metric="NSE" (nowcasting): stat=23.0, p-value=0.03533935546875, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Isolated", metric="RMSE" (forecasting): stat=29.0, p-value=0.083251953125, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Isolated", metric="MAE" (forecasting): stat=31.0, p-value=0.10699462890625, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Isolated", metric="NSE" (forecasting): stat=21.0, p-value=0.02557373046875, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Graphlet", metric="RMSE" (forecasting): stat=1.0, p-value=0.0001220703125, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Graphlet", metric="MAE" (forecasting): stat=3.0, p-value=0.00030517578125, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Graphlet", metric="NSE" (forecasting): stat=0.0, p-value=6.103515625e-05, significant=True
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Embedded", metric="RMSE" (forecasting): stat=56.0, p-value=0.846923828125, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Embedded", metric="MAE" (forecasting): stat=53.0, p-value=0.7197265625, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="Embedded", metric="NSE" (forecasting): stat=52.0, p-value=0.67877197265625, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="ST-GNN", metric="RMSE" (forecasting): stat=38.0, p-value=0.22930908203125, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="ST-GNN", metric="MAE" (forecasting): stat=31.0, p-value=0.10699462890625, significant=False
# <span style="color:blue;">[info]</span>  Wilcoxon test for graph="zurich", arch="ST-GNN", metric="NSE" (forecasting): stat=40.0, p-value=0.27685546875, significant=False

# %% [markdown]
# ### Construct LaTeX table:

# %%
GRAPH_NAMES = ['swiss-1990', 'swiss-2010', 'zurich']
# METHODS = ['lstm', 'transformer', 'graphlet', 'transformer_graphlet', 'lstm_embedding', 'transformer_embedding',
#            'stgnn', 'transformer_stgnn']
ARCHITECTURES = ['Isolated', 'Graphlet', 'Embedded', 'ST-GNN']

# %%
import numpy as np


def get_value_str_suffix(change_in_percent: float, larger_is_better: bool = False, threshold: float = 0.05) -> str:
    if np.isnan(change_in_percent):
        return ''
    condition_better = (change_in_percent >= threshold) if larger_is_better else (change_in_percent <= -threshold)
    condition_worse = (change_in_percent <= -threshold) if larger_is_better else (change_in_percent >= threshold)
    if condition_better:
        str_color = 'Green'
        str_arrow = '$\\uparrow$'
    elif condition_worse:
        str_color = 'Red'
        str_arrow = '$\\downarrow$'
    else:
        str_color = 'Blue'
        str_arrow = ''
    return f'\\textcolor{{{str_color}}}{{\\scriptsize{{{abs(change_in_percent):.1f}\\%{str_arrow}}}}}~'


def get_best_performance(data: list) -> float | None:
    idx_best_perf = []
    for i_graph, graph_name in enumerate(GRAPH_NAMES):
        value_lists = []
        for i_model, model_name in enumerate(['LSTM', 'Transformer']):
            for i_arch, arch in enumerate(ARCHITECTURES):
                # RMSE, MAE, NSE for nowcasting and forecasting:
                all_values = np.array(data[1 + 4 * i_graph + i_arch][1][i_model][0:6])
                value_lists.append(all_values)
        value_array = np.array(value_lists)
        # print(f'Graph: {graph_name}')
        # print(value_array)
        max_i_vals = np.argmax(value_array, axis=0)
        min_i_vals = np.argmin(value_array, axis=0)
        best_i_vals = [max_i if i in [2, 5] else min_i for i, (min_i, max_i) in
                       enumerate(zip(min_i_vals, max_i_vals))]
        # print(max_i_vals)
        # print(min_i_vals)
        # print(best_i_vals)
        idx_best_perf.append(best_i_vals)
    return idx_best_perf


def is_best_performance(idx_best_perf: list, i_graph: int, i_model: int, i_arch: int, i_metric: int) -> bool:
    n_archs = len(ARCHITECTURES)
    idx = i_model * n_archs + i_arch
    return idx_best_perf[i_graph][i_metric] == idx


# if __name__ == '__main__':
idx_best_perf = get_best_performance(data)

latex_str = ''
for i_graph, graph_name in enumerate(GRAPH_NAMES):
    latex_str += f'\\bf {graph_name.capitalize()} & '
    for i_model, model_name in enumerate(['LSTM', 'Transformer']):
        if i_model == 1:
            latex_str += ' & '
        latex_str += f'{model_name} & '
        for i_arch, arch in enumerate(ARCHITECTURES):
            if i_model == 0 and i_arch == 0:
                pass
            elif i_model == 1 and i_arch == 0:
                pass
            else:
                latex_str += ' & & '
            latex_str += f'{arch} & '
            all_values = np.array(
                data[1 + 4 * i_graph + i_arch][1][i_model][0:6]
            )  # RMSE, MAE, NSE for nowcasting and forecasting

            # Get the value change:
            if i_model == 1:
                all_values_lstm = np.array(data[1 + 4 * i_graph + i_arch][1][0][0:6])  # LSTM values
                nan_lstm = np.where(all_values_lstm == None, np.nan, all_values_lstm)
                nan_transformer = np.where(all_values == None, np.nan, all_values)
                changes_in_percent = ((nan_transformer - nan_lstm) / nan_lstm) * 100.0

            for i_val, val in enumerate(all_values):
                if val is None:
                    latex_str += '-'
                else:
                    formatted_val = (lambda x: f"{x:.3f}".lstrip("0").replace("-0", "-"))(val)
                    if is_best_performance(idx_best_perf, i_graph, i_model, i_arch, i_val):
                        formatted_val = f'\\textbf{{{formatted_val}}}'
                        formatted_val = f'\\underline{{{formatted_val}}}'
                    larger_is_better = True if i_val in [2, 5] else False  # NSE larger is better
                    latex_str += (get_value_str_suffix(
                        changes_in_percent[i_val], larger_is_better=larger_is_better
                    ) if i_model == 1 else '') + formatted_val

                # Add a star to indicate significant difference:
                if i_model == 1:  # Transformer models only
                    arch_name = ARCHITECTURES[i_arch]
                    if_sig_diff = significant_diff.get(
                        'nowcasting' if i_val < 3 else 'forecasting', {}
                    ).get(graph_name, {}).get(arch_name, {}).get(
                        'RMSE' if i_val % 3 == 0 else 'MAE' if i_val % 3 == 1 else 'NSE', None
                    )
                    if if_sig_diff is None:
                        print(
                            f'{ISSUE_TAG} Missing significance test result for graph="{graph_name}", arch="{arch_name}", '
                            f'metric="{"RMSE" if i_val % 3 == 0 else "MAE" if i_val % 3 == 1 else "NSE"}" '
                            f'({"nowcasting" if i_val < 3 else "forecasting"}).'
                        )
                    elif if_sig_diff:
                        latex_str += '$^{*}$'

                if i_val < len(all_values) - 1:
                    latex_str += ' & '
            if i_arch < len(ARCHITECTURES) - 1:
                latex_str += ' \\\\ \n'

        if i_model < 1:
            latex_str += ' \\\\ \n \\cmidrule(r){2-9} \n'

    if i_graph < len(GRAPH_NAMES) - 1:
        latex_str += ' \\\\ \n\\midrule \n'

latex_str += ' \\\\'

# print(latex_str)  # directly print does not display correctly in Jupyter Notebook
from IPython.display import HTML

HTML(f"<pre>{latex_str}</pre>")
# Out:
# <pre>\bf Swiss-1990 & LSTM & Isolated & .782 & .598 & .954 & 1.167 & .909 & .893 \\
#  & & Graphlet & .769 & .591 & .956 & 1.160 & .905 & .896 \\
#  & & Embedded & .802 & .619 & .952 & 1.165 & .912 & .893 \\
#  & & ST-GNN & .942 & .721 & .937 & 1.175 & .917 & .891 \\
#  \cmidrule(r){2-9}
#  & Transformer & Isolated & \textcolor{Green}{\scriptsize{3.7\%$\uparrow$}}~.753$^{*}$ & \textcolor{Green}{\scriptsize{4.3\%$\uparrow$}}~.573$^{*}$ & \textcolor{Green}{\scriptsize{0.4\%$\uparrow$}}~.959$^{*}$ & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~1.165 & \textcolor{Blue}{\scriptsize{0.0\%}}~.908 & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.896 \\
#  & & Graphlet & \textcolor{Green}{\scriptsize{3.0\%$\uparrow$}}~\underline{\textbf{.746}}$^{*}$ & \textcolor{Green}{\scriptsize{4.6\%$\uparrow$}}~\underline{\textbf{.564}}$^{*}$ & \textcolor{Green}{\scriptsize{0.4\%$\uparrow$}}~\underline{\textbf{.960}} & \textcolor{Green}{\scriptsize{1.1\%$\uparrow$}}~\underline{\textbf{1.147}} & \textcolor{Green}{\scriptsize{1.3\%$\uparrow$}}~\underline{\textbf{.894}} & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~\underline{\textbf{.899}} \\
#  & & Embedded & \textcolor{Green}{\scriptsize{3.3\%$\uparrow$}}~.776 & \textcolor{Green}{\scriptsize{4.9\%$\uparrow$}}~.589$^{*}$ & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.955 & \textcolor{Green}{\scriptsize{1.0\%$\uparrow$}}~1.154 & \textcolor{Green}{\scriptsize{0.9\%$\uparrow$}}~.903 & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.896 \\
#  & & ST-GNN & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.941 & \textcolor{Green}{\scriptsize{0.6\%$\uparrow$}}~.716 & \textcolor{Red}{\scriptsize{0.1\%$\downarrow$}}~.936 & \textcolor{Red}{\scriptsize{0.8\%$\downarrow$}}~1.185 & \textcolor{Red}{\scriptsize{0.3\%$\downarrow$}}~.920 & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.892 \\
# \midrule
# \bf Swiss-2010 & LSTM & Isolated & .789 & .609 & .960 & 1.225 & .957 & .907 \\
#  & & Graphlet & .745 & .573 & .965 & 1.211 & .947 & .910 \\
#  & & Embedded & .789 & .610 & .961 & 1.248 & .974 & .905 \\
#  & & ST-GNN & .899 & .684 & .950 & 1.212 & .943 & .909 \\
#  \cmidrule(r){2-9}
#  & Transformer & Isolated & \textcolor{Green}{\scriptsize{2.0\%$\uparrow$}}~.773$^{*}$ & \textcolor{Green}{\scriptsize{1.9\%$\uparrow$}}~.598$^{*}$ & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~.963$^{*}$ & \textcolor{Green}{\scriptsize{1.0\%$\uparrow$}}~1.213$^{*}$ & \textcolor{Green}{\scriptsize{1.2\%$\uparrow$}}~.946$^{*}$ & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.910$^{*}$ \\
#  & & Graphlet & \textcolor{Green}{\scriptsize{2.8\%$\uparrow$}}~\underline{\textbf{.725}}$^{*}$ & \textcolor{Green}{\scriptsize{2.5\%$\uparrow$}}~\underline{\textbf{.559}}$^{*}$ & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~\underline{\textbf{.967}}$^{*}$ & \textcolor{Green}{\scriptsize{2.5\%$\uparrow$}}~\underline{\textbf{1.181}}$^{*}$ & \textcolor{Green}{\scriptsize{2.6\%$\uparrow$}}~\underline{\textbf{.922}}$^{*}$ & \textcolor{Green}{\scriptsize{0.4\%$\uparrow$}}~\underline{\textbf{.914}}$^{*}$ \\
#  & & Embedded & \textcolor{Green}{\scriptsize{1.3\%$\uparrow$}}~.779 & \textcolor{Green}{\scriptsize{1.0\%$\uparrow$}}~.604 & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~.963 & \textcolor{Green}{\scriptsize{2.5\%$\uparrow$}}~1.217$^{*}$ & \textcolor{Green}{\scriptsize{2.2\%$\uparrow$}}~.952$^{*}$ & \textcolor{Green}{\scriptsize{0.5\%$\uparrow$}}~.909$^{*}$ \\
#  & & ST-GNN & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.896 & \textcolor{Blue}{\scriptsize{0.0\%}}~.684 & \textcolor{Blue}{\scriptsize{0.0\%}}~.951 & \textcolor{Red}{\scriptsize{0.4\%$\downarrow$}}~1.217 & \textcolor{Red}{\scriptsize{1.0\%$\downarrow$}}~.953$^{*}$ & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.909 \\
# \midrule
# \bf Zurich & LSTM & Isolated & .748 & .586 & .979 & 1.292 & 1.011 & .934 \\
#  & & Graphlet & .711 & .559 & .981 & 1.292 & 1.019 & .934 \\
#  & & Embedded & .798 & .603 & .977 & 1.284 & .992 & .936 \\
#  & & ST-GNN & .924 & .684 & .970 & 1.265 & .984 & .936 \\
#  \cmidrule(r){2-9}
#  & Transformer & Isolated & \textcolor{Green}{\scriptsize{3.5\%$\uparrow$}}~.722 & \textcolor{Green}{\scriptsize{3.6\%$\uparrow$}}~.565 & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.980 & \textcolor{Green}{\scriptsize{1.6\%$\uparrow$}}~1.271 & \textcolor{Green}{\scriptsize{1.3\%$\uparrow$}}~.997 & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~.936$^{*}$ \\
#  & & Graphlet & \textcolor{Red}{\scriptsize{1.2\%$\downarrow$}}~.720 & \textcolor{Red}{\scriptsize{0.3\%$\downarrow$}}~.561 & \textcolor{Red}{\scriptsize{0.1\%$\downarrow$}}~.980 & \textcolor{Green}{\scriptsize{3.8\%$\uparrow$}}~\underline{\textbf{1.243}}$^{*}$ & \textcolor{Green}{\scriptsize{4.3\%$\uparrow$}}~\underline{\textbf{.975}}$^{*}$ & \textcolor{Green}{\scriptsize{0.6\%$\uparrow$}}~\underline{\textbf{.939}}$^{*}$ \\
#  & & Embedded & \textcolor{Green}{\scriptsize{12.4\%$\uparrow$}}~\underline{\textbf{.700}}$^{*}$ & \textcolor{Green}{\scriptsize{9.0\%$\uparrow$}}~\underline{\textbf{.549}}$^{*}$ & \textcolor{Green}{\scriptsize{0.4\%$\uparrow$}}~\underline{\textbf{.981}}$^{*}$ & \textcolor{Green}{\scriptsize{0.7\%$\uparrow$}}~1.275 & \textcolor{Red}{\scriptsize{0.3\%$\downarrow$}}~.996 & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.936 \\
#  & & ST-GNN & \textcolor{Green}{\scriptsize{2.3\%$\uparrow$}}~.903$^{*}$ & \textcolor{Green}{\scriptsize{2.2\%$\uparrow$}}~.669 & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.971$^{*}$ & \textcolor{Red}{\scriptsize{1.3\%$\downarrow$}}~1.282 & \textcolor{Red}{\scriptsize{1.8\%$\downarrow$}}~1.002 & \textcolor{Red}{\scriptsize{0.1\%$\downarrow$}}~.935 \\</pre>
