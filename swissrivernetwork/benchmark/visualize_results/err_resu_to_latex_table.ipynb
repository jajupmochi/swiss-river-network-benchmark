# %% [markdown]
# # Process data

# %% [markdown]
# ## Process error-based metrics (MAE, RMSE, NSE) with window lengths 90
# (together with model size and runtime)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

CUR_ABS_DIR = Path.cwd().resolve()
PROJ_DIR = (CUR_ABS_DIR / '../../../').resolve()
OUTPUT_DIR = (PROJ_DIR / 'swissrivernetwork/benchmark/outputs/ray_results/').resolve()
DUMP_DIR = (CUR_ABS_DIR / 'outputs/radar/').resolve()

LOAD_LATEST_RESULTS = True

ISSUE_TAG = '<span style="color:red;">[issue]</span> '
INFO_TAG = '<span style="color:blue;">[info]</span> '
SUCCESS_TAG = '<span style="color:green;">[success]</span> '


def print(text=None):
    from IPython.display import display, HTML
    if text is None:
        display(HTML("<br>"))
        return
    text = str(text)
    display(HTML(text))


print(f'{INFO_TAG} Project directory: {PROJ_DIR}')
print(f'{INFO_TAG} Current directory: {CUR_ABS_DIR}')
print(f'{INFO_TAG} Output directory: {OUTPUT_DIR}')
print(f'{INFO_TAG} Dump directory: {DUMP_DIR}')
# Out:
# <span style="color:blue;">[info]</span>  Project directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark
# <span style="color:blue;">[info]</span>  Current directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/visualize_results
# <span style="color:blue;">[info]</span>  Output directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/outputs/ray_results
# <span style="color:blue;">[info]</span>  Dump directory: /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/visualize_results/outputs/radar

# %%
# Get Err 90 data, Model Size data, Runtime data

import pandas as pd
import os
import json


def read_results_from_csv(
        output_dir: Path, graph_name: str, method: str, filename_key: str = 'results', verbose: bool = False
) -> pd.DataFrame:
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_{filename_key}.csv')
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        if verbose:
            print(f"{SUCCESS_TAG} Loaded results from {file_path}.")
        return df
    else:
        if verbose:
            print(f"{INFO_TAG} No results found at {file_path}.")
        return pd.DataFrame()


def save_results_to_csv(
        df: pd.DataFrame, output_dir: Path, graph_name: str, method: str, filename_key: str = 'results',
        verbose: bool = True
) -> str:
    output_dir.mkdir(parents=True, exist_ok=True)
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_{filename_key}.csv')
    df.to_csv(file_path, index=False)
    if verbose:
        print(f"{SUCCESS_TAG} Saved results to {file_path}.")
    return file_path


def read_results_from_json(
        output_dir: Path, graph_name: str, method: str, filename_key: str = 'results', verbose: bool = False
) -> dict:
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_{filename_key}.json')
    if os.path.exists(file_path):
        with open(file_path, 'r') as f:
            data = json.load(f)
        if verbose:
            print(f"{SUCCESS_TAG} Loaded extra results from {file_path}.")
        return data
    else:
        if verbose:
            print(f"{INFO_TAG} No extra results found at {file_path}.")
        return {}


def save_results_to_json(
        data: dict, output_dir: Path, graph_name: str, method: str, filename_key: str = 'results',
        verbose: bool = True
) -> str:
    output_dir.mkdir(parents=True, exist_ok=True)
    file_path = os.path.join(output_dir, f'{graph_name}_{method}_{filename_key}.json')
    with open(file_path, 'w') as f:
        json.dump(data, f, indent=4)
    if verbose:
        print(f"{SUCCESS_TAG} Saved results to {file_path}.")
    return file_path

# %%
from swissrivernetwork.benchmark.ray_evaluation import process_method
from swissrivernetwork.benchmark.util import get_run_extra_key, is_transformer_model
from typing import Union


def infer_single_run(graph_name: str, method: str, df_res: pd.DataFrame, settings: dict) -> (pd.DataFrame, dict):
    import numpy as np

    max_days = 500 if method == 'transformer_embedding' else np.inf
    # window_len = 90  # curate_window_lens(WINDOW_LENS, graph_name, mode='subsequences', max_days=max_days)
    # print(f'{INFO_TAG} Curated window lengths for graph="{graph_name}", method="{m}": {window_lens}')

    settings['path_extra_keys'] = get_run_extra_key(settings)

    df_data, extra_resu = process_method(
        graph_name, method, output_dir=OUTPUT_DIR, settings=settings, return_extra=True
    )
    new_row = {'window_len': settings['window_len']}
    for metric in ['RMSE', 'MAE', 'NSE']:
        for stat_measure in ['Mean', 'Std', 'Median', 'Min', 'Max']:
            col_name = f'{metric}_{stat_measure}'
            if metric in df_data.columns:
                value = df_data[df_data['Station'] == stat_measure][metric]
                if not value.empty:
                    new_row[col_name] = value.values[0]
                else:
                    new_row[col_name] = np.nan
            else:
                new_row[col_name] = np.nan
    # Add extra results:
    extra_resu_keys = [k for k in df_data.keys().to_list() if k.startswith('extra__')]
    for extra_key in extra_resu_keys:
        new_row[f'{extra_key}_Mean'] = df_data[df_data['Station'] == 'Mean'][extra_key].values[0]
    for key in extra_resu.keys():
        if f'extra__{key}' not in new_row:
            new_row[f'extra__{key}'] = extra_resu[key]

    df_res = pd.concat([df_res, pd.DataFrame([new_row])], ignore_index=True)
    return df_res, extra_resu


def infer_lstm(
        graph_name: str, method: str, df_res: pd.DataFrame, settings: dict
) -> Union[pd.DataFrame, str] | None:
    window_len = settings['window_len']
    if not df_res.empty and window_len in df_res['window_len'].values:
        print(f"{SUCCESS_TAG} Results for window_len={window_len} already exist. Skipping...")
        return None, None

    settings.update(
        {
            'positional_encoding': 'none',
        }
    )

    df_res, extra_resu = infer_single_run(graph_name, method, df_res, settings)
    file_path = save_results_to_csv(df_res, DUMP_DIR, graph_name, method, filename_key='err_90', verbose=True)
    # file_path_extra = save_results_to_json(
    #     extra_resu, DUMP_DIR, graph_name, method, filename_key='extra_resu', verbose=True
    # )
    return df_res, file_path


def infer_transformer(
        graph_name: str, method: str, df_res: pd.DataFrame, settings: dict
) -> Union[pd.DataFrame, str] | None:
    window_len = settings['window_len']
    position_encodings = ['learnable', 'sinusoidal', 'rope']  # [None, 'learnable', 'sinusoidal', 'rope']
    updated = False
    for pe in position_encodings:
        print(f'{INFO_TAG} --- Processing positional_encoding={pe} ---')
        if not df_res.empty and window_len in df_res['window_len'].values and pe in df_res[
            'positional_encoding'].values:
            print(
                f'{SUCCESS_TAG} Results for window_len={window_len}, positional_encoding={pe} already exist. Skipping...'
            )
            continue

        settings.update(
            {
                'max_len': 500,
                'positional_encoding': pe,  # 'learnable' or 'sinusoidal' or 'rope' or None
            }
        )

        df_res, extra_resu = infer_single_run(graph_name, method, df_res, settings)  # Already concatenated
        if 'positional_encoding' in df_res.columns:
            df_res.loc[df_res.index[-1], 'positional_encoding'] = pe
        else:
            df_res.insert(loc=1, column='positional_encoding', value=pe)

        file_path = save_results_to_csv(df_res, DUMP_DIR, graph_name, method, filename_key='err_90', verbose=True)

        updated = True

    if not updated:
        return None, None

    return df_res, file_path


def infer_graph(graph_name: str, methods: list[str], window_len: int = 90):
    for m in methods:
        print()
        print(f'{INFO_TAG} #### Starting processing for method="{m}" on graph="{graph_name}"...')

        df_res = read_results_from_csv(DUMP_DIR, graph_name, m, filename_key='err_90')
        # extra_resu = read_results_from_json(DUMP_DIR, graph_name, m, filename_key='extra_resu')
        # print(f"{INFO_TAG} ==== Processing window_len={window_len} [{i_len + 1}/{len(window_lens)}] ====")

        settings = {
            'missing_value_method': None,  # 'mask_embedding' or 'interpolation' or 'zero' or None
            'use_current_x': True,
            'window_len': 90,
            'verbose': 1,
            'env': 'notebook',
        }

        if is_transformer_model(m):
            df_res, file_path = infer_transformer(graph_name, m, df_res, settings)
        else:
            df_res, file_path = infer_lstm(graph_name, m, df_res, settings)
        if df_res is None:
            continue

        print(f'{SUCCESS_TAG} Completed processing for window_len={window_len}. Results saved to {file_path}. ')

        print(f'{SUCCESS_TAG} #### Finished processing for method="{m}" on graph="{graph_name}"!')

# %%
GRAPH_NAMES = ['swiss-1990', 'swiss-2010', 'zurich']
METHODS = ['lstm', 'transformer', 'graphlet', 'transformer_graphlet', 'lstm_embedding', 'transformer_embedding',
           'stgnn', 'transformer_stgnn']

# %%
# Compute results and save to CSV:
for graph_name in GRAPH_NAMES[0:]:
    print(f'{INFO_TAG} ================= Starting processing for graph="{graph_name}" =================')
    infer_graph(graph_name, METHODS[0:4], window_len=90)  # test [2:3]
# Out:
# <span style="color:blue;">[info]</span>  ================= Starting processing for graph="swiss-1990" =================
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="lstm" on graph="swiss-1990"...
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer" on graph="swiss-1990"...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=learnable ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=learnable already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=sinusoidal ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=sinusoidal already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=rope ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=rope already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="graphlet" on graph="swiss-1990"...
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer_graphlet" on graph="swiss-1990"...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=learnable ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=learnable already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=sinusoidal ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=sinusoidal already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=rope ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=rope already exist. Skipping...
# <span style="color:blue;">[info]</span>  ================= Starting processing for graph="swiss-2010" =================
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="lstm" on graph="swiss-2010"...
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer" on graph="swiss-2010"...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=learnable ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=learnable already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=sinusoidal ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=sinusoidal already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=rope ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=rope already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="graphlet" on graph="swiss-2010"...
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer_graphlet" on graph="swiss-2010"...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=learnable ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=learnable already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=sinusoidal ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=sinusoidal already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=rope ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=rope already exist. Skipping...
# <span style="color:blue;">[info]</span>  ================= Starting processing for graph="zurich" =================
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="lstm" on graph="zurich"...
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer" on graph="zurich"...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=learnable ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=learnable already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=sinusoidal ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=sinusoidal already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=rope ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=rope already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="graphlet" on graph="zurich"...
# <span style="color:green;">[success]</span>  Results for window_len=90 already exist. Skipping...
# <br>
# <span style="color:blue;">[info]</span>  #### Starting processing for method="transformer_graphlet" on graph="zurich"...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=learnable ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=learnable already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=sinusoidal ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=sinusoidal already exist. Skipping...
# <span style="color:blue;">[info]</span>  --- Processing positional_encoding=rope ---
# <span style="color:green;">[success]</span>  Results for window_len=90, positional_encoding=rope already exist. Skipping...

# %% [markdown]
# # Plot radar charts

# %% [markdown]
# ## Gather data

# %% [markdown]
# ### Gather Err 90 data, Model Size data, Runtime data

# %%
GRAPH_NAMES = ['swiss-1990', 'swiss-2010', 'zurich']
METHODS = ['lstm', 'transformer', 'graphlet', 'transformer_graphlet', 'lstm_embedding', 'transformer_embedding',
           'stgnn', 'transformer_stgnn']

# %%
import pandas as pd


def get_err_from_df_lstm(df_res: pd.DataFrame, metric: str, window_len: int = 90) -> float | None:
    # Filter rows with window_len=window_len
    df_filtered = df_res[df_res['window_len'] == window_len]
    if df_filtered.empty:
        print(f'{ISSUE_TAG} No data found for window_len={window_len}.')
        return None
    if len(df_filtered) > 1:
        raise ValueError(f'{ISSUE_TAG} Multiple rows found for window_len={window_len}. Expected only one.')
    return float(df_filtered.iloc[0][metric])


def get_err_from_df_transformer(df_res: pd.DataFrame, metric: str, window_len: int = 90) -> float | None:
    # Filter rows with window_len=window_len
    df_filtered = df_res[df_res['window_len'] == window_len]
    if df_filtered.empty:
        print(f'{ISSUE_TAG} No data found for window_len={window_len}.')
        return None
    # Get the row with the best metric (lowest for RMSE and MAE, highest for NSE):
    if metric.startswith('RMSE') or metric.startswith('MAE'):
        best_row = df_filtered.loc[df_filtered[metric].idxmin()]
    elif metric.startswith('NSE'):
        best_row = df_filtered.loc[df_filtered[metric].idxmax()]
    elif any([k in metric for k in ['model_size', 'train_time', 'infer_time']]):
        best_row = df_filtered.loc[df_filtered['RMSE_Mean'].idxmin()]  # Choose the one with min RMSE Mean
    else:
        print(f'{ISSUE_TAG} Unknown metric "{metric}".')
        return None
    return float(best_row[metric])


def gather_err_data(
        graph_names: list[str], methods: list[str], metric: str = 'RMSE_Mean', window_len: int = 90
) -> dict:
    data = {}
    for graph_name in graph_names:
        data[graph_name] = {}
        for method in methods:
            df_res = read_results_from_csv(DUMP_DIR, graph_name, method, filename_key='err_90')
            if df_res.empty:
                print(f"{ISSUE_TAG} No data found for graph='{graph_name}', method='{method}'. Skipping...")
                continue
            if is_transformer_model(method):
                result = get_err_from_df_transformer(df_res, metric, window_len=window_len)
            else:
                result = get_err_from_df_lstm(df_res, metric, window_len=window_len)
            print(f'{SUCCESS_TAG} Gathered {metric}={result} for graph="{graph_name}", method="{method}".')

            data[graph_name][method] = result

    return data


def normalize_err_data(
        err_data: dict, min_is_better: bool = True, global_min: float | None = None, global_max: float | None = None,
) -> dict:
    """
    Normalize error data to [0, 1] range across all graphs and methods. Higher values are better.
    """
    # Find global min and max
    return err_data
    all_values = []
    for graph_name in err_data:
        for method in err_data[graph_name]:
            value = err_data[graph_name][method]
            if value is not None:
                all_values.append(value)
    global_min = min(all_values) if global_min is None else global_min
    global_max = max(all_values) if global_max is None else global_max

    # Normalize data
    normalized_data = {}
    for graph_name in err_data:
        normalized_data[graph_name] = {}
        for method in err_data[graph_name]:
            value = err_data[graph_name][method]
            if value is None:
                normalized_value = None
            else:
                if min_is_better:
                    normalized_value = (global_max - value) / (global_max - global_min)  # Higher is better
                else:
                    normalized_value = (value - global_min) / (global_max - global_min)  # Higher is better
            normalized_data[graph_name][method] = normalized_value

    return normalized_data

# %%
metric = 'RMSE_Mean'
err_90_data = gather_err_data(GRAPH_NAMES, METHODS, metric, window_len=90)
normalized_err_90_data = normalize_err_data(err_90_data, min_is_better=(not metric.startswith('NSE')))
print(normalized_err_90_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7815848 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7530428 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7687232 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7456003 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.80223453 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.77567834 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.792337 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.9413735270500184 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.788674 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.77297866 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.74543744 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.72453034 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7891973 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7791719 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.8992083 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.8961308 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7480738 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.72211015 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7110647 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.71971107 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.7983226 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.69957054 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.718054 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=0.6979277 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.7815848, 'transformer': 0.7530428, 'graphlet': 0.7687232, 'transformer_graphlet': 0.7456003, 'lstm_embedding': 0.80223453, 'transformer_embedding': 0.77567834, 'stgnn': 0.792337, 'transformer_stgnn': 0.9413735270500184}, 'swiss-2010': {'lstm': 0.788674, 'transformer': 0.77297866, 'graphlet': 0.74543744, 'transformer_graphlet': 0.72453034, 'lstm_embedding': 0.7891973, 'transformer_embedding': 0.7791719, 'stgnn': 0.8992083, 'transformer_stgnn': 0.8961308}, 'zurich': {'lstm': 0.7480738, 'transformer': 0.72211015, 'graphlet': 0.7110647, 'transformer_graphlet': 0.71971107, 'lstm_embedding': 0.7983226, 'transformer_embedding': 0.69957054, 'stgnn': 0.718054, 'transformer_stgnn': 0.6979277}}

# %%
metric = 'MAE_Mean'
mae_data = gather_err_data(GRAPH_NAMES, METHODS, metric, window_len=90)
normalized_mae_data = normalize_err_data(mae_data, min_is_better=True)
print(normalized_mae_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5982856 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.57257843 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5905265 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5636322 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.61948174 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.58909565 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.613928 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.716244637966156 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6094375 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.59785366 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5732033 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.55897707 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6100487 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.60378665 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6839092 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.6842292 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.58580834 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5647848 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5594092 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.56111366 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.60335803 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5487588 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.55986583 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.5465388 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.5982856, 'transformer': 0.57257843, 'graphlet': 0.5905265, 'transformer_graphlet': 0.5636322, 'lstm_embedding': 0.61948174, 'transformer_embedding': 0.58909565, 'stgnn': 0.613928, 'transformer_stgnn': 0.716244637966156}, 'swiss-2010': {'lstm': 0.6094375, 'transformer': 0.59785366, 'graphlet': 0.5732033, 'transformer_graphlet': 0.55897707, 'lstm_embedding': 0.6100487, 'transformer_embedding': 0.60378665, 'stgnn': 0.6839092, 'transformer_stgnn': 0.6842292}, 'zurich': {'lstm': 0.58580834, 'transformer': 0.5647848, 'graphlet': 0.5594092, 'transformer_graphlet': 0.56111366, 'lstm_embedding': 0.60335803, 'transformer_embedding': 0.5487588, 'stgnn': 0.55986583, 'transformer_stgnn': 0.5465388}}

# %%
metric = 'NSE_Mean'
nse_data = gather_err_data(GRAPH_NAMES, METHODS, metric, window_len=90)
normalized_nse_data = nse_data  # normalize_err_data(nse_data, min_is_better=False, global_min=0.0, global_max=1.0)
print(normalized_nse_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9544531 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9586869 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9563571 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9599849 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9520756 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9546305 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9531913 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9361129 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.96047723 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9625836 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9650015 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9673347 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9609785 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9627678 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9504563 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9508898 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9786393 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9797679 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9805818 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.979802 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.976573 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.98066556 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.98039687 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9808315 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.9544531, 'transformer': 0.9586869, 'graphlet': 0.9563571, 'transformer_graphlet': 0.9599849, 'lstm_embedding': 0.9520756, 'transformer_embedding': 0.9546305, 'stgnn': 0.9531913, 'transformer_stgnn': 0.9361129}, 'swiss-2010': {'lstm': 0.96047723, 'transformer': 0.9625836, 'graphlet': 0.9650015, 'transformer_graphlet': 0.9673347, 'lstm_embedding': 0.9609785, 'transformer_embedding': 0.9627678, 'stgnn': 0.9504563, 'transformer_stgnn': 0.9508898}, 'zurich': {'lstm': 0.9786393, 'transformer': 0.9797679, 'graphlet': 0.9805818, 'transformer_graphlet': 0.979802, 'lstm_embedding': 0.976573, 'transformer_embedding': 0.98066556, 'stgnn': 0.98039687, 'transformer_stgnn': 0.9808315}}

# %% [markdown]
# ### Gather forecasting results (RMSE, MAE, NSE), window length results, and noise robustness results:
# **Forecasting results are loaded from files saved by running `future_steps_resu.ipynb` in the same directory.**
#
# **Window length results are loaded from files saved by running `window_length_resu.ipynb` in the same directory.**
#
# **Noise robustness results are loaded from files saved by running `noise_robustness_resu.ipynb` in the same directory.**

# %%
from typing import Any


def aggregate_fs_metric(values: dict[Any, float]) -> float:
    values = list(values.values())
    return sum(values) / len(values)


def aggregate_win_len_metric(values: dict[Any, float]) -> float:
    """
    $\text{WT-Score}=\frac{\sum_{i} w(c_i) M(c_i)}{\sum_{i} w(c_i)}$,
    where $w(l)=2^{-l/h_{1/2}}$.
    """
    keys = list(values.keys())
    max_len = max(keys)
    h_half = max_len // 2
    weighted_sum = 0.0
    weight_total = 0.0
    for l in keys:
        w_l = 2 ** (-l / h_half)
        weighted_sum += w_l * values[l]
        weight_total += w_l
    return weighted_sum / weight_total


def aggregate_noise_metric(values: dict[Any, float]) -> float:
    """
    $\text{WT-Score}=\frac{\sum_{i} w(c_i) M(c_i)}{\sum_{i} w(c_i)}$,
    where $w(\sigma)=\sigma^\gamma$, and $\sigma$ is the noise level related to the standard deviation of the baseline, and $\gamma=2$.
    """
    keys = list(values.keys())
    gamma = 2.0
    weighted_sum = 0.0
    weight_total = 0.0
    for sigma in keys:
        w_sigma = sigma ** gamma
        weighted_sum += w_sigma * values[sigma]
        weight_total += w_sigma
    return weighted_sum / weight_total
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:27: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_17649/2951228072.py:10: SyntaxWarning: invalid escape sequence '\s'
#   """
# /tmp/ipykernel_17649/2951228072.py:27: SyntaxWarning: invalid escape sequence '\s'
#   """

# %%
from typing import Callable
import pandas as pd


def get_metric_along_variable(
        df_res: pd.DataFrame, metric: str, variable_key: str, variable_list: list,
):
    results = {}
    for var_val in variable_list:
        # Filter rows with variable_key=var_val:
        df_filtered = df_res[df_res[variable_key] == var_val]
        if df_filtered.empty:
            print(f'{ISSUE_TAG} No data found for {variable_key}={var_val}.')
            return None
        if len(df_filtered) > 1:
            raise ValueError(f'{ISSUE_TAG} Multiple rows found for {variable_key}={var_val}. Expected only one.')
        results[var_val] = float(df_filtered.iloc[0][metric])
    return results


def get_variable_data_from_df_lstm(
        df_res: pd.DataFrame, metric: str, variable_key: str, variable_list: list, aggregate_fun: Callable
) -> float | None:
    results = get_metric_along_variable(df_res, metric, variable_key=variable_key, variable_list=variable_list)
    if results is None:
        return None
    return aggregate_fun(results)


def get_variable_data_from_df_transformer(
        df_res: pd.DataFrame, metric: str, variable_key: str, variable_list: list, aggregate_fun: Callable
) -> float | None:
    positional_encodings = ['learnable', 'sinusoidal', 'rope']
    results = []
    for pe in positional_encodings:
        # Filter rows with positional_encoding=pe:
        df_pe = df_res[df_res['positional_encoding'] == pe]
        if df_pe.empty:
            print(f'{ISSUE_TAG} No data found for positional_encoding={pe}.')
            return None
        pe_results = get_metric_along_variable(df_pe, metric, variable_key=variable_key, variable_list=variable_list)
        if pe_results is None:
            return None
        pe_results = aggregate_fun(pe_results)
        results.append(pe_results)

    # Get the results with the best metric (lowest for RMSE and MAE, highest for NSE):
    if metric.startswith('RMSE') or metric.startswith('MAE'):
        best_result = min(results)
    elif metric.startswith('NSE'):
        best_result = max(results)
    # elif any([k in metric for k in ['model_size', 'train_time', 'infer_time']]):
    #     best_row = df_filtered.loc[df_filtered['RMSE_Mean'].idxmin()]  # Choose the one with min RMSE Mean
    else:
        print(f'{ISSUE_TAG} Unknown metric "{metric}".')
        return None
    return best_result


def gather_variable_data(
        graph_names: list[str], methods: list[str], metric: str, variable_key: str, variable_list: list,
        aggregate_fun: Callable, filename_key: str, dump_dir: Path = DUMP_DIR
) -> dict:
    data = {}
    for graph_name in graph_names:
        data[graph_name] = {}
        for method in methods:
            df_res = read_results_from_csv(dump_dir, graph_name, method, filename_key=filename_key)
            if df_res.empty:
                print(f"{ISSUE_TAG} No data found for graph='{graph_name}', method='{method}'. Skipping...")
                continue
            if is_transformer_model(method):
                result = get_variable_data_from_df_transformer(
                    df_res, metric, variable_key, variable_list, aggregate_fun
                )
            else:
                result = get_variable_data_from_df_lstm(df_res, metric, variable_key, variable_list, aggregate_fun)
            print(f'{SUCCESS_TAG} Gathered {metric}={result} for graph="{graph_name}", method="{method}".')

            data[graph_name][method] = result

    return data

# %% [markdown]
# #### Forecasting results:

# %%
FS_DUMP_DIR = (CUR_ABS_DIR / 'outputs/future_steps/').resolve()
filename_key = 'fs_resu'
MAX_HORIZON = 7
variable_key = 'future_step'
variable_list = list(range(1, MAX_HORIZON + 1))
aggregate_fun = aggregate_fs_metric

# %%
metric = 'RMSE_Mean'
rmse_f_data = gather_variable_data(
    GRAPH_NAMES, METHODS, metric, variable_key, variable_list, aggregate_fun, filename_key, FS_DUMP_DIR
)
normalized_rmse_f_data = normalize_err_data(rmse_f_data, min_is_better=(not metric.startswith('NSE')))
print(normalized_rmse_f_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1672030928571429 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.16513479 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1602396285714285 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1474932228571428 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.165480462857143 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1536261857142858 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1751828142857141 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1847208653177534 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2253516342857143 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2129290085714286 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2112898714285714 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.1806695042857143 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2476980857142856 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2165865214285714 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.212332837142857 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2174435214285713 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.291853457142857 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2714704000000001 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2922117 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2430915 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2842401928571427 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2752472771428571 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.2653613000000001 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered RMSE_Mean=1.281765042857143 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 1.1672030928571429, 'transformer': 1.16513479, 'graphlet': 1.1602396285714285, 'transformer_graphlet': 1.1474932228571428, 'lstm_embedding': 1.165480462857143, 'transformer_embedding': 1.1536261857142858, 'stgnn': 1.1751828142857141, 'transformer_stgnn': 1.1847208653177534}, 'swiss-2010': {'lstm': 1.2253516342857143, 'transformer': 1.2129290085714286, 'graphlet': 1.2112898714285714, 'transformer_graphlet': 1.1806695042857143, 'lstm_embedding': 1.2476980857142856, 'transformer_embedding': 1.2165865214285714, 'stgnn': 1.212332837142857, 'transformer_stgnn': 1.2174435214285713}, 'zurich': {'lstm': 1.291853457142857, 'transformer': 1.2714704000000001, 'graphlet': 1.2922117, 'transformer_graphlet': 1.2430915, 'lstm_embedding': 1.2842401928571427, 'transformer_embedding': 1.2752472771428571, 'stgnn': 1.2653613000000001, 'transformer_stgnn': 1.281765042857143}}

# %%
metric = 'MAE_Mean'
mae_f_data = gather_variable_data(
    GRAPH_NAMES, METHODS, metric, variable_key, variable_list, aggregate_fun, filename_key, FS_DUMP_DIR
)
normalized_mae_f_data = normalize_err_data(mae_f_data, min_is_better=(not metric.startswith('NSE')))
print(normalized_mae_f_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9086901742857142 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9083182057142858 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9053229857142858 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.8939223199999999 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9115052928571429 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9033050128571428 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.91704123 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9201605660574776 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.95707409 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9458142 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9466547114285715 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9218409200000001 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9735727071428572 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9523607414285714 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9433832114285714 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9532790242857142 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=1.010626867142857 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9972451714285714 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=1.018516977142857 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9746692428571428 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9924479285714286 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9955469142857142 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=0.9836263242857142 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered MAE_Mean=1.0015729671428573 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.9086901742857142, 'transformer': 0.9083182057142858, 'graphlet': 0.9053229857142858, 'transformer_graphlet': 0.8939223199999999, 'lstm_embedding': 0.9115052928571429, 'transformer_embedding': 0.9033050128571428, 'stgnn': 0.91704123, 'transformer_stgnn': 0.9201605660574776}, 'swiss-2010': {'lstm': 0.95707409, 'transformer': 0.9458142, 'graphlet': 0.9466547114285715, 'transformer_graphlet': 0.9218409200000001, 'lstm_embedding': 0.9735727071428572, 'transformer_embedding': 0.9523607414285714, 'stgnn': 0.9433832114285714, 'transformer_stgnn': 0.9532790242857142}, 'zurich': {'lstm': 1.010626867142857, 'transformer': 0.9972451714285714, 'graphlet': 1.018516977142857, 'transformer_graphlet': 0.9746692428571428, 'lstm_embedding': 0.9924479285714286, 'transformer_embedding': 0.9955469142857142, 'stgnn': 0.9836263242857142, 'transformer_stgnn': 1.0015729671428573}}

# %%
metric = 'NSE_Mean'
nse_f_data = gather_variable_data(
    GRAPH_NAMES, METHODS, metric, variable_key, variable_list, aggregate_fun, filename_key, FS_DUMP_DIR
)
normalized_nse_f_data = normalize_err_data(nse_f_data, min_is_better=(not metric.startswith('NSE')))
print(normalized_nse_f_data)
# Out:
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8927386714285716 for graph="swiss-1990", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8957724514285713 for graph="swiss-1990", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8958927814285714 for graph="swiss-1990", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8988203957142857 for graph="swiss-1990", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8934925128571428 for graph="swiss-1990", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8960655271428571 for graph="swiss-1990", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8911263628571428 for graph="swiss-1990", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.8923832859311785 for graph="swiss-1990", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9071943785714286 for graph="swiss-2010", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9095128414285715 for graph="swiss-2010", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9102792299999999 for graph="swiss-2010", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9143202514285714 for graph="swiss-2010", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9048581628571428 for graph="swiss-2010", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9090970985714285 for graph="swiss-2010", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.90866612 for graph="swiss-2010", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9094011871428572 for graph="swiss-2010", method="transformer_stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.93404149 for graph="zurich", method="lstm".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9361471885714285 for graph="zurich", method="transformer".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9337440842857143 for graph="zurich", method="graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9390051128571428 for graph="zurich", method="transformer_graphlet".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9355324142857143 for graph="zurich", method="lstm_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9361243014285714 for graph="zurich", method="transformer_embedding".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9362872257142857 for graph="zurich", method="stgnn".
# <span style="color:green;">[success]</span>  Gathered NSE_Mean=0.9353055514285715 for graph="zurich", method="transformer_stgnn".
# {'swiss-1990': {'lstm': 0.8927386714285716, 'transformer': 0.8957724514285713, 'graphlet': 0.8958927814285714, 'transformer_graphlet': 0.8988203957142857, 'lstm_embedding': 0.8934925128571428, 'transformer_embedding': 0.8960655271428571, 'stgnn': 0.8911263628571428, 'transformer_stgnn': 0.8923832859311785}, 'swiss-2010': {'lstm': 0.9071943785714286, 'transformer': 0.9095128414285715, 'graphlet': 0.9102792299999999, 'transformer_graphlet': 0.9143202514285714, 'lstm_embedding': 0.9048581628571428, 'transformer_embedding': 0.9090970985714285, 'stgnn': 0.90866612, 'transformer_stgnn': 0.9094011871428572}, 'zurich': {'lstm': 0.93404149, 'transformer': 0.9361471885714285, 'graphlet': 0.9337440842857143, 'transformer_graphlet': 0.9390051128571428, 'lstm_embedding': 0.9355324142857143, 'transformer_embedding': 0.9361243014285714, 'stgnn': 0.9362872257142857, 'transformer_stgnn': 0.9353055514285715}}

# %% [markdown]
# ### Combine all data into a single structure to construct latex table:

# %%
data = [[]]
for graph_name in GRAPH_NAMES:
    data += [
        (f'{graph_name}, Isolated', [
            [],
            [],
        ]),
        (f'{graph_name}, Graphlet', [
            [],
            [],
        ]),
        (f'{graph_name}, Embedded', [
            [],
            [],
        ]),
        (f'{graph_name}, ST-GNN', [
            [],
            [],
        ]),
    ]


def append_data_to_visual(data: list, data_to_add: dict, varlabel_to_add: str) -> list:
    data[0].append(varlabel_to_add)
    n_models = 4
    for idx_g, graph_name in enumerate(GRAPH_NAMES):
        data[1 + n_models * idx_g][1][0].append(data_to_add[graph_name].get('lstm'))
        data[1 + n_models * idx_g][1][1].append(data_to_add[graph_name].get('transformer'))
        data[2 + n_models * idx_g][1][0].append(data_to_add[graph_name].get('graphlet'))
        data[2 + n_models * idx_g][1][1].append(data_to_add[graph_name].get('transformer_graphlet'))
        data[3 + n_models * idx_g][1][0].append(data_to_add[graph_name].get('lstm_embedding'))
        data[3 + n_models * idx_g][1][1].append(data_to_add[graph_name].get('transformer_embedding'))
        data[4 + n_models * idx_g][1][0].append(data_to_add[graph_name].get('stgnn'))
        data[4 + n_models * idx_g][1][1].append(data_to_add[graph_name].get('transformer_stgnn'))
    return data

# %%
# Metrics for nowcasting:
data = append_data_to_visual(data, normalized_err_90_data, 'RMSE/N')
data = append_data_to_visual(data, normalized_mae_data, 'MAE/N')
data = append_data_to_visual(data, normalized_nse_data, 'NSE/N')
# Metrics for forecasting:
data = append_data_to_visual(data, normalized_rmse_f_data, 'RMSE/F')
data = append_data_to_visual(data, normalized_mae_f_data, 'MAE/F')
data = append_data_to_visual(data, normalized_nse_f_data, 'NSE/F')
print(len(data))
print(data)
# Out:
# 13
# [['RMSE/N', 'MAE/N', 'NSE/N', 'RMSE/F', 'MAE/F', 'NSE/F'], ('swiss-1990, Isolated', [[0.7815848, 0.5982856, 0.9544531, 1.1672030928571429, 0.9086901742857142, 0.8927386714285716], [0.7530428, 0.57257843, 0.9586869, 1.16513479, 0.9083182057142858, 0.8957724514285713]]), ('swiss-1990, Graphlet', [[0.7687232, 0.5905265, 0.9563571, 1.1602396285714285, 0.9053229857142858, 0.8958927814285714], [0.7456003, 0.5636322, 0.9599849, 1.1474932228571428, 0.8939223199999999, 0.8988203957142857]]), ('swiss-1990, Embedded', [[0.80223453, 0.61948174, 0.9520756, 1.165480462857143, 0.9115052928571429, 0.8934925128571428], [0.77567834, 0.58909565, 0.9546305, 1.1536261857142858, 0.9033050128571428, 0.8960655271428571]]), ('swiss-1990, ST-GNN', [[0.792337, 0.613928, 0.9531913, 1.1751828142857141, 0.91704123, 0.8911263628571428], [0.9413735270500184, 0.716244637966156, 0.9361129, 1.1847208653177534, 0.9201605660574776, 0.8923832859311785]]), ('swiss-2010, Isolated', [[0.788674, 0.6094375, 0.96047723, 1.2253516342857143, 0.95707409, 0.9071943785714286], [0.77297866, 0.59785366, 0.9625836, 1.2129290085714286, 0.9458142, 0.9095128414285715]]), ('swiss-2010, Graphlet', [[0.74543744, 0.5732033, 0.9650015, 1.2112898714285714, 0.9466547114285715, 0.9102792299999999], [0.72453034, 0.55897707, 0.9673347, 1.1806695042857143, 0.9218409200000001, 0.9143202514285714]]), ('swiss-2010, Embedded', [[0.7891973, 0.6100487, 0.9609785, 1.2476980857142856, 0.9735727071428572, 0.9048581628571428], [0.7791719, 0.60378665, 0.9627678, 1.2165865214285714, 0.9523607414285714, 0.9090970985714285]]), ('swiss-2010, ST-GNN', [[0.8992083, 0.6839092, 0.9504563, 1.212332837142857, 0.9433832114285714, 0.90866612], [0.8961308, 0.6842292, 0.9508898, 1.2174435214285713, 0.9532790242857142, 0.9094011871428572]]), ('zurich, Isolated', [[0.7480738, 0.58580834, 0.9786393, 1.291853457142857, 1.010626867142857, 0.93404149], [0.72211015, 0.5647848, 0.9797679, 1.2714704000000001, 0.9972451714285714, 0.9361471885714285]]), ('zurich, Graphlet', [[0.7110647, 0.5594092, 0.9805818, 1.2922117, 1.018516977142857, 0.9337440842857143], [0.71971107, 0.56111366, 0.979802, 1.2430915, 0.9746692428571428, 0.9390051128571428]]), ('zurich, Embedded', [[0.7983226, 0.60335803, 0.976573, 1.2842401928571427, 0.9924479285714286, 0.9355324142857143], [0.69957054, 0.5487588, 0.98066556, 1.2752472771428571, 0.9955469142857142, 0.9361243014285714]]), ('zurich, ST-GNN', [[0.718054, 0.55986583, 0.98039687, 1.2653613000000001, 0.9836263242857142, 0.9362872257142857], [0.6979277, 0.5465388, 0.9808315, 1.281765042857143, 1.0015729671428573, 0.9353055514285715]])]

# %% [markdown]
# ### Construct LaTeX table:

# %%
GRAPH_NAMES = ['swiss-1990', 'swiss-2010', 'zurich']
# METHODS = ['lstm', 'transformer', 'graphlet', 'transformer_graphlet', 'lstm_embedding', 'transformer_embedding',
#            'stgnn', 'transformer_stgnn']
ARCHITECTURES = ['Isolated', 'Graphlet', 'Embedded', 'ST-GNN']

# %%
import numpy as np


def get_value_str_suffix(change_in_percent: float, larger_is_better: bool = False, threshold: float = 0.05) -> str:
    if np.isnan(change_in_percent):
        return ''
    condition_better = (change_in_percent >= threshold) if larger_is_better else (change_in_percent <= -threshold)
    condition_worse = (change_in_percent <= -threshold) if larger_is_better else (change_in_percent >= threshold)
    if condition_better:
        str_color = 'Green'
        str_arrow = '$\\uparrow$'
    elif condition_worse:
        str_color = 'Red'
        str_arrow = '$\\downarrow$'
    else:
        str_color = 'Blue'
        str_arrow = ''
    return f'\\textcolor{{{str_color}}}{{\\scriptsize{{{abs(change_in_percent):.1f}\\%{str_arrow}}}}}~'


def get_best_performance(data: list) -> float | None:
    idx_best_perf = []
    for i_graph, graph_name in enumerate(GRAPH_NAMES):
        value_lists = []
        for i_model, model_name in enumerate(['LSTM', 'Transformer']):
            for i_arch, arch in enumerate(ARCHITECTURES):
                # RMSE, MAE, NSE for nowcasting and forecasting:
                all_values = np.array(data[1 + 4 * i_graph + i_arch][1][i_model][0:6])
                value_lists.append(all_values)
        value_array = np.array(value_lists)
        # print(f'Graph: {graph_name}')
        # print(value_array)
        max_i_vals = np.argmax(value_array, axis=0)
        min_i_vals = np.argmin(value_array, axis=0)
        best_i_vals = [max_i if i in [2, 5] else min_i for i, (min_i, max_i) in
                       enumerate(zip(min_i_vals, max_i_vals))]
        # print(max_i_vals)
        # print(min_i_vals)
        # print(best_i_vals)
        idx_best_perf.append(best_i_vals)
    return idx_best_perf


def is_best_performance(idx_best_perf: list, i_graph: int, i_model: int, i_arch: int, i_metric: int) -> bool:
    n_archs = len(ARCHITECTURES)
    idx = i_model * n_archs + i_arch
    return idx_best_perf[i_graph][i_metric] == idx


# if __name__ == '__main__':
idx_best_perf = get_best_performance(data)

latex_str = ''
for i_graph, graph_name in enumerate(GRAPH_NAMES):
    latex_str += f'\\bf {graph_name.capitalize()} & '
    for i_model, model_name in enumerate(['LSTM', 'Transformer']):
        if i_model == 1:
            latex_str += ' & '
        latex_str += f'{model_name} & '
        for i_arch, arch in enumerate(ARCHITECTURES):
            if i_model == 0 and i_arch == 0:
                pass
            elif i_model == 1 and i_arch == 0:
                pass
            else:
                latex_str += ' & & '
            latex_str += f'{arch} & '
            all_values = np.array(
                data[1 + 4 * i_graph + i_arch][1][i_model][0:6]
            )  # RMSE, MAE, NSE for nowcasting and forecasting

            # Get the value change:
            if i_model == 1:
                all_values_lstm = np.array(data[1 + 4 * i_graph + i_arch][1][0][0:6])  # LSTM values
                nan_lstm = np.where(all_values_lstm == None, np.nan, all_values_lstm)
                nan_transformer = np.where(all_values == None, np.nan, all_values)
                changes_in_percent = ((nan_transformer - nan_lstm) / nan_lstm) * 100.0

            for i_val, val in enumerate(all_values):
                if val is None:
                    latex_str += '-'
                else:
                    formatted_val = (lambda x: f"{x:.3f}".lstrip("0").replace("-0", "-"))(val)
                    if is_best_performance(idx_best_perf, i_graph, i_model, i_arch, i_val):
                        formatted_val = f'\\textbf{{{formatted_val}}}'
                        formatted_val = f'\\underline{{{formatted_val}}}'
                    larger_is_better = True if i_val in [2, 5] else False  # NSE larger is better
                    latex_str += (get_value_str_suffix(
                        changes_in_percent[i_val], larger_is_better=larger_is_better
                    ) if i_model == 1 else '') + formatted_val
                if i_val < len(all_values) - 1:
                    latex_str += ' & '
            if i_arch < len(ARCHITECTURES) - 1:
                latex_str += ' \\\\ \n'

        if i_model < 1:
            latex_str += ' \\\\ \n \\cmidrule(r){2-9} \n'

    if i_graph < len(GRAPH_NAMES) - 1:
        latex_str += ' \\\\ \n\\midrule \n'

latex_str += ' \\\\'

# print(latex_str)  # directly print does not display correctly in Jupyter Notebook
from IPython.display import HTML

HTML(f"<pre>{latex_str}</pre>")
# Out:
# <pre>\bf Swiss-1990 & LSTM & Isolated & .782 & .598 & .954 & 1.167 & .909 & .893 \\
#  & & Graphlet & .769 & .591 & .956 & 1.160 & .905 & .896 \\
#  & & Embedded & .802 & .619 & .952 & 1.165 & .912 & .893 \\
#  & & ST-GNN & .792 & .614 & .953 & 1.175 & .917 & .891 \\
#  \cmidrule(r){2-9}
#  & Transformer & Isolated & \textcolor{Green}{\scriptsize{3.7\%$\uparrow$}}~.753 & \textcolor{Green}{\scriptsize{4.3\%$\uparrow$}}~.573 & \textcolor{Green}{\scriptsize{0.4\%$\uparrow$}}~.959 & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~1.165 & \textcolor{Blue}{\scriptsize{0.0\%}}~.908 & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.896 \\
#  & & Graphlet & \textcolor{Green}{\scriptsize{3.0\%$\uparrow$}}~\underline{\textbf{.746}} & \textcolor{Green}{\scriptsize{4.6\%$\uparrow$}}~\underline{\textbf{.564}} & \textcolor{Green}{\scriptsize{0.4\%$\uparrow$}}~\underline{\textbf{.960}} & \textcolor{Green}{\scriptsize{1.1\%$\uparrow$}}~\underline{\textbf{1.147}} & \textcolor{Green}{\scriptsize{1.3\%$\uparrow$}}~\underline{\textbf{.894}} & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~\underline{\textbf{.899}} \\
#  & & Embedded & \textcolor{Green}{\scriptsize{3.3\%$\uparrow$}}~.776 & \textcolor{Green}{\scriptsize{4.9\%$\uparrow$}}~.589 & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.955 & \textcolor{Green}{\scriptsize{1.0\%$\uparrow$}}~1.154 & \textcolor{Green}{\scriptsize{0.9\%$\uparrow$}}~.903 & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.896 \\
#  & & ST-GNN & \textcolor{Red}{\scriptsize{18.8\%$\downarrow$}}~.941 & \textcolor{Red}{\scriptsize{16.7\%$\downarrow$}}~.716 & \textcolor{Red}{\scriptsize{1.8\%$\downarrow$}}~.936 & \textcolor{Red}{\scriptsize{0.8\%$\downarrow$}}~1.185 & \textcolor{Red}{\scriptsize{0.3\%$\downarrow$}}~.920 & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.892 \\
# \midrule
# \bf Swiss-2010 & LSTM & Isolated & .789 & .609 & .960 & 1.225 & .957 & .907 \\
#  & & Graphlet & .745 & .573 & .965 & 1.211 & .947 & .910 \\
#  & & Embedded & .789 & .610 & .961 & 1.248 & .974 & .905 \\
#  & & ST-GNN & .899 & .684 & .950 & 1.212 & .943 & .909 \\
#  \cmidrule(r){2-9}
#  & Transformer & Isolated & \textcolor{Green}{\scriptsize{2.0\%$\uparrow$}}~.773 & \textcolor{Green}{\scriptsize{1.9\%$\uparrow$}}~.598 & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~.963 & \textcolor{Green}{\scriptsize{1.0\%$\uparrow$}}~1.213 & \textcolor{Green}{\scriptsize{1.2\%$\uparrow$}}~.946 & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.910 \\
#  & & Graphlet & \textcolor{Green}{\scriptsize{2.8\%$\uparrow$}}~\underline{\textbf{.725}} & \textcolor{Green}{\scriptsize{2.5\%$\uparrow$}}~\underline{\textbf{.559}} & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~\underline{\textbf{.967}} & \textcolor{Green}{\scriptsize{2.5\%$\uparrow$}}~\underline{\textbf{1.181}} & \textcolor{Green}{\scriptsize{2.6\%$\uparrow$}}~\underline{\textbf{.922}} & \textcolor{Green}{\scriptsize{0.4\%$\uparrow$}}~\underline{\textbf{.914}} \\
#  & & Embedded & \textcolor{Green}{\scriptsize{1.3\%$\uparrow$}}~.779 & \textcolor{Green}{\scriptsize{1.0\%$\uparrow$}}~.604 & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~.963 & \textcolor{Green}{\scriptsize{2.5\%$\uparrow$}}~1.217 & \textcolor{Green}{\scriptsize{2.2\%$\uparrow$}}~.952 & \textcolor{Green}{\scriptsize{0.5\%$\uparrow$}}~.909 \\
#  & & ST-GNN & \textcolor{Green}{\scriptsize{0.3\%$\uparrow$}}~.896 & \textcolor{Blue}{\scriptsize{0.0\%}}~.684 & \textcolor{Blue}{\scriptsize{0.0\%}}~.951 & \textcolor{Red}{\scriptsize{0.4\%$\downarrow$}}~1.217 & \textcolor{Red}{\scriptsize{1.0\%$\downarrow$}}~.953 & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.909 \\
# \midrule
# \bf Zurich & LSTM & Isolated & .748 & .586 & .979 & 1.292 & 1.011 & .934 \\
#  & & Graphlet & .711 & .559 & .981 & 1.292 & 1.019 & .934 \\
#  & & Embedded & .798 & .603 & .977 & 1.284 & .992 & .936 \\
#  & & ST-GNN & .718 & .560 & .980 & 1.265 & .984 & .936 \\
#  \cmidrule(r){2-9}
#  & Transformer & Isolated & \textcolor{Green}{\scriptsize{3.5\%$\uparrow$}}~.722 & \textcolor{Green}{\scriptsize{3.6\%$\uparrow$}}~.565 & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.980 & \textcolor{Green}{\scriptsize{1.6\%$\uparrow$}}~1.271 & \textcolor{Green}{\scriptsize{1.3\%$\uparrow$}}~.997 & \textcolor{Green}{\scriptsize{0.2\%$\uparrow$}}~.936 \\
#  & & Graphlet & \textcolor{Red}{\scriptsize{1.2\%$\downarrow$}}~.720 & \textcolor{Red}{\scriptsize{0.3\%$\downarrow$}}~.561 & \textcolor{Red}{\scriptsize{0.1\%$\downarrow$}}~.980 & \textcolor{Green}{\scriptsize{3.8\%$\uparrow$}}~\underline{\textbf{1.243}} & \textcolor{Green}{\scriptsize{4.3\%$\uparrow$}}~\underline{\textbf{.975}} & \textcolor{Green}{\scriptsize{0.6\%$\uparrow$}}~\underline{\textbf{.939}} \\
#  & & Embedded & \textcolor{Green}{\scriptsize{12.4\%$\uparrow$}}~.700 & \textcolor{Green}{\scriptsize{9.0\%$\uparrow$}}~.549 & \textcolor{Green}{\scriptsize{0.4\%$\uparrow$}}~.981 & \textcolor{Green}{\scriptsize{0.7\%$\uparrow$}}~1.275 & \textcolor{Red}{\scriptsize{0.3\%$\downarrow$}}~.996 & \textcolor{Green}{\scriptsize{0.1\%$\uparrow$}}~.936 \\
#  & & ST-GNN & \textcolor{Green}{\scriptsize{2.8\%$\uparrow$}}~\underline{\textbf{.698}} & \textcolor{Green}{\scriptsize{2.4\%$\uparrow$}}~\underline{\textbf{.547}} & \textcolor{Blue}{\scriptsize{0.0\%}}~\underline{\textbf{.981}} & \textcolor{Red}{\scriptsize{1.3\%$\downarrow$}}~1.282 & \textcolor{Red}{\scriptsize{1.8\%$\downarrow$}}~1.002 & \textcolor{Red}{\scriptsize{0.1\%$\downarrow$}}~.935 \\</pre>
