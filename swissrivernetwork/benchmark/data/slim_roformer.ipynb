# %% [markdown]
# ## Slim saved RoFormer weights, e.g., the word embedding

# %%
import os
from pathlib import Path

import torch

from swissrivernetwork.benchmark.model import TransformerEmbeddingModel


def prune_roformer_word_embeddings(input_path: Path, weights_to_prune: list[str], output_path: Path | None = None):
    """Prune RoFormer model weights.
    """
    if output_path is None:
        output_path = input_path
    os.makedirs(output_path.parent, exist_ok=True)

    state_dict = torch.load(input_path)
    # for k in state_dict.keys():
    #     print(k, state_dict[k].shape)

    # Infer proper size from the state dict:
    num_embeddings = state_dict['embedding.weight'].shape[0]
    embedding_size = state_dict['embedding.weight'].shape[1]
    input_size = state_dict['input_proj.weight'].shape[1] - embedding_size
    # Assuming state dict is ordered:
    num_layers = int(
        [name for name in state_dict.keys() if name.startswith('transformer.encoder.layer')][-1].split('.')[3]
    ) + 1
    dim_feedforward = state_dict['transformer.encoder.layer.0.intermediate.dense.weight'].shape[0]
    d_model = state_dict['transformer.embeddings.word_embeddings.weight'].shape[1]
    num_heads = d_model // state_dict['transformer.encoder.embed_positions.weight'].shape[1]
    max_len = state_dict['transformer.encoder.embed_positions.weight'].shape[0]
    missing_value_method = 'mask_embedding' if 'mask_embedding' in state_dict else None
    # print(state_dict['transformer.encoder.embed_positions.weight'].shape[1])
    # print(
    #     f'num_embeddings: {num_embeddings}, embedding_size: {embedding_size}, num_heads: {num_heads}, '
    #     f'num_layers: {num_layers}, dim_feedforward: {dim_feedforward}, d_model: {d_model}, max_len: {max_len}, '
    #     f'missing_value_method: {missing_value_method}'
    # )

    model = TransformerEmbeddingModel(
        input_size, num_embeddings=num_embeddings,
        embedding_size=embedding_size,
        num_heads=num_heads,
        num_layers=num_layers,
        dim_feedforward=dim_feedforward,
        dropout=0.1,  # This does not matter for loading weights
        d_model=d_model,
        max_len=max_len,
        missing_value_method=missing_value_method,
        use_current_x=True,  # This does not matter for loading weights
        positional_encoding='rope',
    )

    vocab_size = state_dict['transformer.embeddings.word_embeddings.weight'].shape[0]
    word_embeddings = model.transformer.embeddings.word_embeddings
    if word_embeddings.weight.shape[0] != vocab_size:
        # print(
        #     f'Pruning word embeddings from {word_embeddings.weight.shape[0]} to {vocab_size}...'
        # )
        state_dict['transformer.embeddings.word_embeddings.weight'] = word_embeddings.weight
        # state_dict.pop('transformer.embeddings.word_embeddings.weight')
    # for k in state_dict.keys():
    #     print(k, state_dict[k].shape)

    # This is not actually necessary, but just to check the consistency:
    model.load_state_dict(state_dict)
    # print(model)

    torch.save(state_dict, output_path)

# %%
CUR_ABS_DIR = Path.cwd().resolve()
PROJ_DIR = (CUR_ABS_DIR / '../../../').resolve()
root_dir = (PROJ_DIR / 'swissrivernetwork/benchmark/outputs/ray_results/').resolve()

ray_exp_dirs = sorted(
    [item for item in root_dir.iterdir() if
     item.name.startswith('transformer_embedding') and 'rope' in item.name]
)
weights_to_prune = ['transformer.embeddings.word_embeddings']

for input_dir in ray_exp_dirs[1:]:
    print('\n====================')
    print(input_dir)
    count = 0
    trial_dirs = sorted([item for item in input_dir.iterdir() if item.is_dir()])
    for trial_dir in trial_dirs:
        ckp_dirs = sorted(
            [item for item in trial_dir.iterdir() if item.is_dir() and item.name.startswith('checkpoint_')]
        )
        for ckp_dir in ckp_dirs:
            ckp_paths = sorted([item for item in ckp_dir.iterdir() if item.is_file() and item.name.endswith('.pth')])
            for ckp_path in ckp_paths:
                # print(ckp_path)
                try:
                    prune_roformer_word_embeddings(
                        ckp_path, weights_to_prune, output_path=ckp_path
                    )
                    print(f'Pruned weights for the {count}-th checkpoint.')
                    count += 1
                except Exception as e:
                    print(f'Error processing {ckp_path}: {e}')

print('\nAll done!')
# Out:
# /mnt/832acd65-7396-480e-aa76-dca6765861b0/research-repo/projects/2025.09_hydrology_Switzerland/codes/swiss-river-network-benchmark/swissrivernetwork/benchmark/outputs/ray_results/transformer_embedding-swiss-2010-rope-2025-10-01_16-04-25
# Pruned weights for the 0-th checkpoint.
# Pruned weights for the 1-th checkpoint.
# Pruned weights for the 2-th checkpoint.
# Pruned weights for the 3-th checkpoint.
# Pruned weights for the 4-th checkpoint.
# Pruned weights for the 5-th checkpoint.
# Pruned weights for the 6-th checkpoint.
# Pruned weights for the 7-th checkpoint.
# Pruned weights for the 8-th checkpoint.
# Pruned weights for the 9-th checkpoint.
# Pruned weights for the 10-th checkpoint.
# Pruned weights for the 11-th checkpoint.
# Pruned weights for the 12-th checkpoint.
# Pruned weights for the 13-th checkpoint.
# Pruned weights for the 14-th checkpoint.
# Pruned weights for the 15-th checkpoint.
# Pruned weights for the 16-th checkpoint.
# Pruned weights for the 17-th checkpoint.
# Pruned weights for the 18-th checkpoint.
# Pruned weights for the 19-th checkpoint.
# Pruned weights for the 20-th checkpoint.
# Pruned weights for the 21-th checkpoint.
# Pruned weights for the 22-th checkpoint.
# Pruned weights for the 23-th checkpoint.
# Pruned weights for the 24-th checkpoint.
# Pruned weights for the 25-th checkpoint.
# Pruned weights for the 26-th checkpoint.
# Pruned weights for the 27-th checkpoint.
# Pruned weights for the 28-th checkpoint.
# Pruned weights for the 29-th checkpoint.
# Pruned weights for the 30-th checkpoint.
# Pruned weights for the 31-th checkpoint.
# Pruned weights for the 32-th checkpoint.
# Pruned weights for the 33-th checkpoint.
# Pruned weights for the 34-th checkpoint.
# Pruned weights for the 35-th checkpoint.
# Pruned weights for the 36-th checkpoint.
# Pruned weights for the 37-th checkpoint.
# Pruned weights for the 38-th checkpoint.
# Pruned weights for the 39-th checkpoint.
# Pruned weights for the 40-th checkpoint.
# Pruned weights for the 41-th checkpoint.
# Pruned weights for the 42-th checkpoint.
# Pruned weights for the 43-th checkpoint.
# Pruned weights for the 44-th checkpoint.
# Pruned weights for the 45-th checkpoint.
# Pruned weights for the 46-th checkpoint.
# Pruned weights for the 47-th checkpoint.
# Pruned weights for the 48-th checkpoint.
# Pruned weights for the 49-th checkpoint.
# Pruned weights for the 50-th checkpoint.
# Pruned weights for the 51-th checkpoint.
# Pruned weights for the 52-th checkpoint.
# Pruned weights for the 53-th checkpoint.
# Pruned weights for the 54-th checkpoint.
# Pruned weights for the 55-th checkpoint.
# Pruned weights for the 56-th checkpoint.
# Pruned weights for the 57-th checkpoint.
# Pruned weights for the 58-th checkpoint.
# Pruned weights for the 59-th checkpoint.
# Pruned weights for the 60-th checkpoint.
# Pruned weights for the 61-th checkpoint.
# Pruned weights for the 62-th checkpoint.
# Pruned weights for the 63-th checkpoint.
# Pruned weights for the 64-th checkpoint.
# Pruned weights for the 65-th checkpoint.
# Pruned weights for the 66-th checkpoint.
# Pruned weights for the 67-th checkpoint.
# Pruned weights for the 68-th checkpoint.
# Pruned weights for the 69-th checkpoint.
# Pruned weights for the 70-th checkpoint.
# Pruned weights for the 71-th checkpoint.
# Pruned weights for the 72-th checkpoint.
# Pruned weights for the 73-th checkpoint.
# Pruned weights for the 74-th checkpoint.
# Pruned weights for the 75-th checkpoint.
# Pruned weights for the 76-th checkpoint.
# Pruned weights for the 77-th checkpoint.
# Pruned weights for the 78-th checkpoint.
# Pruned weights for the 79-th checkpoint.
# Pruned weights for the 80-th checkpoint.
# Pruned weights for the 81-th checkpoint.
# Pruned weights for the 82-th checkpoint.
# Pruned weights for the 83-th checkpoint.
# Pruned weights for the 84-th checkpoint.
# Pruned weights for the 85-th checkpoint.
# Pruned weights for the 86-th checkpoint.
# Pruned weights for the 87-th checkpoint.
# Pruned weights for the 88-th checkpoint.
# Pruned weights for the 89-th checkpoint.
# Pruned weights for the 90-th checkpoint.
# Pruned weights for the 91-th checkpoint.
# Pruned weights for the 92-th checkpoint.
# Pruned weights for the 93-th checkpoint.
# Pruned weights for the 94-th checkpoint.
# Pruned weights for the 95-th checkpoint.
# Pruned weights for the 96-th checkpoint.
# Pruned weights for the 97-th checkpoint.
# Pruned weights for the 98-th checkpoint.
# Pruned weights for the 99-th checkpoint.
# Pruned weights for the 100-th checkpoint.
# Pruned weights for the 101-th checkpoint.
# Pruned weights for the 102-th checkpoint.
# Pruned weights for the 103-th checkpoint.
# Pruned weights for the 104-th checkpoint.
# Pruned weights for the 105-th checkpoint.
# Pruned weights for the 106-th checkpoint.
# Pruned weights for the 107-th checkpoint.
# Pruned weights for the 108-th checkpoint.
# Pruned weights for the 109-th checkpoint.
# Pruned weights for the 110-th checkpoint.
# Pruned weights for the 111-th checkpoint.
# Pruned weights for the 112-th checkpoint.
# Pruned weights for the 113-th checkpoint.
# Pruned weights for the 114-th checkpoint.
# Pruned weights for the 115-th checkpoint.
# Pruned weights for the 116-th checkpoint.
# Pruned weights for the 117-th checkpoint.
# Pruned weights for the 118-th checkpoint.
# Pruned weights for the 119-th checkpoint.
# Pruned weights for the 120-th checkpoint.
# Pruned weights for the 121-th checkpoint.
# Pruned weights for the 122-th checkpoint.
# Pruned weights for the 123-th checkpoint.
# Pruned weights for the 124-th checkpoint.
# Pruned weights for the 125-th checkpoint.
# Pruned weights for the 126-th checkpoint.
# Pruned weights for the 127-th checkpoint.
# Pruned weights for the 128-th checkpoint.
# Pruned weights for the 129-th checkpoint.
# Pruned weights for the 130-th checkpoint.
# Pruned weights for the 131-th checkpoint.
# Pruned weights for the 132-th checkpoint.
# Pruned weights for the 133-th checkpoint.
# Pruned weights for the 134-th checkpoint.
# Pruned weights for the 135-th checkpoint.
# Pruned weights for the 136-th checkpoint.
# Pruned weights for the 137-th checkpoint.
# Pruned weights for the 138-th checkpoint.
# Pruned weights for the 139-th checkpoint.
# Pruned weights for the 140-th checkpoint.
# Pruned weights for the 141-th checkpoint.
# Pruned weights for the 142-th checkpoint.
# Pruned weights for the 143-th checkpoint.
# Pruned weights for the 144-th checkpoint.
# Pruned weights for the 145-th checkpoint.
# Pruned weights for the 146-th checkpoint.
# Pruned weights for the 147-th checkpoint.
# Pruned weights for the 148-th checkpoint.
# Pruned weights for the 149-th checkpoint.
# Pruned weights for the 150-th checkpoint.
# Pruned weights for the 151-th checkpoint.
# Pruned weights for the 152-th checkpoint.
# Pruned weights for the 153-th checkpoint.
# Pruned weights for the 154-th checkpoint.
# Pruned weights for the 155-th checkpoint.
# Pruned weights for the 156-th checkpoint.
# Pruned weights for the 157-th checkpoint.
# Pruned weights for the 158-th checkpoint.
# Pruned weights for the 159-th checkpoint.
# Pruned weights for the 160-th checkpoint.
# Pruned weights for the 161-th checkpoint.
# Pruned weights for the 162-th checkpoint.
# Pruned weights for the 163-th checkpoint.
# Pruned weights for the 164-th checkpoint.
# Pruned weights for the 165-th checkpoint.
# Pruned weights for the 166-th checkpoint.
# Pruned weights for the 167-th checkpoint.
# Pruned weights for the 168-th checkpoint.
# Pruned weights for the 169-th checkpoint.
# Pruned weights for the 170-th checkpoint.
# Pruned weights for the 171-th checkpoint.
# Pruned weights for the 172-th checkpoint.
# Pruned weights for the 173-th checkpoint.
# Pruned weights for the 174-th checkpoint.
# Pruned weights for the 175-th checkpoint.
# Pruned weights for the 176-th checkpoint.
# Pruned weights for the 177-th checkpoint.
# Pruned weights for the 178-th checkpoint.
# Pruned weights for the 179-th checkpoint.
# Pruned weights for the 180-th checkpoint.
# Pruned weights for the 181-th checkpoint.
# Pruned weights for the 182-th checkpoint.
# Pruned weights for the 183-th checkpoint.
# Pruned weights for the 184-th checkpoint.
# Pruned weights for the 185-th checkpoint.
# Pruned weights for the 186-th checkpoint.
# Pruned weights for the 187-th checkpoint.
# Pruned weights for the 188-th checkpoint.
# Pruned weights for the 189-th checkpoint.
# Pruned weights for the 190-th checkpoint.
# Pruned weights for the 191-th checkpoint.
# Pruned weights for the 192-th checkpoint.
# Pruned weights for the 193-th checkpoint.
# Pruned weights for the 194-th checkpoint.
# Pruned weights for the 195-th checkpoint.
# Pruned weights for the 196-th checkpoint.
# Pruned weights for the 197-th checkpoint.
# Pruned weights for the 198-th checkpoint.
# Pruned weights for the 199-th checkpoint.
# Pruned weights for the 200-th checkpoint.
# Pruned weights for the 201-th checkpoint.
# Pruned weights for the 202-th checkpoint.
# Pruned weights for the 203-th checkpoint.
# Pruned weights for the 204-th checkpoint.
# Pruned weights for the 205-th checkpoint.
# Pruned weights for the 206-th checkpoint.
# Pruned weights for the 207-th checkpoint.
# Pruned weights for the 208-th checkpoint.
# Pruned weights for the 209-th checkpoint.
# Pruned weights for the 210-th checkpoint.
# Pruned weights for the 211-th checkpoint.
# Pruned weights for the 212-th checkpoint.
# Pruned weights for the 213-th checkpoint.
# Pruned weights for the 214-th checkpoint.
# Pruned weights for the 215-th checkpoint.
# Pruned weights for the 216-th checkpoint.
# Pruned weights for the 217-th checkpoint.
# Pruned weights for the 218-th checkpoint.
# Pruned weights for the 219-th checkpoint.
# Pruned weights for the 220-th checkpoint.
# Pruned weights for the 221-th checkpoint.
# Pruned weights for the 222-th checkpoint.
# Pruned weights for the 223-th checkpoint.
# Pruned weights for the 224-th checkpoint.
# Pruned weights for the 225-th checkpoint.
# Pruned weights for the 226-th checkpoint.
# Pruned weights for the 227-th checkpoint.
# Pruned weights for the 228-th checkpoint.
# Pruned weights for the 229-th checkpoint.
# Pruned weights for the 230-th checkpoint.
# Pruned weights for the 231-th checkpoint.
# Pruned weights for the 232-th checkpoint.
# Pruned weights for the 233-th checkpoint.
# Pruned weights for the 234-th checkpoint.
# Pruned weights for the 235-th checkpoint.
# Pruned weights for the 236-th checkpoint.
# Pruned weights for the 237-th checkpoint.
# Pruned weights for the 238-th checkpoint.
# Pruned weights for the 239-th checkpoint.
# Pruned weights for the 240-th checkpoint.
# Pruned weights for the 241-th checkpoint.
# Pruned weights for the 242-th checkpoint.
# Pruned weights for the 243-th checkpoint.
# Pruned weights for the 244-th checkpoint.
# Pruned weights for the 245-th checkpoint.
# Pruned weights for the 246-th checkpoint.
# Pruned weights for the 247-th checkpoint.
# Pruned weights for the 248-th checkpoint.
# Pruned weights for the 249-th checkpoint.
# Pruned weights for the 250-th checkpoint.
# Pruned weights for the 251-th checkpoint.
# Pruned weights for the 252-th checkpoint.
# Pruned weights for the 253-th checkpoint.
# Pruned weights for the 254-th checkpoint.
# Pruned weights for the 255-th checkpoint.
# Pruned weights for the 256-th checkpoint.
# Pruned weights for the 257-th checkpoint.
# Pruned weights for the 258-th checkpoint.
# Pruned weights for the 259-th checkpoint.
# Pruned weights for the 260-th checkpoint.
# Pruned weights for the 261-th checkpoint.
# Pruned weights for the 262-th checkpoint.
# Pruned weights for the 263-th checkpoint.
# Pruned weights for the 264-th checkpoint.
# Pruned weights for the 265-th checkpoint.
# Pruned weights for the 266-th checkpoint.
# Pruned weights for the 267-th checkpoint.
# Pruned weights for the 268-th checkpoint.
# Pruned weights for the 269-th checkpoint.
# Pruned weights for the 270-th checkpoint.
# Pruned weights for the 271-th checkpoint.
# Pruned weights for the 272-th checkpoint.
# Pruned weights for the 273-th checkpoint.
# Pruned weights for the 274-th checkpoint.
# Pruned weights for the 275-th checkpoint.
# Pruned weights for the 276-th checkpoint.
# Pruned weights for the 277-th checkpoint.
# Pruned weights for the 278-th checkpoint.
# Pruned weights for the 279-th checkpoint.
# Pruned weights for the 280-th checkpoint.
# Pruned weights for the 281-th checkpoint.
# Pruned weights for the 282-th checkpoint.
# Pruned weights for the 283-th checkpoint.
# Pruned weights for the 284-th checkpoint.
# Pruned weights for the 285-th checkpoint.
# Pruned weights for the 286-th checkpoint.
# Pruned weights for the 287-th checkpoint.
# Pruned weights for the 288-th checkpoint.
# Pruned weights for the 289-th checkpoint.
# Pruned weights for the 290-th checkpoint.
# Pruned weights for the 291-th checkpoint.
# Pruned weights for the 292-th checkpoint.
# Pruned weights for the 293-th checkpoint.
# Pruned weights for the 294-th checkpoint.
# Pruned weights for the 295-th checkpoint.
# Pruned weights for the 296-th checkpoint.
# Pruned weights for the 297-th checkpoint.
# Pruned weights for the 298-th checkpoint.
# Pruned weights for the 299-th checkpoint.
# Pruned weights for the 300-th checkpoint.
# Pruned weights for the 301-th checkpoint.
# Pruned weights for the 302-th checkpoint.
# Pruned weights for the 303-th checkpoint.
# Pruned weights for the 304-th checkpoint.
# Pruned weights for the 305-th checkpoint.
# Pruned weights for the 306-th checkpoint.
# Pruned weights for the 307-th checkpoint.
# Pruned weights for the 308-th checkpoint.
# Pruned weights for the 309-th checkpoint.
# Pruned weights for the 310-th checkpoint.
# Pruned weights for the 311-th checkpoint.
# Pruned weights for the 312-th checkpoint.
# Pruned weights for the 313-th checkpoint.
# Pruned weights for the 314-th checkpoint.
# Pruned weights for the 315-th checkpoint.
# Pruned weights for the 316-th checkpoint.
# Pruned weights for the 317-th checkpoint.
# Pruned weights for the 318-th checkpoint.
# Pruned weights for the 319-th checkpoint.
# Pruned weights for the 320-th checkpoint.
# Pruned weights for the 321-th checkpoint.
# Pruned weights for the 322-th checkpoint.
# Pruned weights for the 323-th checkpoint.
# Pruned weights for the 324-th checkpoint.
# Pruned weights for the 325-th checkpoint.
# Pruned weights for the 326-th checkpoint.
# Pruned weights for the 327-th checkpoint.
# Pruned weights for the 328-th checkpoint.
# Pruned weights for the 329-th checkpoint.
# Pruned weights for the 330-th checkpoint.
# Pruned weights for the 331-th checkpoint.
# Pruned weights for the 332-th checkpoint.
# Pruned weights for the 333-th checkpoint.
# Pruned weights for the 334-th checkpoint.
# Pruned weights for the 335-th checkpoint.
# Pruned weights for the 336-th checkpoint.
# Pruned weights for the 337-th checkpoint.
# Pruned weights for the 338-th checkpoint.
# Pruned weights for the 339-th checkpoint.
# Pruned weights for the 340-th checkpoint.
# Pruned weights for the 341-th checkpoint.
# Pruned weights for the 342-th checkpoint.
# Pruned weights for the 343-th checkpoint.
# Pruned weights for the 344-th checkpoint.
# Pruned weights for the 345-th checkpoint.
# Pruned weights for the 346-th checkpoint.
# Pruned weights for the 347-th checkpoint.
# Pruned weights for the 348-th checkpoint.
# Pruned weights for the 349-th checkpoint.
# Pruned weights for the 350-th checkpoint.
# Pruned weights for the 351-th checkpoint.
# Pruned weights for the 352-th checkpoint.
# Pruned weights for the 353-th checkpoint.
# Pruned weights for the 354-th checkpoint.
# Pruned weights for the 355-th checkpoint.
# Pruned weights for the 356-th checkpoint.
# Pruned weights for the 357-th checkpoint.
# Pruned weights for the 358-th checkpoint.
# Pruned weights for the 359-th checkpoint.
# Pruned weights for the 360-th checkpoint.
# Pruned weights for the 361-th checkpoint.
# Pruned weights for the 362-th checkpoint.
# Pruned weights for the 363-th checkpoint.
# Pruned weights for the 364-th checkpoint.
# Pruned weights for the 365-th checkpoint.
# Pruned weights for the 366-th checkpoint.
# Pruned weights for the 367-th checkpoint.
# Pruned weights for the 368-th checkpoint.
# Pruned weights for the 369-th checkpoint.
# Pruned weights for the 370-th checkpoint.
# Pruned weights for the 371-th checkpoint.
# Pruned weights for the 372-th checkpoint.
# Pruned weights for the 373-th checkpoint.
# Pruned weights for the 374-th checkpoint.
# Pruned weights for the 375-th checkpoint.
# Pruned weights for the 376-th checkpoint.
# Pruned weights for the 377-th checkpoint.
# Pruned weights for the 378-th checkpoint.
# Pruned weights for the 379-th checkpoint.
# Pruned weights for the 380-th checkpoint.
# Pruned weights for the 381-th checkpoint.
# Pruned weights for the 382-th checkpoint.
# Pruned weights for the 383-th checkpoint.
# Pruned weights for the 384-th checkpoint.
# Pruned weights for the 385-th checkpoint.
# Pruned weights for the 386-th checkpoint.
# Pruned weights for the 387-th checkpoint.
# Pruned weights for the 388-th checkpoint.
# Pruned weights for the 389-th checkpoint.
# Pruned weights for the 390-th checkpoint.
# Pruned weights for the 391-th checkpoint.
# Pruned weights for the 392-th checkpoint.
# Pruned weights for the 393-th checkpoint.
# Pruned weights for the 394-th checkpoint.
# Pruned weights for the 395-th checkpoint.
# Pruned weights for the 396-th checkpoint.
# Pruned weights for the 397-th checkpoint.
# Pruned weights for the 398-th checkpoint.
# Pruned weights for the 399-th checkpoint.
# Pruned weights for the 400-th checkpoint.
# Pruned weights for the 401-th checkpoint.
# Pruned weights for the 402-th checkpoint.
# Pruned weights for the 403-th checkpoint.
# Pruned weights for the 404-th checkpoint.
# Pruned weights for the 405-th checkpoint.
# Pruned weights for the 406-th checkpoint.
# Pruned weights for the 407-th checkpoint.
# Pruned weights for the 408-th checkpoint.
# Pruned weights for the 409-th checkpoint.
# Pruned weights for the 410-th checkpoint.
# Pruned weights for the 411-th checkpoint.
# Pruned weights for the 412-th checkpoint.
# Pruned weights for the 413-th checkpoint.
# Pruned weights for the 414-th checkpoint.
# Pruned weights for the 415-th checkpoint.
# Pruned weights for the 416-th checkpoint.
# Pruned weights for the 417-th checkpoint.
# Pruned weights for the 418-th checkpoint.
# Pruned weights for the 419-th checkpoint.
# Pruned weights for the 420-th checkpoint.
# Pruned weights for the 421-th checkpoint.
# Pruned weights for the 422-th checkpoint.
# Pruned weights for the 423-th checkpoint.
# Pruned weights for the 424-th checkpoint.
# Pruned weights for the 425-th checkpoint.
# Pruned weights for the 426-th checkpoint.
# Pruned weights for the 427-th checkpoint.
# Pruned weights for the 428-th checkpoint.
# Pruned weights for the 429-th checkpoint.
# Pruned weights for the 430-th checkpoint.
# Pruned weights for the 431-th checkpoint.
# Pruned weights for the 432-th checkpoint.
# Pruned weights for the 433-th checkpoint.
# Pruned weights for the 434-th checkpoint.
# Pruned weights for the 435-th checkpoint.
# Pruned weights for the 436-th checkpoint.
# Pruned weights for the 437-th checkpoint.
# Pruned weights for the 438-th checkpoint.
# Pruned weights for the 439-th checkpoint.
# Pruned weights for the 440-th checkpoint.
# Pruned weights for the 441-th checkpoint.
# Pruned weights for the 442-th checkpoint.
# Pruned weights for the 443-th checkpoint.
# Pruned weights for the 444-th checkpoint.
# Pruned weights for the 445-th checkpoint.
# Pruned weights for the 446-th checkpoint.
# Pruned weights for the 447-th checkpoint.
# Pruned weights for the 448-th checkpoint.
# Pruned weights for the 449-th checkpoint.
# Pruned weights for the 450-th checkpoint.
# Pruned weights for the 451-th checkpoint.
# Pruned weights for the 452-th checkpoint.
# Pruned weights for the 453-th checkpoint.
# Pruned weights for the 454-th checkpoint.
# Pruned weights for the 455-th checkpoint.
# Pruned weights for the 456-th checkpoint.
# Pruned weights for the 457-th checkpoint.
# Pruned weights for the 458-th checkpoint.
# Pruned weights for the 459-th checkpoint.
# Pruned weights for the 460-th checkpoint.
# Pruned weights for the 461-th checkpoint.
# Pruned weights for the 462-th checkpoint.
# Pruned weights for the 463-th checkpoint.
# Pruned weights for the 464-th checkpoint.
# Pruned weights for the 465-th checkpoint.
# Pruned weights for the 466-th checkpoint.
# Pruned weights for the 467-th checkpoint.
# Pruned weights for the 468-th checkpoint.
# Pruned weights for the 469-th checkpoint.
# Pruned weights for the 470-th checkpoint.
# Pruned weights for the 471-th checkpoint.
# Pruned weights for the 472-th checkpoint.
# Pruned weights for the 473-th checkpoint.
# Pruned weights for the 474-th checkpoint.
# Pruned weights for the 475-th checkpoint.
# Pruned weights for the 476-th checkpoint.
# Pruned weights for the 477-th checkpoint.
# Pruned weights for the 478-th checkpoint.
# Pruned weights for the 479-th checkpoint.
# Pruned weights for the 480-th checkpoint.
# Pruned weights for the 481-th checkpoint.
# Pruned weights for the 482-th checkpoint.
# Pruned weights for the 483-th checkpoint.
# Pruned weights for the 484-th checkpoint.
# Pruned weights for the 485-th checkpoint.
# Pruned weights for the 486-th checkpoint.
# Pruned weights for the 487-th checkpoint.
# Pruned weights for the 488-th checkpoint.
# Pruned weights for the 489-th checkpoint.
# Pruned weights for the 490-th checkpoint.
# Pruned weights for the 491-th checkpoint.
# Pruned weights for the 492-th checkpoint.
# Pruned weights for the 493-th checkpoint.
# Pruned weights for the 494-th checkpoint.
# Pruned weights for the 495-th checkpoint.
# Pruned weights for the 496-th checkpoint.
# Pruned weights for the 497-th checkpoint.
# Pruned weights for the 498-th checkpoint.
# Pruned weights for the 499-th checkpoint.
# Pruned weights for the 500-th checkpoint.
# Pruned weights for the 501-th checkpoint.
# Pruned weights for the 502-th checkpoint.
# Pruned weights for the 503-th checkpoint.
# Pruned weights for the 504-th checkpoint.
# Pruned weights for the 505-th checkpoint.
# Pruned weights for the 506-th checkpoint.
# Pruned weights for the 507-th checkpoint.
# Pruned weights for the 508-th checkpoint.
# Pruned weights for the 509-th checkpoint.
# Pruned weights for the 510-th checkpoint.
# Pruned weights for the 511-th checkpoint.
# Pruned weights for the 512-th checkpoint.
# Pruned weights for the 513-th checkpoint.
# Pruned weights for the 514-th checkpoint.
# Pruned weights for the 515-th checkpoint.
# Pruned weights for the 516-th checkpoint.
# Pruned weights for the 517-th checkpoint.
# Pruned weights for the 518-th checkpoint.
# Pruned weights for the 519-th checkpoint.
# Pruned weights for the 520-th checkpoint.
# Pruned weights for the 521-th checkpoint.
# Pruned weights for the 522-th checkpoint.
# Pruned weights for the 523-th checkpoint.
# Pruned weights for the 524-th checkpoint.
# Pruned weights for the 525-th checkpoint.
# Pruned weights for the 526-th checkpoint.
# Pruned weights for the 527-th checkpoint.
# Pruned weights for the 528-th checkpoint.
# Pruned weights for the 529-th checkpoint.
# Pruned weights for the 530-th checkpoint.
# Pruned weights for the 531-th checkpoint.
# Pruned weights for the 532-th checkpoint.
# Pruned weights for the 533-th checkpoint.
# Pruned weights for the 534-th checkpoint.
# Pruned weights for the 535-th checkpoint.
# Pruned weights for the 536-th checkpoint.
# Pruned weights for the 537-th checkpoint.
# Pruned weights for the 538-th checkpoint.
# Pruned weights for the 539-th checkpoint.
# Pruned weights for the 540-th checkpoint.
# Pruned weights for the 541-th checkpoint.
# Pruned weights for the 542-th checkpoint.
# Pruned weights for the 543-th checkpoint.
# Pruned weights for the 544-th checkpoint.
# Pruned weights for the 545-th checkpoint.
# Pruned weights for the 546-th checkpoint.
# Pruned weights for the 547-th checkpoint.
# Pruned weights for the 548-th checkpoint.
# Pruned weights for the 549-th checkpoint.
# Pruned weights for the 550-th checkpoint.
# Pruned weights for the 551-th checkpoint.
# Pruned weights for the 552-th checkpoint.
# Pruned weights for the 553-th checkpoint.
# Pruned weights for the 554-th checkpoint.
# Pruned weights for the 555-th checkpoint.
# Pruned weights for the 556-th checkpoint.
# Pruned weights for the 557-th checkpoint.
# Pruned weights for the 558-th checkpoint.
# Pruned weights for the 559-th checkpoint.
# Pruned weights for the 560-th checkpoint.
# Pruned weights for the 561-th checkpoint.
# Pruned weights for the 562-th checkpoint.
# Pruned weights for the 563-th checkpoint.
# Pruned weights for the 564-th checkpoint.
# Pruned weights for the 565-th checkpoint.
# Pruned weights for the 566-th checkpoint.
# Pruned weights for the 567-th checkpoint.
# Pruned weights for the 568-th checkpoint.
# Pruned weights for the 569-th checkpoint.
# Pruned weights for the 570-th checkpoint.
# Pruned weights for the 571-th checkpoint.
# Pruned weights for the 572-th checkpoint.
# Pruned weights for the 573-th checkpoint.
# Pruned weights for the 574-th checkpoint.
# Pruned weights for the 575-th checkpoint.
# Pruned weights for the 576-th checkpoint.
# Pruned weights for the 577-th checkpoint.
# Pruned weights for the 578-th checkpoint.
# Pruned weights for the 579-th checkpoint.
# Pruned weights for the 580-th checkpoint.
# Pruned weights for the 581-th checkpoint.
# Pruned weights for the 582-th checkpoint.
# Pruned weights for the 583-th checkpoint.
# Pruned weights for the 584-th checkpoint.
# Pruned weights for the 585-th checkpoint.
# Pruned weights for the 586-th checkpoint.
# Pruned weights for the 587-th checkpoint.
# Pruned weights for the 588-th checkpoint.
# Pruned weights for the 589-th checkpoint.
# Pruned weights for the 590-th checkpoint.
# Pruned weights for the 591-th checkpoint.
# Pruned weights for the 592-th checkpoint.
# Pruned weights for the 593-th checkpoint.
# Pruned weights for the 594-th checkpoint.
# Pruned weights for the 595-th checkpoint.
# Pruned weights for the 596-th checkpoint.
# Pruned weights for the 597-th checkpoint.
# Pruned weights for the 598-th checkpoint.
# Pruned weights for the 599-th checkpoint.
# Pruned weights for the 600-th checkpoint.
# Pruned weights for the 601-th checkpoint.
# Pruned weights for the 602-th checkpoint.
# Pruned weights for the 603-th checkpoint.
# Pruned weights for the 604-th checkpoint.
# Pruned weights for the 605-th checkpoint.
# Pruned weights for the 606-th checkpoint.
# Pruned weights for the 607-th checkpoint.
# Pruned weights for the 608-th checkpoint.
# Pruned weights for the 609-th checkpoint.
# Pruned weights for the 610-th checkpoint.
# Pruned weights for the 611-th checkpoint.
# Pruned weights for the 612-th checkpoint.
# Pruned weights for the 613-th checkpoint.
# Pruned weights for the 614-th checkpoint.
# Pruned weights for the 615-th checkpoint.
# Pruned weights for the 616-th checkpoint.
# Pruned weights for the 617-th checkpoint.
# Pruned weights for the 618-th checkpoint.
# Pruned weights for the 619-th checkpoint.
# Pruned weights for the 620-th checkpoint.
# Pruned weights for the 621-th checkpoint.
# Pruned weights for the 622-th checkpoint.
# Pruned weights for the 623-th checkpoint.
# Pruned weights for the 624-th checkpoint.
# Pruned weights for the 625-th checkpoint.
# Pruned weights for the 626-th checkpoint.
# Pruned weights for the 627-th checkpoint.
# Pruned weights for the 628-th checkpoint.
# Pruned weights for the 629-th checkpoint.
# Pruned weights for the 630-th checkpoint.
# Pruned weights for the 631-th checkpoint.
# Pruned weights for the 632-th checkpoint.
# Pruned weights for the 633-th checkpoint.
# Pruned weights for the 634-th checkpoint.
# Pruned weights for the 635-th checkpoint.
# Pruned weights for the 636-th checkpoint.
# Pruned weights for the 637-th checkpoint.
# Pruned weights for the 638-th checkpoint.
# Pruned weights for the 639-th checkpoint.
# Pruned weights for the 640-th checkpoint.
# Pruned weights for the 641-th checkpoint.
# Pruned weights for the 642-th checkpoint.
# Pruned weights for the 643-th checkpoint.
# Pruned weights for the 644-th checkpoint.
# Pruned weights for the 645-th checkpoint.
# Pruned weights for the 646-th checkpoint.
# Pruned weights for the 647-th checkpoint.
# Pruned weights for the 648-th checkpoint.
# Pruned weights for the 649-th checkpoint.
# Pruned weights for the 650-th checkpoint.
# Pruned weights for the 651-th checkpoint.
# Pruned weights for the 652-th checkpoint.
# Pruned weights for the 653-th checkpoint.
# Pruned weights for the 654-th checkpoint.
# Pruned weights for the 655-th checkpoint.
# Pruned weights for the 656-th checkpoint.
# Pruned weights for the 657-th checkpoint.
# Pruned weights for the 658-th checkpoint.
# Pruned weights for the 659-th checkpoint.
# Pruned weights for the 660-th checkpoint.
# Pruned weights for the 661-th checkpoint.
# Pruned weights for the 662-th checkpoint.
# Pruned weights for the 663-th checkpoint.
# Pruned weights for the 664-th checkpoint.
# Pruned weights for the 665-th checkpoint.
# Pruned weights for the 666-th checkpoint.
# Pruned weights for the 667-th checkpoint.
# Pruned weights for the 668-th checkpoint.
# Pruned weights for the 669-th checkpoint.
# Pruned weights for the 670-th checkpoint.
# Pruned weights for the 671-th checkpoint.
# Pruned weights for the 672-th checkpoint.
# Pruned weights for the 673-th checkpoint.
# Pruned weights for the 674-th checkpoint.
# Pruned weights for the 675-th checkpoint.
# Pruned weights for the 676-th checkpoint.
# Pruned weights for the 677-th checkpoint.
# Pruned weights for the 678-th checkpoint.
# Pruned weights for the 679-th checkpoint.
# Pruned weights for the 680-th checkpoint.
# Pruned weights for the 681-th checkpoint.
# Pruned weights for the 682-th checkpoint.
# Pruned weights for the 683-th checkpoint.
# Pruned weights for the 684-th checkpoint.
# Pruned weights for the 685-th checkpoint.
# Pruned weights for the 686-th checkpoint.
# Pruned weights for the 687-th checkpoint.
# Pruned weights for the 688-th checkpoint.
# Pruned weights for the 689-th checkpoint.
# Pruned weights for the 690-th checkpoint.
# Pruned weights for the 691-th checkpoint.
# Pruned weights for the 692-th checkpoint.
# Pruned weights for the 693-th checkpoint.
# Pruned weights for the 694-th checkpoint.
# Pruned weights for the 695-th checkpoint.
# Pruned weights for the 696-th checkpoint.
# Pruned weights for the 697-th checkpoint.
# Pruned weights for the 698-th checkpoint.
# Pruned weights for the 699-th checkpoint.
# Pruned weights for the 700-th checkpoint.
# Pruned weights for the 701-th checkpoint.
# Pruned weights for the 702-th checkpoint.
# Pruned weights for the 703-th checkpoint.
# Pruned weights for the 704-th checkpoint.
# Pruned weights for the 705-th checkpoint.
# Pruned weights for the 706-th checkpoint.
# Pruned weights for the 707-th checkpoint.
# Pruned weights for the 708-th checkpoint.
# Pruned weights for the 709-th checkpoint.
# Pruned weights for the 710-th checkpoint.
# Pruned weights for the 711-th checkpoint.
# Pruned weights for the 712-th checkpoint.
# Pruned weights for the 713-th checkpoint.
# Pruned weights for the 714-th checkpoint.
# Pruned weights for the 715-th checkpoint.
# Pruned weights for the 716-th checkpoint.
# Pruned weights for the 717-th checkpoint.
# Pruned weights for the 718-th checkpoint.
# Pruned weights for the 719-th checkpoint.
# Pruned weights for the 720-th checkpoint.
# Pruned weights for the 721-th checkpoint.
# Pruned weights for the 722-th checkpoint.
# Pruned weights for the 723-th checkpoint.
# Pruned weights for the 724-th checkpoint.
# Pruned weights for the 725-th checkpoint.
# Pruned weights for the 726-th checkpoint.
# Pruned weights for the 727-th checkpoint.
# Pruned weights for the 728-th checkpoint.
# Pruned weights for the 729-th checkpoint.
# Pruned weights for the 730-th checkpoint.
# Pruned weights for the 731-th checkpoint.
# Pruned weights for the 732-th checkpoint.
# Pruned weights for the 733-th checkpoint.
# Pruned weights for the 734-th checkpoint.
# Pruned weights for the 735-th checkpoint.
# Pruned weights for the 736-th checkpoint.
# Pruned weights for the 737-th checkpoint.
# Pruned weights for the 738-th checkpoint.
# Pruned weights for the 739-th checkpoint.
# Pruned weights for the 740-th checkpoint.
# Pruned weights for the 741-th checkpoint.
# Pruned weights for the 742-th checkpoint.
# Pruned weights for the 743-th checkpoint.
# Pruned weights for the 744-th checkpoint.
# Pruned weights for the 745-th checkpoint.
# Pruned weights for the 746-th checkpoint.
# Pruned weights for the 747-th checkpoint.
# Pruned weights for the 748-th checkpoint.
# Pruned weights for the 749-th checkpoint.
# Pruned weights for the 750-th checkpoint.
# Pruned weights for the 751-th checkpoint.
# Pruned weights for the 752-th checkpoint.
# Pruned weights for the 753-th checkpoint.
# Pruned weights for the 754-th checkpoint.
# Pruned weights for the 755-th checkpoint.
# Pruned weights for the 756-th checkpoint.
# Pruned weights for the 757-th checkpoint.
# Pruned weights for the 758-th checkpoint.
# Pruned weights for the 759-th checkpoint.
# Pruned weights for the 760-th checkpoint.
# Pruned weights for the 761-th checkpoint.
# Pruned weights for the 762-th checkpoint.
# Pruned weights for the 763-th checkpoint.
# Pruned weights for the 764-th checkpoint.
# Pruned weights for the 765-th checkpoint.
# Pruned weights for the 766-th checkpoint.
# Pruned weights for the 767-th checkpoint.
# Pruned weights for the 768-th checkpoint.
# Pruned weights for the 769-th checkpoint.
# Pruned weights for the 770-th checkpoint.
# Pruned weights for the 771-th checkpoint.
# Pruned weights for the 772-th checkpoint.
# Pruned weights for the 773-th checkpoint.
# Pruned weights for the 774-th checkpoint.
# Pruned weights for the 775-th checkpoint.
# Pruned weights for the 776-th checkpoint.
# Pruned weights for the 777-th checkpoint.
# Pruned weights for the 778-th checkpoint.
# Pruned weights for the 779-th checkpoint.
# Pruned weights for the 780-th checkpoint.
# Pruned weights for the 781-th checkpoint.
# Pruned weights for the 782-th checkpoint.
# Pruned weights for the 783-th checkpoint.
# Pruned weights for the 784-th checkpoint.
# Pruned weights for the 785-th checkpoint.
# Pruned weights for the 786-th checkpoint.
# Pruned weights for the 787-th checkpoint.
# Pruned weights for the 788-th checkpoint.
# Pruned weights for the 789-th checkpoint.
# Pruned weights for the 790-th checkpoint.
# Pruned weights for the 791-th checkpoint.
# Pruned weights for the 792-th checkpoint.
# Pruned weights for the 793-th checkpoint.
# Pruned weights for the 794-th checkpoint.
# Pruned weights for the 795-th checkpoint.
# Pruned weights for the 796-th checkpoint.
# Pruned weights for the 797-th checkpoint.
# Pruned weights for the 798-th checkpoint.
# Pruned weights for the 799-th checkpoint.
# Pruned weights for the 800-th checkpoint.
# Pruned weights for the 801-th checkpoint.
# Pruned weights for the 802-th checkpoint.
# Pruned weights for the 803-th checkpoint.
# Pruned weights for the 804-th checkpoint.
# Pruned weights for the 805-th checkpoint.
# Pruned weights for the 806-th checkpoint.
# Pruned weights for the 807-th checkpoint.
# Pruned weights for the 808-th checkpoint.
# Pruned weights for the 809-th checkpoint.
# Pruned weights for the 810-th checkpoint.
# Pruned weights for the 811-th checkpoint.
# Pruned weights for the 812-th checkpoint.
# Pruned weights for the 813-th checkpoint.
# Pruned weights for the 814-th checkpoint.
# Pruned weights for the 815-th checkpoint.
# Pruned weights for the 816-th checkpoint.
# Pruned weights for the 817-th checkpoint.
# Pruned weights for the 818-th checkpoint.
# Pruned weights for the 819-th checkpoint.
# Pruned weights for the 820-th checkpoint.
# Pruned weights for the 821-th checkpoint.
# Pruned weights for the 822-th checkpoint.
# Pruned weights for the 823-th checkpoint.
# Pruned weights for the 824-th checkpoint.
# Pruned weights for the 825-th checkpoint.
# Pruned weights for the 826-th checkpoint.
# Pruned weights for the 827-th checkpoint.
# Pruned weights for the 828-th checkpoint.
# Pruned weights for the 829-th checkpoint.
# Pruned weights for the 830-th checkpoint.
# Pruned weights for the 831-th checkpoint.
# Pruned weights for the 832-th checkpoint.
# Pruned weights for the 833-th checkpoint.
# Pruned weights for the 834-th checkpoint.
# Pruned weights for the 835-th checkpoint.
# Pruned weights for the 836-th checkpoint.
# Pruned weights for the 837-th checkpoint.
# Pruned weights for the 838-th checkpoint.
# Pruned weights for the 839-th checkpoint.
# Pruned weights for the 840-th checkpoint.
# Pruned weights for the 841-th checkpoint.
# Pruned weights for the 842-th checkpoint.
# Pruned weights for the 843-th checkpoint.
# Pruned weights for the 844-th checkpoint.
# Pruned weights for the 845-th checkpoint.
# Pruned weights for the 846-th checkpoint.
# Pruned weights for the 847-th checkpoint.
# Pruned weights for the 848-th checkpoint.
# Pruned weights for the 849-th checkpoint.
# Pruned weights for the 850-th checkpoint.
# Pruned weights for the 851-th checkpoint.
# Pruned weights for the 852-th checkpoint.
# Pruned weights for the 853-th checkpoint.
# Pruned weights for the 854-th checkpoint.
# Pruned weights for the 855-th checkpoint.
# Pruned weights for the 856-th checkpoint.
# Pruned weights for the 857-th checkpoint.
# Pruned weights for the 858-th checkpoint.
# Pruned weights for the 859-th checkpoint.
# Pruned weights for the 860-th checkpoint.
# Pruned weights for the 861-th checkpoint.
# Pruned weights for the 862-th checkpoint.
# Pruned weights for the 863-th checkpoint.
# Pruned weights for the 864-th checkpoint.
# Pruned weights for the 865-th checkpoint.
# Pruned weights for the 866-th checkpoint.
# Pruned weights for the 867-th checkpoint.
# Pruned weights for the 868-th checkpoint.
# Pruned weights for the 869-th checkpoint.
# Pruned weights for the 870-th checkpoint.
# Pruned weights for the 871-th checkpoint.
# Pruned weights for the 872-th checkpoint.
# Pruned weights for the 873-th checkpoint.
# Pruned weights for the 874-th checkpoint.
# Pruned weights for the 875-th checkpoint.
# Pruned weights for the 876-th checkpoint.
# Pruned weights for the 877-th checkpoint.
# Pruned weights for the 878-th checkpoint.
# Pruned weights for the 879-th checkpoint.
# Pruned weights for the 880-th checkpoint.
# Pruned weights for the 881-th checkpoint.
# Pruned weights for the 882-th checkpoint.
# Pruned weights for the 883-th checkpoint.
# Pruned weights for the 884-th checkpoint.
# Pruned weights for the 885-th checkpoint.
# Pruned weights for the 886-th checkpoint.
# Pruned weights for the 887-th checkpoint.
# Pruned weights for the 888-th checkpoint.
# Pruned weights for the 889-th checkpoint.
# Pruned weights for the 890-th checkpoint.
# Pruned weights for the 891-th checkpoint.
# Pruned weights for the 892-th checkpoint.
# Pruned weights for the 893-th checkpoint.
# Pruned weights for the 894-th checkpoint.
# Pruned weights for the 895-th checkpoint.
# Pruned weights for the 896-th checkpoint.
# Pruned weights for the 897-th checkpoint.
# Pruned weights for the 898-th checkpoint.
# Pruned weights for the 899-th checkpoint.
# Pruned weights for the 900-th checkpoint.
# Pruned weights for the 901-th checkpoint.
# Pruned weights for the 902-th checkpoint.
# Pruned weights for the 903-th checkpoint.
# Pruned weights for the 904-th checkpoint.
# Pruned weights for the 905-th checkpoint.
# Pruned weights for the 906-th checkpoint.
# Pruned weights for the 907-th checkpoint.
# Pruned weights for the 908-th checkpoint.
# Pruned weights for the 909-th checkpoint.
# Pruned weights for the 910-th checkpoint.
# Pruned weights for the 911-th checkpoint.
# Pruned weights for the 912-th checkpoint.
# Pruned weights for the 913-th checkpoint.
# Pruned weights for the 914-th checkpoint.
# Pruned weights for the 915-th checkpoint.
# Pruned weights for the 916-th checkpoint.
# Pruned weights for the 917-th checkpoint.
# Pruned weights for the 918-th checkpoint.
# Pruned weights for the 919-th checkpoint.
# Pruned weights for the 920-th checkpoint.
# Pruned weights for the 921-th checkpoint.
# Pruned weights for the 922-th checkpoint.
# Pruned weights for the 923-th checkpoint.
# Pruned weights for the 924-th checkpoint.
# Pruned weights for the 925-th checkpoint.
# Pruned weights for the 926-th checkpoint.
# Pruned weights for the 927-th checkpoint.
# Pruned weights for the 928-th checkpoint.
# Pruned weights for the 929-th checkpoint.
# Pruned weights for the 930-th checkpoint.
# Pruned weights for the 931-th checkpoint.
# Pruned weights for the 932-th checkpoint.
# Pruned weights for the 933-th checkpoint.
# Pruned weights for the 934-th checkpoint.
# Pruned weights for the 935-th checkpoint.
# Pruned weights for the 936-th checkpoint.
# Pruned weights for the 937-th checkpoint.
# Pruned weights for the 938-th checkpoint.
# Pruned weights for the 939-th checkpoint.
# Pruned weights for the 940-th checkpoint.
# Pruned weights for the 941-th checkpoint.
# Pruned weights for the 942-th checkpoint.
# Pruned weights for the 943-th checkpoint.
# Pruned weights for the 944-th checkpoint.
# Pruned weights for the 945-th checkpoint.
# Pruned weights for the 946-th checkpoint.
# Pruned weights for the 947-th checkpoint.
# Pruned weights for the 948-th checkpoint.
# Pruned weights for the 949-th checkpoint.
# Pruned weights for the 950-th checkpoint.
# Pruned weights for the 951-th checkpoint.
# Pruned weights for the 952-th checkpoint.
# Pruned weights for the 953-th checkpoint.
# Pruned weights for the 954-th checkpoint.
# Pruned weights for the 955-th checkpoint.
# Pruned weights for the 956-th checkpoint.
# Pruned weights for the 957-th checkpoint.
# Pruned weights for the 958-th checkpoint.
# Pruned weights for the 959-th checkpoint.
# Pruned weights for the 960-th checkpoint.
# Pruned weights for the 961-th checkpoint.
# Pruned weights for the 962-th checkpoint.
# Pruned weights for the 963-th checkpoint.
# Pruned weights for the 964-th checkpoint.
# Pruned weights for the 965-th checkpoint.
# Pruned weights for the 966-th checkpoint.
# Pruned weights for the 967-th checkpoint.
# Pruned weights for the 968-th checkpoint.
# Pruned weights for the 969-th checkpoint.
# Pruned weights for the 970-th checkpoint.
# Pruned weights for the 971-th checkpoint.
# Pruned weights for the 972-th checkpoint.
# Pruned weights for the 973-th checkpoint.
# Pruned weights for the 974-th checkpoint.
# Pruned weights for the 975-th checkpoint.
# Pruned weights for the 976-th checkpoint.
# Pruned weights for the 977-th checkpoint.
# Pruned weights for the 978-th checkpoint.
# Pruned weights for the 979-th checkpoint.
# Pruned weights for the 980-th checkpoint.
# Pruned weights for the 981-th checkpoint.
# Pruned weights for the 982-th checkpoint.
# Pruned weights for the 983-th checkpoint.
# Pruned weights for the 984-th checkpoint.
# Pruned weights for the 985-th checkpoint.
# Pruned weights for the 986-th checkpoint.
# Pruned weights for the 987-th checkpoint.
# Pruned weights for the 988-th checkpoint.
# Pruned weights for the 989-th checkpoint.
# Pruned weights for the 990-th checkpoint.
# Pruned weights for the 991-th checkpoint.
# Pruned weights for the 992-th checkpoint.
# Pruned weights for the 993-th checkpoint.
# Pruned weights for the 994-th checkpoint.
# Pruned weights for the 995-th checkpoint.
# Pruned weights for the 996-th checkpoint.
# Pruned weights for the 997-th checkpoint.
# Pruned weights for the 998-th checkpoint.
# Pruned weights for the 999-th checkpoint.
# Pruned weights for the 1000-th checkpoint.
# Pruned weights for the 1001-th checkpoint.
# Pruned weights for the 1002-th checkpoint.
# Pruned weights for the 1003-th checkpoint.
# Pruned weights for the 1004-th checkpoint.
# Pruned weights for the 1005-th checkpoint.
# Pruned weights for the 1006-th checkpoint.
# Pruned weights for the 1007-th checkpoint.
# Pruned weights for the 1008-th checkpoint.
# Pruned weights for the 1009-th checkpoint.
# Pruned weights for the 1010-th checkpoint.
# Pruned weights for the 1011-th checkpoint.
# Pruned weights for the 1012-th checkpoint.
# Pruned weights for the 1013-th checkpoint.
# Pruned weights for the 1014-th checkpoint.
# Pruned weights for the 1015-th checkpoint.
# Pruned weights for the 1016-th checkpoint.
# Pruned weights for the 1017-th checkpoint.
# Pruned weights for the 1018-th checkpoint.
# Pruned weights for the 1019-th checkpoint.
# Pruned weights for the 1020-th checkpoint.
# Pruned weights for the 1021-th checkpoint.
# Pruned weights for the 1022-th checkpoint.
# Pruned weights for the 1023-th checkpoint.
# Pruned weights for the 1024-th checkpoint.
# Pruned weights for the 1025-th checkpoint.
# Pruned weights for the 1026-th checkpoint.
# Pruned weights for the 1027-th checkpoint.
# Pruned weights for the 1028-th checkpoint.
# Pruned weights for the 1029-th checkpoint.
# Pruned weights for the 1030-th checkpoint.
# Pruned weights for the 1031-th checkpoint.
# Pruned weights for the 1032-th checkpoint.
# Pruned weights for the 1033-th checkpoint.
# Pruned weights for the 1034-th checkpoint.
# Pruned weights for the 1035-th checkpoint.
# Pruned weights for the 1036-th checkpoint.
# Pruned weights for the 1037-th checkpoint.
# Pruned weights for the 1038-th checkpoint.
# Pruned weights for the 1039-th checkpoint.
# Pruned weights for the 1040-th checkpoint.
# Pruned weights for the 1041-th checkpoint.
# Pruned weights for the 1042-th checkpoint.
# Pruned weights for the 1043-th checkpoint.
# Pruned weights for the 1044-th checkpoint.
# Pruned weights for the 1045-th checkpoint.
# Pruned weights for the 1046-th checkpoint.
# Pruned weights for the 1047-th checkpoint.
# Pruned weights for the 1048-th checkpoint.
# Pruned weights for the 1049-th checkpoint.
# Pruned weights for the 1050-th checkpoint.
# Pruned weights for the 1051-th checkpoint.
# Pruned weights for the 1052-th checkpoint.
# Pruned weights for the 1053-th checkpoint.
# Pruned weights for the 1054-th checkpoint.
# Pruned weights for the 1055-th checkpoint.
# Pruned weights for the 1056-th checkpoint.
# Pruned weights for the 1057-th checkpoint.
# Pruned weights for the 1058-th checkpoint.
# Pruned weights for the 1059-th checkpoint.
# Pruned weights for the 1060-th checkpoint.
# Pruned weights for the 1061-th checkpoint.
# Pruned weights for the 1062-th checkpoint.
# Pruned weights for the 1063-th checkpoint.
# Pruned weights for the 1064-th checkpoint.
# Pruned weights for the 1065-th checkpoint.
# Pruned weights for the 1066-th checkpoint.
# Pruned weights for the 1067-th checkpoint.
# Pruned weights for the 1068-th checkpoint.
# Pruned weights for the 1069-th checkpoint.
# Pruned weights for the 1070-th checkpoint.
# Pruned weights for the 1071-th checkpoint.
# Pruned weights for the 1072-th checkpoint.
# Pruned weights for the 1073-th checkpoint.
# Pruned weights for the 1074-th checkpoint.
# Pruned weights for the 1075-th checkpoint.
# Pruned weights for the 1076-th checkpoint.
# Pruned weights for the 1077-th checkpoint.
# Pruned weights for the 1078-th checkpoint.
# Pruned weights for the 1079-th checkpoint.
# Pruned weights for the 1080-th checkpoint.
# Pruned weights for the 1081-th checkpoint.
# Pruned weights for the 1082-th checkpoint.
# Pruned weights for the 1083-th checkpoint.
# Pruned weights for the 1084-th checkpoint.
# Pruned weights for the 1085-th checkpoint.
# Pruned weights for the 1086-th checkpoint.
# Pruned weights for the 1087-th checkpoint.
# Pruned weights for the 1088-th checkpoint.
# Pruned weights for the 1089-th checkpoint.
# Pruned weights for the 1090-th checkpoint.
# Pruned weights for the 1091-th checkpoint.
# Pruned weights for the 1092-th checkpoint.
# Pruned weights for the 1093-th checkpoint.
# Pruned weights for the 1094-th checkpoint.
# Pruned weights for the 1095-th checkpoint.
# Pruned weights for the 1096-th checkpoint.
# Pruned weights for the 1097-th checkpoint.
# Pruned weights for the 1098-th checkpoint.
# Pruned weights for the 1099-th checkpoint.
# Pruned weights for the 1100-th checkpoint.
# Pruned weights for the 1101-th checkpoint.
# Pruned weights for the 1102-th checkpoint.
# Pruned weights for the 1103-th checkpoint.
# Pruned weights for the 1104-th checkpoint.
# Pruned weights for the 1105-th checkpoint.
# Pruned weights for the 1106-th checkpoint.
# Pruned weights for the 1107-th checkpoint.
# Pruned weights for the 1108-th checkpoint.
# Pruned weights for the 1109-th checkpoint.
# Pruned weights for the 1110-th checkpoint.
# Pruned weights for the 1111-th checkpoint.
# Pruned weights for the 1112-th checkpoint.
# Pruned weights for the 1113-th checkpoint.
# Pruned weights for the 1114-th checkpoint.
# Pruned weights for the 1115-th checkpoint.
# Pruned weights for the 1116-th checkpoint.
# Pruned weights for the 1117-th checkpoint.
# Pruned weights for the 1118-th checkpoint.
# Pruned weights for the 1119-th checkpoint.
# Pruned weights for the 1120-th checkpoint.
# Pruned weights for the 1121-th checkpoint.
# Pruned weights for the 1122-th checkpoint.
# Pruned weights for the 1123-th checkpoint.
# Pruned weights for the 1124-th checkpoint.
# Pruned weights for the 1125-th checkpoint.
# Pruned weights for the 1126-th checkpoint.
# Pruned weights for the 1127-th checkpoint.
# Pruned weights for the 1128-th checkpoint.
# Pruned weights for the 1129-th checkpoint.
# Pruned weights for the 1130-th checkpoint.
# Pruned weights for the 1131-th checkpoint.
# Pruned weights for the 1132-th checkpoint.
# Pruned weights for the 1133-th checkpoint.
# Pruned weights for the 1134-th checkpoint.
# Pruned weights for the 1135-th checkpoint.
# ...
# Pruned weights for the 4591-th checkpoint.
# Pruned weights for the 4592-th checkpoint.
# Pruned weights for the 4593-th checkpoint.
# Pruned weights for the 4594-th checkpoint.
# Pruned weights for the 4595-th checkpoint.
# Pruned weights for the 4596-th checkpoint.
# Pruned weights for the 4597-th checkpoint.
# Pruned weights for the 4598-th checkpoint.
# Pruned weights for the 4599-th checkpoint.
# Pruned weights for the 4600-th checkpoint.
# Pruned weights for the 4601-th checkpoint.
# Pruned weights for the 4602-th checkpoint.
# Pruned weights for the 4603-th checkpoint.
# Pruned weights for the 4604-th checkpoint.
# Pruned weights for the 4605-th checkpoint.
# Pruned weights for the 4606-th checkpoint.
# Pruned weights for the 4607-th checkpoint.
# Pruned weights for the 4608-th checkpoint.
# Pruned weights for the 4609-th checkpoint.
# Pruned weights for the 4610-th checkpoint.
# Pruned weights for the 4611-th checkpoint.
# Pruned weights for the 4612-th checkpoint.
# Pruned weights for the 4613-th checkpoint.
# Pruned weights for the 4614-th checkpoint.
# Pruned weights for the 4615-th checkpoint.
# Pruned weights for the 4616-th checkpoint.
# Pruned weights for the 4617-th checkpoint.
# Pruned weights for the 4618-th checkpoint.
# Pruned weights for the 4619-th checkpoint.
# Pruned weights for the 4620-th checkpoint.
# Pruned weights for the 4621-th checkpoint.
# Pruned weights for the 4622-th checkpoint.
# Pruned weights for the 4623-th checkpoint.
# Pruned weights for the 4624-th checkpoint.
# Pruned weights for the 4625-th checkpoint.
# Pruned weights for the 4626-th checkpoint.
# Pruned weights for the 4627-th checkpoint.
# Pruned weights for the 4628-th checkpoint.
# Pruned weights for the 4629-th checkpoint.
# Pruned weights for the 4630-th checkpoint.
# Pruned weights for the 4631-th checkpoint.
# Pruned weights for the 4632-th checkpoint.
# Pruned weights for the 4633-th checkpoint.
# Pruned weights for the 4634-th checkpoint.
# Pruned weights for the 4635-th checkpoint.
# Pruned weights for the 4636-th checkpoint.
# Pruned weights for the 4637-th checkpoint.
# Pruned weights for the 4638-th checkpoint.
# Pruned weights for the 4639-th checkpoint.
# Pruned weights for the 4640-th checkpoint.
# Pruned weights for the 4641-th checkpoint.
# Pruned weights for the 4642-th checkpoint.
# Pruned weights for the 4643-th checkpoint.
# Pruned weights for the 4644-th checkpoint.
# Pruned weights for the 4645-th checkpoint.
# Pruned weights for the 4646-th checkpoint.
# Pruned weights for the 4647-th checkpoint.
# Pruned weights for the 4648-th checkpoint.
# Pruned weights for the 4649-th checkpoint.
# Pruned weights for the 4650-th checkpoint.
# Pruned weights for the 4651-th checkpoint.
# Pruned weights for the 4652-th checkpoint.
# Pruned weights for the 4653-th checkpoint.
# Pruned weights for the 4654-th checkpoint.
# Pruned weights for the 4655-th checkpoint.
# Pruned weights for the 4656-th checkpoint.
# Pruned weights for the 4657-th checkpoint.
# Pruned weights for the 4658-th checkpoint.
# Pruned weights for the 4659-th checkpoint.
# Pruned weights for the 4660-th checkpoint.
# Pruned weights for the 4661-th checkpoint.
# Pruned weights for the 4662-th checkpoint.
# Pruned weights for the 4663-th checkpoint.
# Pruned weights for the 4664-th checkpoint.
# Pruned weights for the 4665-th checkpoint.
# Pruned weights for the 4666-th checkpoint.
# Pruned weights for the 4667-th checkpoint.
# Pruned weights for the 4668-th checkpoint.
# Pruned weights for the 4669-th checkpoint.
# Pruned weights for the 4670-th checkpoint.
# Pruned weights for the 4671-th checkpoint.
# Pruned weights for the 4672-th checkpoint.
# Pruned weights for the 4673-th checkpoint.
# Pruned weights for the 4674-th checkpoint.
# Pruned weights for the 4675-th checkpoint.
# Pruned weights for the 4676-th checkpoint.
# Pruned weights for the 4677-th checkpoint.
# Pruned weights for the 4678-th checkpoint.
# Pruned weights for the 4679-th checkpoint.
# Pruned weights for the 4680-th checkpoint.
# Pruned weights for the 4681-th checkpoint.
# Pruned weights for the 4682-th checkpoint.
# Pruned weights for the 4683-th checkpoint.
# Pruned weights for the 4684-th checkpoint.
# Pruned weights for the 4685-th checkpoint.
# Pruned weights for the 4686-th checkpoint.
# Pruned weights for the 4687-th checkpoint.
# Pruned weights for the 4688-th checkpoint.
# Pruned weights for the 4689-th checkpoint.
# Pruned weights for the 4690-th checkpoint.
# Pruned weights for the 4691-th checkpoint.
# Pruned weights for the 4692-th checkpoint.
# Pruned weights for the 4693-th checkpoint.
# Pruned weights for the 4694-th checkpoint.
# Pruned weights for the 4695-th checkpoint.
# Pruned weights for the 4696-th checkpoint.
# Pruned weights for the 4697-th checkpoint.
# Pruned weights for the 4698-th checkpoint.
# Pruned weights for the 4699-th checkpoint.
# Pruned weights for the 4700-th checkpoint.
# Pruned weights for the 4701-th checkpoint.
# Pruned weights for the 4702-th checkpoint.
# Pruned weights for the 4703-th checkpoint.
# Pruned weights for the 4704-th checkpoint.
# Pruned weights for the 4705-th checkpoint.
# Pruned weights for the 4706-th checkpoint.
# Pruned weights for the 4707-th checkpoint.
# Pruned weights for the 4708-th checkpoint.
# Pruned weights for the 4709-th checkpoint.
# Pruned weights for the 4710-th checkpoint.
# Pruned weights for the 4711-th checkpoint.
# Pruned weights for the 4712-th checkpoint.
# Pruned weights for the 4713-th checkpoint.
# Pruned weights for the 4714-th checkpoint.
# Pruned weights for the 4715-th checkpoint.
# Pruned weights for the 4716-th checkpoint.
# Pruned weights for the 4717-th checkpoint.
# Pruned weights for the 4718-th checkpoint.
# Pruned weights for the 4719-th checkpoint.
# Pruned weights for the 4720-th checkpoint.
# Pruned weights for the 4721-th checkpoint.
# Pruned weights for the 4722-th checkpoint.
# Pruned weights for the 4723-th checkpoint.
# Pruned weights for the 4724-th checkpoint.
# Pruned weights for the 4725-th checkpoint.
# Pruned weights for the 4726-th checkpoint.
# Pruned weights for the 4727-th checkpoint.
# Pruned weights for the 4728-th checkpoint.
# Pruned weights for the 4729-th checkpoint.
# Pruned weights for the 4730-th checkpoint.
# Pruned weights for the 4731-th checkpoint.
# Pruned weights for the 4732-th checkpoint.
# Pruned weights for the 4733-th checkpoint.
# Pruned weights for the 4734-th checkpoint.
# Pruned weights for the 4735-th checkpoint.
# Pruned weights for the 4736-th checkpoint.
# Pruned weights for the 4737-th checkpoint.
# Pruned weights for the 4738-th checkpoint.
# Pruned weights for the 4739-th checkpoint.
# Pruned weights for the 4740-th checkpoint.
# Pruned weights for the 4741-th checkpoint.
# Pruned weights for the 4742-th checkpoint.
# Pruned weights for the 4743-th checkpoint.
# Pruned weights for the 4744-th checkpoint.
# Pruned weights for the 4745-th checkpoint.
# Pruned weights for the 4746-th checkpoint.
# Pruned weights for the 4747-th checkpoint.
# Pruned weights for the 4748-th checkpoint.
# Pruned weights for the 4749-th checkpoint.
# Pruned weights for the 4750-th checkpoint.
# Pruned weights for the 4751-th checkpoint.
# Pruned weights for the 4752-th checkpoint.
# Pruned weights for the 4753-th checkpoint.
# Pruned weights for the 4754-th checkpoint.
# Pruned weights for the 4755-th checkpoint.
# Pruned weights for the 4756-th checkpoint.
# Pruned weights for the 4757-th checkpoint.
# Pruned weights for the 4758-th checkpoint.
# Pruned weights for the 4759-th checkpoint.
# Pruned weights for the 4760-th checkpoint.
# Pruned weights for the 4761-th checkpoint.
# Pruned weights for the 4762-th checkpoint.
# Pruned weights for the 4763-th checkpoint.
# Pruned weights for the 4764-th checkpoint.
# Pruned weights for the 4765-th checkpoint.
# Pruned weights for the 4766-th checkpoint.
# Pruned weights for the 4767-th checkpoint.
# Pruned weights for the 4768-th checkpoint.
# Pruned weights for the 4769-th checkpoint.
# Pruned weights for the 4770-th checkpoint.
# Pruned weights for the 4771-th checkpoint.
# Pruned weights for the 4772-th checkpoint.
# Pruned weights for the 4773-th checkpoint.
# Pruned weights for the 4774-th checkpoint.
# Pruned weights for the 4775-th checkpoint.
# Pruned weights for the 4776-th checkpoint.
# Pruned weights for the 4777-th checkpoint.
# Pruned weights for the 4778-th checkpoint.
# Pruned weights for the 4779-th checkpoint.
# Pruned weights for the 4780-th checkpoint.
# Pruned weights for the 4781-th checkpoint.
# Pruned weights for the 4782-th checkpoint.
# Pruned weights for the 4783-th checkpoint.
# Pruned weights for the 4784-th checkpoint.
# Pruned weights for the 4785-th checkpoint.
# Pruned weights for the 4786-th checkpoint.
# Pruned weights for the 4787-th checkpoint.
# Pruned weights for the 4788-th checkpoint.
# Pruned weights for the 4789-th checkpoint.
# Pruned weights for the 4790-th checkpoint.
# Pruned weights for the 4791-th checkpoint.
# Pruned weights for the 4792-th checkpoint.
# Pruned weights for the 4793-th checkpoint.
# Pruned weights for the 4794-th checkpoint.
# Pruned weights for the 4795-th checkpoint.
# Pruned weights for the 4796-th checkpoint.
# Pruned weights for the 4797-th checkpoint.
# Pruned weights for the 4798-th checkpoint.
# Pruned weights for the 4799-th checkpoint.
# Pruned weights for the 4800-th checkpoint.
# Pruned weights for the 4801-th checkpoint.
# Pruned weights for the 4802-th checkpoint.
# Pruned weights for the 4803-th checkpoint.
# Pruned weights for the 4804-th checkpoint.
# Pruned weights for the 4805-th checkpoint.
# Pruned weights for the 4806-th checkpoint.
# Pruned weights for the 4807-th checkpoint.
# Pruned weights for the 4808-th checkpoint.
# Pruned weights for the 4809-th checkpoint.
# Pruned weights for the 4810-th checkpoint.
# Pruned weights for the 4811-th checkpoint.
# Pruned weights for the 4812-th checkpoint.
# Pruned weights for the 4813-th checkpoint.
# Pruned weights for the 4814-th checkpoint.
# Pruned weights for the 4815-th checkpoint.
# Pruned weights for the 4816-th checkpoint.
# Pruned weights for the 4817-th checkpoint.
# Pruned weights for the 4818-th checkpoint.
# Pruned weights for the 4819-th checkpoint.
# Pruned weights for the 4820-th checkpoint.
# Pruned weights for the 4821-th checkpoint.
# Pruned weights for the 4822-th checkpoint.
# Pruned weights for the 4823-th checkpoint.
# Pruned weights for the 4824-th checkpoint.
# Pruned weights for the 4825-th checkpoint.
# Pruned weights for the 4826-th checkpoint.
# Pruned weights for the 4827-th checkpoint.
# Pruned weights for the 4828-th checkpoint.
# Pruned weights for the 4829-th checkpoint.
# Pruned weights for the 4830-th checkpoint.
# Pruned weights for the 4831-th checkpoint.
# Pruned weights for the 4832-th checkpoint.
# Pruned weights for the 4833-th checkpoint.
# Pruned weights for the 4834-th checkpoint.
# Pruned weights for the 4835-th checkpoint.
# Pruned weights for the 4836-th checkpoint.
# Pruned weights for the 4837-th checkpoint.
# Pruned weights for the 4838-th checkpoint.
# Pruned weights for the 4839-th checkpoint.
# Pruned weights for the 4840-th checkpoint.
# Pruned weights for the 4841-th checkpoint.
# Pruned weights for the 4842-th checkpoint.
# Pruned weights for the 4843-th checkpoint.
# Pruned weights for the 4844-th checkpoint.
# Pruned weights for the 4845-th checkpoint.
# Pruned weights for the 4846-th checkpoint.
# Pruned weights for the 4847-th checkpoint.
# Pruned weights for the 4848-th checkpoint.
# Pruned weights for the 4849-th checkpoint.
# Pruned weights for the 4850-th checkpoint.
# Pruned weights for the 4851-th checkpoint.
# Pruned weights for the 4852-th checkpoint.
# Pruned weights for the 4853-th checkpoint.
# Pruned weights for the 4854-th checkpoint.
# Pruned weights for the 4855-th checkpoint.
# Pruned weights for the 4856-th checkpoint.
# Pruned weights for the 4857-th checkpoint.
# Pruned weights for the 4858-th checkpoint.
# Pruned weights for the 4859-th checkpoint.
# Pruned weights for the 4860-th checkpoint.
# Pruned weights for the 4861-th checkpoint.
# Pruned weights for the 4862-th checkpoint.
# Pruned weights for the 4863-th checkpoint.
# Pruned weights for the 4864-th checkpoint.
# Pruned weights for the 4865-th checkpoint.
# Pruned weights for the 4866-th checkpoint.
# Pruned weights for the 4867-th checkpoint.
# Pruned weights for the 4868-th checkpoint.
# Pruned weights for the 4869-th checkpoint.
# Pruned weights for the 4870-th checkpoint.
# Pruned weights for the 4871-th checkpoint.
# Pruned weights for the 4872-th checkpoint.
# Pruned weights for the 4873-th checkpoint.
# Pruned weights for the 4874-th checkpoint.
# Pruned weights for the 4875-th checkpoint.
# Pruned weights for the 4876-th checkpoint.
# Pruned weights for the 4877-th checkpoint.
# Pruned weights for the 4878-th checkpoint.
# Pruned weights for the 4879-th checkpoint.
# Pruned weights for the 4880-th checkpoint.
# Pruned weights for the 4881-th checkpoint.
# Pruned weights for the 4882-th checkpoint.
# Pruned weights for the 4883-th checkpoint.
# Pruned weights for the 4884-th checkpoint.
# Pruned weights for the 4885-th checkpoint.
# Pruned weights for the 4886-th checkpoint.
# Pruned weights for the 4887-th checkpoint.
# Pruned weights for the 4888-th checkpoint.
# Pruned weights for the 4889-th checkpoint.
# Pruned weights for the 4890-th checkpoint.
# Pruned weights for the 4891-th checkpoint.
# Pruned weights for the 4892-th checkpoint.
# Pruned weights for the 4893-th checkpoint.
# Pruned weights for the 4894-th checkpoint.
# Pruned weights for the 4895-th checkpoint.
# Pruned weights for the 4896-th checkpoint.
# Pruned weights for the 4897-th checkpoint.
# Pruned weights for the 4898-th checkpoint.
# Pruned weights for the 4899-th checkpoint.
# Pruned weights for the 4900-th checkpoint.
# Pruned weights for the 4901-th checkpoint.
# Pruned weights for the 4902-th checkpoint.
# Pruned weights for the 4903-th checkpoint.
# Pruned weights for the 4904-th checkpoint.
# Pruned weights for the 4905-th checkpoint.
# Pruned weights for the 4906-th checkpoint.
# Pruned weights for the 4907-th checkpoint.
# Pruned weights for the 4908-th checkpoint.
# Pruned weights for the 4909-th checkpoint.
# Pruned weights for the 4910-th checkpoint.
# Pruned weights for the 4911-th checkpoint.
# Pruned weights for the 4912-th checkpoint.
# Pruned weights for the 4913-th checkpoint.
# Pruned weights for the 4914-th checkpoint.
# Pruned weights for the 4915-th checkpoint.
# Pruned weights for the 4916-th checkpoint.
# Pruned weights for the 4917-th checkpoint.
# Pruned weights for the 4918-th checkpoint.
# Pruned weights for the 4919-th checkpoint.
# Pruned weights for the 4920-th checkpoint.
# Pruned weights for the 4921-th checkpoint.
# Pruned weights for the 4922-th checkpoint.
# Pruned weights for the 4923-th checkpoint.
# Pruned weights for the 4924-th checkpoint.
# Pruned weights for the 4925-th checkpoint.
# Pruned weights for the 4926-th checkpoint.
# Pruned weights for the 4927-th checkpoint.
# Pruned weights for the 4928-th checkpoint.
# Pruned weights for the 4929-th checkpoint.
# Pruned weights for the 4930-th checkpoint.
# Pruned weights for the 4931-th checkpoint.
# Pruned weights for the 4932-th checkpoint.
# Pruned weights for the 4933-th checkpoint.
# Pruned weights for the 4934-th checkpoint.
# Pruned weights for the 4935-th checkpoint.
# Pruned weights for the 4936-th checkpoint.
# Pruned weights for the 4937-th checkpoint.
# Pruned weights for the 4938-th checkpoint.
# Pruned weights for the 4939-th checkpoint.
# Pruned weights for the 4940-th checkpoint.
# Pruned weights for the 4941-th checkpoint.
# Pruned weights for the 4942-th checkpoint.
# Pruned weights for the 4943-th checkpoint.
# Pruned weights for the 4944-th checkpoint.
# Pruned weights for the 4945-th checkpoint.
# Pruned weights for the 4946-th checkpoint.
# Pruned weights for the 4947-th checkpoint.
# Pruned weights for the 4948-th checkpoint.
# Pruned weights for the 4949-th checkpoint.
# Pruned weights for the 4950-th checkpoint.
# Pruned weights for the 4951-th checkpoint.
# Pruned weights for the 4952-th checkpoint.
# Pruned weights for the 4953-th checkpoint.
# Pruned weights for the 4954-th checkpoint.
# Pruned weights for the 4955-th checkpoint.
# Pruned weights for the 4956-th checkpoint.
# Pruned weights for the 4957-th checkpoint.
# Pruned weights for the 4958-th checkpoint.
# Pruned weights for the 4959-th checkpoint.
# Pruned weights for the 4960-th checkpoint.
# Pruned weights for the 4961-th checkpoint.
# Pruned weights for the 4962-th checkpoint.

# %%
# Test dropout:
import torch.nn as nn

m = nn.Dropout(p=0.3)
print(m.state_dict())
# Out:
# OrderedDict()
